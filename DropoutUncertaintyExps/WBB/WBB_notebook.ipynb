# %%
# Copyright 2016, Yarin Gal, All rights reserved.
# This code is based on the code by Jose Miguel Hernandez-Lobato used for his 
# paper "Probabilistic Backpropagation for Scalable Learning of Bayesian Neural Networks".

import warnings
warnings.filterwarnings("ignore")

import math
from scipy.special import logsumexp
import numpy as np

from keras.regularizers import l2
# from keras import Input
from keras.layers import Input
from keras.layers import Dropout
from keras.layers import Dense
# from keras import Model

import time

import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn.functional as F
import torch.nn as nn
import torch.utils.data as Data
from scipy.stats import norm

import time


class netWBB:
    n_bootstrap_samples = 100     #number of bootstrap sampling
    NNs = []

    def __init__(self, X_train, y_train, n_hidden, n_epochs = 40,
        normalize = False):

        """
            Constructor for the class implementing a Bayesian neural network
            trained with the probabilistic back propagation method.

            @param X_train      Matrix with the features for the training data.
            @param y_train      Vector with the target variables for the
                                training data.
            @param n_hidden     Vector with the number of neurons for each
                                hidden layer.
            @param n_epochs     Numer of epochs for which to train the
                                network. The recommended value 40 should be
                                enough.
            @param normalize    Whether to normalize the input features. This
                                is recommended unles the input vector is for
                                example formed by binary features (a
                                fingerprint). In that case we do not recommend
                                to normalize the features.
        """


        # We normalize the training data to have zero mean and unit standard
        # deviation in the training set if necessary
        print("running")
        if normalize:
            self.std_X_train = np.std(X_train, 0)
            self.std_X_train[ self.std_X_train == 0 ] = 1
            self.mean_X_train = np.mean(X_train, 0)
        else:
            self.std_X_train = np.ones(X_train.shape[ 1 ])
            self.mean_X_train = np.zeros(X_train.shape[ 1 ])

        X_train = (X_train - np.full(X_train.shape, self.mean_X_train)) / \
            np.full(X_train.shape, self.std_X_train)

        self.mean_y_train = np.mean(y_train)
        self.std_y_train = np.std(y_train)

        y_train_normalized = (y_train - self.mean_y_train) / self.std_y_train
        y_train_normalized = np.array(y_train_normalized, ndmin = 2).T

        
        # TODO: implement WBB network
        input_shape = X_train.shape[1]
        output_shape = y_train_normalized.shape[1]
        max_index = X_train.shape[0]
        print("shape of input, output and max_index", input_shape, output_shape, max_index)

        lamda = 0.001
        Exp = torch.distributions.exponential.Exponential(torch.tensor([1.0]))
        for m in range (self.n_bootstrap_samples):
            print("Trainning model: ", m)
            weights = [Exp.sample() for _ in range(X_train.shape[0] + 1)]
            print(len(weights))

            # Network with a hidden layer and ReLU activation
            net = torch.nn.Sequential(
            torch.nn.Linear(input_shape, n_hidden[0]),
            torch.nn.ReLU(),
            torch.nn.Linear(n_hidden[0], output_shape),
            )
            
            
            BATCH_SIZE = 64
            optimizer = torch.optim.Adam(net.parameters(), lr=0.01)

            # Minimizing the negative log-likelihood of our data with respect to θ is equivalent to 
            # minimizing the mean squared error between the observed y and our prediction thereof
            loss_func = torch.nn.MSELoss(reduction = 'none')
            torch_dataset = Data.TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train_normalized))

            loader = Data.DataLoader(
            dataset=torch_dataset, 
            batch_size=BATCH_SIZE, 
            shuffle=False, num_workers=2,)

            start_time = time.time()
            for epoch in range(n_epochs):
                optimizer.zero_grad()
                loss = 0

                index1 = 0;
                for step, (batch_x, batch_y) in enumerate(loader):  
                    
                    index2 = (step+1)*BATCH_SIZE   # set index of weight array to multiply with loss: weight*loss_func
                    index2 = min(index2,max_index) 
                    b_x = Variable(batch_x)
                    b_y = Variable(batch_y)               
                    prediction = net(b_x.float())    
                    
                    # print("weight ",(torch.FloatTensor(weights[index1:index2]).shape))
                    # print("loss ", loss_func(prediction, b_y.float()).shape)
                    loss += (torch.FloatTensor(weights[index1:index2]).unsqueeze(1) * loss_func(prediction, b_y.float())).sum()
                    # print((torch.FloatTensor(weights[index1:index2]).unsqueeze(1) * loss_func(prediction, b_y.float())).shape)
                    index1 = index2   

                # #add L1 regularization
                # l1 = 0
                # for p in net.parameters():
                #     l1 = l1 + p.abs().sum()       
                # loss += weights[-1] * lamda * l1

                #add L2 regularization
                l2 = 0
                for p in net.parameters():
                    l2 = l2 + 0.5 * (p ** 2).sum()      
                loss += (weights[-1] * lamda * l2).sum()
                
                loss.backward()         
                optimizer.step()        
                print("EPOCH: ", epoch, " LOSS: ", loss)
            print("BATCH_SIZE: ", BATCH_SIZE, "time execution for a neural net: ", time.time() - start_time )
            self.NNs.append(net)


    def predict(self, X_test, y_test):

        """
            Function for making predictions with the Bayesian neural network.

            @param X_test   The matrix of features for the test data
            
    
            @return m       The predictive mean for the test target variables.
            @return v       The predictive variance for the test target
                            variables.
            @return v_noise The estimated variance for the additive noise.

        """

        X_test = np.array(X_test, ndmin = 2)
        y_test = np.array(y_test, ndmin = 2).T

        # We normalize the test set

        X_test = (X_test - np.full(X_test.shape, self.mean_X_train)) / \
            np.full(X_test.shape, self.std_X_train)

        # We compute the predictive mean and variance for the target variables
        # of the test data

        NN_pred = np.array([self.NNs[m](torch.from_numpy(X_test).float()).detach().numpy() for m in range(self.n_bootstrap_samples)])
        NN_pred = NN_pred * self.std_y_train + self.mean_y_train

        standard_pred = NN_pred[0]
        rmse_standard_pred = np.mean((y_test.squeeze() - standard_pred.squeeze())**2.)**0.5

        # MC_error
        MC_pred = np.mean(NN_pred, axis = 0)
        rmse = np.mean((y_test.squeeze() - MC_pred.squeeze())**2.)**0.5

        variance_ll = 0.1
        tau = 1. / variance_ll
        # T = y_test.shape[0]
        T = self.n_bootstrap_samples
        # We compute the test log-likelihood
        ll = (logsumexp(-0.5 * tau * (y_test[None] - NN_pred)**2., 0) - np.log(T) 
            - 0.5*np.log(2*np.pi) + 0.5*np.log(tau))
        test_ll = np.mean(ll)

        # We are done!
        return rmse_standard_pred, rmse, test_ll

# %%
# Copyright 2016, Yarin Gal, All rights reserved.
# This code is based on the code by Jose Miguel Hernandez-Lobato used for his 
# paper "Probabilistic Backpropagation for Scalable Learning of Bayesian Neural Networks".

# This file contains code to train dropout networks on the UCI datasets using the following algorithm:
# 1. Create 20 random splits of the training-test dataset.
# 2. For each split:
# 3.   Create a validation (val) set taking 20% of the training set.
# 4.   Get best hyperparameters: dropout_rate and tau by training on (train-val) set and testing on val set.
# 5.   Train a network on the entire training set with the best pair of hyperparameters.
# 6.   Get the performance (MC RMSE and log-likelihood) on the test set.
# 7. Report the averaged performance (Monte Carlo RMSE and log-likelihood) on all 20 splits.

import math
import numpy as np
import argparse
import sys

# parser=argparse.ArgumentParser()

# parser.add_argument('--dir', '-d', required=True, help='Name of the UCI Dataset directory. Eg: bostonHousing')
# parser.add_argument('--epochx','-e', default=500, type=int, help='Multiplier for the number of epochs for training.')
# parser.add_argument('--hidden', '-nh', default=2, type=int, help='Number of hidden layers for the neural net')

# args=parser.parse_args()

# data_directory = args.dir
# epochs_multiplier = args.epochx
# num_hidden_layers = args.hidden

data_directory = "yacht"
epochs_multiplier = 30
num_hidden_layers = 1

# sys.path.append('net/')

# import netWBB
# from net import netWBB

# We delete previous results

from subprocess import call


_RESULTS_VALIDATION_LL = "./UCI_Datasets/" + data_directory + "/results/validation_ll_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_VALIDATION_RMSE = "./UCI_Datasets/" + data_directory + "/results/validation_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_VALIDATION_MC_RMSE = "./UCI_Datasets/" + data_directory + "/results/validation_MC_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"

_RESULTS_TEST_LL = "./UCI_Datasets/" + data_directory + "/results/test_ll_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_TAU = "./UCI_Datasets/" + data_directory + "/results/test_tau_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_RMSE = "./UCI_Datasets/" + data_directory + "/results/test_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_MC_RMSE = "./UCI_Datasets/" + data_directory + "/results/test_MC_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_LOG = "./UCI_Datasets/" + data_directory + "/results/log_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"

_DATA_DIRECTORY_PATH = "./UCI_Datasets/" + data_directory + "/data/"
_DROPOUT_RATES_FILE = _DATA_DIRECTORY_PATH + "dropout_rates.txt"
_TAU_VALUES_FILE = _DATA_DIRECTORY_PATH + "tau_values.txt"
_DATA_FILE = _DATA_DIRECTORY_PATH + "data.txt"
_HIDDEN_UNITS_FILE = _DATA_DIRECTORY_PATH + "n_hidden.txt"
_EPOCHS_FILE = _DATA_DIRECTORY_PATH + "n_epochs.txt"
_INDEX_FEATURES_FILE = _DATA_DIRECTORY_PATH + "index_features.txt"
_INDEX_TARGET_FILE = _DATA_DIRECTORY_PATH + "index_target.txt"
_N_SPLITS_FILE = _DATA_DIRECTORY_PATH + "n_splits.txt"

def _get_index_train_test_path(split_num, train = True):
    """
       Method to generate the path containing the training/test split for the given
       split number (generally from 1 to 20).
       @param split_num      Split number for which the data has to be generated
       @param train          Is true if the data is training data. Else false.
       @return path          Path of the file containing the requried data
    """
    if train:
        return _DATA_DIRECTORY_PATH + "index_train_" + str(split_num) + ".txt"
    else:
        return _DATA_DIRECTORY_PATH + "index_test_" + str(split_num) + ".txt" 


print ("Removing existing result files...")
call(["rm", _RESULTS_VALIDATION_LL])
call(["rm", _RESULTS_VALIDATION_RMSE])
call(["rm", _RESULTS_VALIDATION_MC_RMSE])
call(["rm", _RESULTS_TEST_LL])
call(["rm", _RESULTS_TEST_TAU])
call(["rm", _RESULTS_TEST_RMSE])
call(["rm", _RESULTS_TEST_MC_RMSE])
call(["rm", _RESULTS_TEST_LOG])
print ("Result files removed.")

# We fix the random seed

np.random.seed(1)

print ("Loading data and other hyperparameters...")
# We load the data

data = np.loadtxt(_DATA_FILE)

# We load the number of hidden units

n_hidden = np.loadtxt(_HIDDEN_UNITS_FILE).tolist()

# We load the number of training epocs

n_epochs = np.loadtxt(_EPOCHS_FILE).tolist()

# We load the indexes for the features and for the target

index_features = np.loadtxt(_INDEX_FEATURES_FILE)
index_target = np.loadtxt(_INDEX_TARGET_FILE)

X = data[ : , [int(i) for i in index_features.tolist()] ]
y = data[ : , int(index_target.tolist()) ]

# We iterate over the training test splits

n_splits = np.loadtxt(_N_SPLITS_FILE)
print ("Done.")

errors, MC_errors, lls = [], [], []
# for split in range(int(n_splits)):
for split in range(5):  # first, test in 5 splits dataset
    print ("Trainning on split: ", split)
    # We load the indexes of the training and test sets
    print ('Loading file: ' + _get_index_train_test_path(split, train=True))
    print ('Loading file: ' + _get_index_train_test_path(split, train=False))
    index_train = np.loadtxt(_get_index_train_test_path(split, train=True))
    index_test = np.loadtxt(_get_index_train_test_path(split, train=False))

    X_train = X[ [int(i) for i in index_train.tolist()] ]
    y_train = y[ [int(i) for i in index_train.tolist()] ]
    
    X_test = X[ [int(i) for i in index_test.tolist()] ]
    y_test = y[ [int(i) for i in index_test.tolist()] ]

    X_train_original = X_train
    y_train_original = y_train
    num_training_examples = int(0.8 * X_train.shape[0])
    X_validation = X_train[num_training_examples:, :]
    y_validation = y_train[num_training_examples:]
    X_train = X_train[0:num_training_examples, :]
    y_train = y_train[0:num_training_examples]
    
    # Printing the size of the training, validation and test sets
    print ('Number of training examples: ' + str(X_train.shape[0]))
    print ('Number of validation examples: ' + str(X_validation.shape[0]))
    print ('Number of test examples: ' + str(X_test.shape[0]))
    print ('Number of train_original examples: ' + str(X_train_original.shape[0]))

    # List of hyperparameters which we will try out using grid-search
    # dropout_rates = np.loadtxt(_DROPOUT_RATES_FILE).tolist()
    # tau_values = np.loadtxt(_TAU_VALUES_FILE).tolist()


    network = netWBB(X_train_original, y_train_original, ([ int(n_hidden) ] * num_hidden_layers),
            normalize = True, n_epochs = int(n_epochs * epochs_multiplier))


            
#             # Storing validation results
#             with open(_RESULTS_VALIDATION_RMSE, "a") as myfile:
#                 myfile.write('Dropout_Rate: ' + repr(dropout_rate) + ' Tau: ' + repr(tau) + ' :: ')
#                 myfile.write(repr(error) + '\n')

#             with open(_RESULTS_VALIDATION_MC_RMSE, "a") as myfile:
#                 myfile.write('Dropout_Rate: ' + repr(dropout_rate) + ' Tau: ' + repr(tau) + ' :: ')
#                 myfile.write(repr(MC_error) + '\n')

#             with open(_RESULTS_VALIDATION_LL, "a") as myfile:
#                 myfile.write('Dropout_Rate: ' + repr(dropout_rate) + ' Tau: ' + repr(tau) + ' :: ')
#                 myfile.write(repr(ll) + '\n')

#     # Storing test results
#     best_network = net.net(X_train_original, y_train_original, ([ int(n_hidden) ] * num_hidden_layers),
#                     normalize = True, n_epochs = int(n_epochs * epochs_multiplier), tau = best_tau,
#                     dropout = best_dropout)
    error, MC_error, ll = network.predict(X_test, y_test)
    
    with open(_RESULTS_TEST_RMSE, "a") as myfile:
        myfile.write(repr(error) + '\n')

    with open(_RESULTS_TEST_MC_RMSE, "a") as myfile:
        myfile.write(repr(MC_error) + '\n')

    with open(_RESULTS_TEST_LL, "a") as myfile:
        myfile.write(repr(ll) + '\n')

    # with open(_RESULTS_TEST_TAU, "a") as myfile:
    #     myfile.write(repr(best_network.tau) + '\n')

    print ("Tests on split " + str(split) + " complete.")
    errors += [error]
    MC_errors += [MC_error]
    lls += [ll]

with open(_RESULTS_TEST_LOG, "a") as myfile:
    myfile.write('errors %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(errors), np.std(errors), np.std(errors)/math.sqrt(n_splits),
        np.percentile(errors, 50), np.percentile(errors, 25), np.percentile(errors, 75)))
    myfile.write('MC errors %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(MC_errors), np.std(MC_errors), np.std(MC_errors)/math.sqrt(n_splits),
        np.percentile(MC_errors, 50), np.percentile(MC_errors, 25), np.percentile(MC_errors, 75)))
    myfile.write('lls %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(lls), np.std(lls), np.std(lls)/math.sqrt(n_splits), 
        np.percentile(lls, 50), np.percentile(lls, 25), np.percentile(lls, 75)))
# Out:
# Removing existing result files...
# Result files removed.
# Loading data and other hyperparameters...
# Done.
# Trainning on split:  0
# Loading file: ./UCI_Datasets/yacht/data/index_train_0.txt
# Loading file: ./UCI_Datasets/yacht/data/index_test_0.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# running
# shape 6 1 277
# Trainning model:  0
# 278
# EPOCH:  0  LOSS:  tensor(356.8891, grad_fn=<AddBackward0>)
# EPOCH:  1  LOSS:  tensor(307.4855, grad_fn=<AddBackward0>)
# EPOCH:  2  LOSS:  tensor(270.0096, grad_fn=<AddBackward0>)
# EPOCH:  3  LOSS:  tensor(239.9880, grad_fn=<AddBackward0>)
# EPOCH:  4  LOSS:  tensor(214.6577, grad_fn=<AddBackward0>)
# EPOCH:  5  LOSS:  tensor(192.3997, grad_fn=<AddBackward0>)
# EPOCH:  6  LOSS:  tensor(172.4898, grad_fn=<AddBackward0>)
# EPOCH:  7  LOSS:  tensor(154.5892, grad_fn=<AddBackward0>)
# EPOCH:  8  LOSS:  tensor(138.7633, grad_fn=<AddBackward0>)
# EPOCH:  9  LOSS:  tensor(125.2663, grad_fn=<AddBackward0>)
# EPOCH:  10  LOSS:  tensor(114.4913, grad_fn=<AddBackward0>)
# EPOCH:  11  LOSS:  tensor(106.7142, grad_fn=<AddBackward0>)
# EPOCH:  12  LOSS:  tensor(101.8800, grad_fn=<AddBackward0>)
# EPOCH:  13  LOSS:  tensor(99.4400, grad_fn=<AddBackward0>)
# EPOCH:  14  LOSS:  tensor(98.4548, grad_fn=<AddBackward0>)
# EPOCH:  15  LOSS:  tensor(98.0498, grad_fn=<AddBackward0>)
# EPOCH:  16  LOSS:  tensor(97.6990, grad_fn=<AddBackward0>)
# EPOCH:  17  LOSS:  tensor(97.1229, grad_fn=<AddBackward0>)
# EPOCH:  18  LOSS:  tensor(96.1453, grad_fn=<AddBackward0>)
# EPOCH:  19  LOSS:  tensor(94.6330, grad_fn=<AddBackward0>)
# EPOCH:  20  LOSS:  tensor(92.4998, grad_fn=<AddBackward0>)
# EPOCH:  21  LOSS:  tensor(89.6844, grad_fn=<AddBackward0>)
# EPOCH:  22  LOSS:  tensor(86.4157, grad_fn=<AddBackward0>)
# EPOCH:  23  LOSS:  tensor(82.9456, grad_fn=<AddBackward0>)
# EPOCH:  24  LOSS:  tensor(79.5524, grad_fn=<AddBackward0>)
# EPOCH:  25  LOSS:  tensor(76.4355, grad_fn=<AddBackward0>)
# EPOCH:  26  LOSS:  tensor(73.6139, grad_fn=<AddBackward0>)
# EPOCH:  27  LOSS:  tensor(71.0927, grad_fn=<AddBackward0>)
# EPOCH:  28  LOSS:  tensor(68.8636, grad_fn=<AddBackward0>)
# EPOCH:  29  LOSS:  tensor(66.8622, grad_fn=<AddBackward0>)
# EPOCH:  30  LOSS:  tensor(65.0042, grad_fn=<AddBackward0>)
# EPOCH:  31  LOSS:  tensor(63.1437, grad_fn=<AddBackward0>)
# EPOCH:  32  LOSS:  tensor(61.2323, grad_fn=<AddBackward0>)
# EPOCH:  33  LOSS:  tensor(59.1790, grad_fn=<AddBackward0>)
# EPOCH:  34  LOSS:  tensor(57.0188, grad_fn=<AddBackward0>)
# EPOCH:  35  LOSS:  tensor(54.7602, grad_fn=<AddBackward0>)
# EPOCH:  36  LOSS:  tensor(52.4508, grad_fn=<AddBackward0>)
# EPOCH:  37  LOSS:  tensor(50.1723, grad_fn=<AddBackward0>)
# EPOCH:  38  LOSS:  tensor(47.9326, grad_fn=<AddBackward0>)
# EPOCH:  39  LOSS:  tensor(45.8302, grad_fn=<AddBackward0>)
# EPOCH:  40  LOSS:  tensor(43.8916, grad_fn=<AddBackward0>)
# EPOCH:  41  LOSS:  tensor(42.1304, grad_fn=<AddBackward0>)
# EPOCH:  42  LOSS:  tensor(40.4922, grad_fn=<AddBackward0>)
# EPOCH:  43  LOSS:  tensor(38.9468, grad_fn=<AddBackward0>)
# EPOCH:  44  LOSS:  tensor(37.4263, grad_fn=<AddBackward0>)
# EPOCH:  45  LOSS:  tensor(35.8883, grad_fn=<AddBackward0>)
# EPOCH:  46  LOSS:  tensor(34.3382, grad_fn=<AddBackward0>)
# EPOCH:  47  LOSS:  tensor(32.7819, grad_fn=<AddBackward0>)
# EPOCH:  48  LOSS:  tensor(31.2099, grad_fn=<AddBackward0>)
# EPOCH:  49  LOSS:  tensor(29.6245, grad_fn=<AddBackward0>)
# EPOCH:  50  LOSS:  tensor(28.0459, grad_fn=<AddBackward0>)
# EPOCH:  51  LOSS:  tensor(26.5058, grad_fn=<AddBackward0>)
# EPOCH:  52  LOSS:  tensor(25.0329, grad_fn=<AddBackward0>)
# EPOCH:  53  LOSS:  tensor(23.6294, grad_fn=<AddBackward0>)
# EPOCH:  54  LOSS:  tensor(22.2947, grad_fn=<AddBackward0>)
# EPOCH:  55  LOSS:  tensor(21.0525, grad_fn=<AddBackward0>)
# EPOCH:  56  LOSS:  tensor(19.8941, grad_fn=<AddBackward0>)
# EPOCH:  57  LOSS:  tensor(18.7970, grad_fn=<AddBackward0>)
# EPOCH:  58  LOSS:  tensor(17.7475, grad_fn=<AddBackward0>)
# EPOCH:  59  LOSS:  tensor(16.7227, grad_fn=<AddBackward0>)
# EPOCH:  60  LOSS:  tensor(15.7173, grad_fn=<AddBackward0>)
# EPOCH:  61  LOSS:  tensor(14.7534, grad_fn=<AddBackward0>)
# EPOCH:  62  LOSS:  tensor(13.8388, grad_fn=<AddBackward0>)
# EPOCH:  63  LOSS:  tensor(12.9709, grad_fn=<AddBackward0>)
# EPOCH:  64  LOSS:  tensor(12.1356, grad_fn=<AddBackward0>)
# EPOCH:  65  LOSS:  tensor(11.3470, grad_fn=<AddBackward0>)
# EPOCH:  66  LOSS:  tensor(10.6117, grad_fn=<AddBackward0>)
# EPOCH:  67  LOSS:  tensor(9.9318, grad_fn=<AddBackward0>)
# EPOCH:  68  LOSS:  tensor(9.3064, grad_fn=<AddBackward0>)
# EPOCH:  69  LOSS:  tensor(8.7294, grad_fn=<AddBackward0>)
# EPOCH:  70  LOSS:  tensor(8.1961, grad_fn=<AddBackward0>)
# EPOCH:  71  LOSS:  tensor(7.6963, grad_fn=<AddBackward0>)
# EPOCH:  72  LOSS:  tensor(7.2288, grad_fn=<AddBackward0>)
# EPOCH:  73  LOSS:  tensor(6.7959, grad_fn=<AddBackward0>)
# EPOCH:  74  LOSS:  tensor(6.3893, grad_fn=<AddBackward0>)
# EPOCH:  75  LOSS:  tensor(6.0235, grad_fn=<AddBackward0>)
# EPOCH:  76  LOSS:  tensor(5.6897, grad_fn=<AddBackward0>)
# EPOCH:  77  LOSS:  tensor(5.3851, grad_fn=<AddBackward0>)
# EPOCH:  78  LOSS:  tensor(5.1063, grad_fn=<AddBackward0>)
# EPOCH:  79  LOSS:  tensor(4.8490, grad_fn=<AddBackward0>)
# EPOCH:  80  LOSS:  tensor(4.6110, grad_fn=<AddBackward0>)
# EPOCH:  81  LOSS:  tensor(4.3935, grad_fn=<AddBackward0>)
# EPOCH:  82  LOSS:  tensor(4.1925, grad_fn=<AddBackward0>)
# EPOCH:  83  LOSS:  tensor(4.0068, grad_fn=<AddBackward0>)
# EPOCH:  84  LOSS:  tensor(3.8332, grad_fn=<AddBackward0>)
# EPOCH:  85  LOSS:  tensor(3.6739, grad_fn=<AddBackward0>)
# EPOCH:  86  LOSS:  tensor(3.5290, grad_fn=<AddBackward0>)
# EPOCH:  87  LOSS:  tensor(3.3946, grad_fn=<AddBackward0>)
# EPOCH:  88  LOSS:  tensor(3.2697, grad_fn=<AddBackward0>)
# EPOCH:  89  LOSS:  tensor(3.1524, grad_fn=<AddBackward0>)
# EPOCH:  90  LOSS:  tensor(3.0421, grad_fn=<AddBackward0>)
# EPOCH:  91  LOSS:  tensor(2.9395, grad_fn=<AddBackward0>)
# EPOCH:  92  LOSS:  tensor(2.8435, grad_fn=<AddBackward0>)
# EPOCH:  93  LOSS:  tensor(2.7546, grad_fn=<AddBackward0>)
# EPOCH:  94  LOSS:  tensor(2.6705, grad_fn=<AddBackward0>)
# EPOCH:  95  LOSS:  tensor(2.5907, grad_fn=<AddBackward0>)
# EPOCH:  96  LOSS:  tensor(2.5160, grad_fn=<AddBackward0>)
# EPOCH:  97  LOSS:  tensor(2.4447, grad_fn=<AddBackward0>)
# EPOCH:  98  LOSS:  tensor(2.3783, grad_fn=<AddBackward0>)
# EPOCH:  99  LOSS:  tensor(2.3153, grad_fn=<AddBackward0>)
# EPOCH:  100  LOSS:  tensor(2.2558, grad_fn=<AddBackward0>)
# EPOCH:  101  LOSS:  tensor(2.1990, grad_fn=<AddBackward0>)
# EPOCH:  102  LOSS:  tensor(2.1429, grad_fn=<AddBackward0>)
# EPOCH:  103  LOSS:  tensor(2.0895, grad_fn=<AddBackward0>)
# EPOCH:  104  LOSS:  tensor(2.0377, grad_fn=<AddBackward0>)
# EPOCH:  105  LOSS:  tensor(1.9858, grad_fn=<AddBackward0>)
# EPOCH:  106  LOSS:  tensor(1.9364, grad_fn=<AddBackward0>)
# EPOCH:  107  LOSS:  tensor(1.8898, grad_fn=<AddBackward0>)
# EPOCH:  108  LOSS:  tensor(1.8454, grad_fn=<AddBackward0>)
# EPOCH:  109  LOSS:  tensor(1.8023, grad_fn=<AddBackward0>)
# EPOCH:  110  LOSS:  tensor(1.7611, grad_fn=<AddBackward0>)
# EPOCH:  111  LOSS:  tensor(1.7227, grad_fn=<AddBackward0>)
# EPOCH:  112  LOSS:  tensor(1.6869, grad_fn=<AddBackward0>)
# EPOCH:  113  LOSS:  tensor(1.6527, grad_fn=<AddBackward0>)
# EPOCH:  114  LOSS:  tensor(1.6203, grad_fn=<AddBackward0>)
# EPOCH:  115  LOSS:  tensor(1.5891, grad_fn=<AddBackward0>)
# EPOCH:  116  LOSS:  tensor(1.5593, grad_fn=<AddBackward0>)
# EPOCH:  117  LOSS:  tensor(1.5307, grad_fn=<AddBackward0>)
# EPOCH:  118  LOSS:  tensor(1.5025, grad_fn=<AddBackward0>)
# EPOCH:  119  LOSS:  tensor(1.4755, grad_fn=<AddBackward0>)
# EPOCH:  120  LOSS:  tensor(1.4501, grad_fn=<AddBackward0>)
# EPOCH:  121  LOSS:  tensor(1.4263, grad_fn=<AddBackward0>)
# EPOCH:  122  LOSS:  tensor(1.4038, grad_fn=<AddBackward0>)
# EPOCH:  123  LOSS:  tensor(1.3814, grad_fn=<AddBackward0>)
# EPOCH:  124  LOSS:  tensor(1.3594, grad_fn=<AddBackward0>)
# EPOCH:  125  LOSS:  tensor(1.3386, grad_fn=<AddBackward0>)
# EPOCH:  126  LOSS:  tensor(1.3189, grad_fn=<AddBackward0>)
# EPOCH:  127  LOSS:  tensor(1.3001, grad_fn=<AddBackward0>)
# EPOCH:  128  LOSS:  tensor(1.2821, grad_fn=<AddBackward0>)
# EPOCH:  129  LOSS:  tensor(1.2648, grad_fn=<AddBackward0>)
# EPOCH:  130  LOSS:  tensor(1.2481, grad_fn=<AddBackward0>)
# EPOCH:  131  LOSS:  tensor(1.2324, grad_fn=<AddBackward0>)
# EPOCH:  132  LOSS:  tensor(1.2170, grad_fn=<AddBackward0>)
# EPOCH:  133  LOSS:  tensor(1.2032, grad_fn=<AddBackward0>)
# EPOCH:  134  LOSS:  tensor(1.1892, grad_fn=<AddBackward0>)
# EPOCH:  135  LOSS:  tensor(1.1752, grad_fn=<AddBackward0>)
# EPOCH:  136  LOSS:  tensor(1.1610, grad_fn=<AddBackward0>)
# EPOCH:  137  LOSS:  tensor(1.1481, grad_fn=<AddBackward0>)
# EPOCH:  138  LOSS:  tensor(1.1356, grad_fn=<AddBackward0>)
# EPOCH:  139  LOSS:  tensor(1.1234, grad_fn=<AddBackward0>)
# EPOCH:  140  LOSS:  tensor(1.1120, grad_fn=<AddBackward0>)
# EPOCH:  141  LOSS:  tensor(1.1007, grad_fn=<AddBackward0>)
# EPOCH:  142  LOSS:  tensor(1.0896, grad_fn=<AddBackward0>)
# EPOCH:  143  LOSS:  tensor(1.0787, grad_fn=<AddBackward0>)
# EPOCH:  144  LOSS:  tensor(1.0679, grad_fn=<AddBackward0>)
# EPOCH:  145  LOSS:  tensor(1.0577, grad_fn=<AddBackward0>)
# EPOCH:  146  LOSS:  tensor(1.0479, grad_fn=<AddBackward0>)
# EPOCH:  147  LOSS:  tensor(1.0384, grad_fn=<AddBackward0>)
# EPOCH:  148  LOSS:  tensor(1.0291, grad_fn=<AddBackward0>)
# EPOCH:  149  LOSS:  tensor(1.0198, grad_fn=<AddBackward0>)
# EPOCH:  150  LOSS:  tensor(1.0105, grad_fn=<AddBackward0>)
# EPOCH:  151  LOSS:  tensor(1.0014, grad_fn=<AddBackward0>)
# EPOCH:  152  LOSS:  tensor(0.9924, grad_fn=<AddBackward0>)
# EPOCH:  153  LOSS:  tensor(0.9839, grad_fn=<AddBackward0>)
# EPOCH:  154  LOSS:  tensor(0.9757, grad_fn=<AddBackward0>)
# EPOCH:  155  LOSS:  tensor(0.9681, grad_fn=<AddBackward0>)
# EPOCH:  156  LOSS:  tensor(0.9604, grad_fn=<AddBackward0>)
# EPOCH:  157  LOSS:  tensor(0.9532, grad_fn=<AddBackward0>)
# EPOCH:  158  LOSS:  tensor(0.9461, grad_fn=<AddBackward0>)
# EPOCH:  159  LOSS:  tensor(0.9390, grad_fn=<AddBackward0>)
# EPOCH:  160  LOSS:  tensor(0.9321, grad_fn=<AddBackward0>)
# EPOCH:  161  LOSS:  tensor(0.9251, grad_fn=<AddBackward0>)
# EPOCH:  162  LOSS:  tensor(0.9184, grad_fn=<AddBackward0>)
# EPOCH:  163  LOSS:  tensor(0.9119, grad_fn=<AddBackward0>)
# EPOCH:  164  LOSS:  tensor(0.9058, grad_fn=<AddBackward0>)
# EPOCH:  165  LOSS:  tensor(0.8998, grad_fn=<AddBackward0>)
# EPOCH:  166  LOSS:  tensor(0.8941, grad_fn=<AddBackward0>)
# EPOCH:  167  LOSS:  tensor(0.8885, grad_fn=<AddBackward0>)
# EPOCH:  168  LOSS:  tensor(0.8831, grad_fn=<AddBackward0>)
# EPOCH:  169  LOSS:  tensor(0.8776, grad_fn=<AddBackward0>)
# EPOCH:  170  LOSS:  tensor(0.8723, grad_fn=<AddBackward0>)
# EPOCH:  171  LOSS:  tensor(0.8666, grad_fn=<AddBackward0>)
# EPOCH:  172  LOSS:  tensor(0.8568, grad_fn=<AddBackward0>)
# EPOCH:  173  LOSS:  tensor(0.8463, grad_fn=<AddBackward0>)
# EPOCH:  174  LOSS:  tensor(0.8360, grad_fn=<AddBackward0>)
# EPOCH:  175  LOSS:  tensor(0.8267, grad_fn=<AddBackward0>)
# EPOCH:  176  LOSS:  tensor(0.8191, grad_fn=<AddBackward0>)
# EPOCH:  177  LOSS:  tensor(0.8129, grad_fn=<AddBackward0>)
# EPOCH:  178  LOSS:  tensor(0.8038, grad_fn=<AddBackward0>)
# EPOCH:  179  LOSS:  tensor(0.7961, grad_fn=<AddBackward0>)
# EPOCH:  180  LOSS:  tensor(0.7892, grad_fn=<AddBackward0>)
# EPOCH:  181  LOSS:  tensor(0.7821, grad_fn=<AddBackward0>)
# EPOCH:  182  LOSS:  tensor(0.7752, grad_fn=<AddBackward0>)
# EPOCH:  183  LOSS:  tensor(0.7690, grad_fn=<AddBackward0>)
# EPOCH:  184  LOSS:  tensor(0.7623, grad_fn=<AddBackward0>)
# EPOCH:  185  LOSS:  tensor(0.7552, grad_fn=<AddBackward0>)
# EPOCH:  186  LOSS:  tensor(0.7481, grad_fn=<AddBackward0>)
# EPOCH:  187  LOSS:  tensor(0.7411, grad_fn=<AddBackward0>)
# EPOCH:  188  LOSS:  tensor(0.7347, grad_fn=<AddBackward0>)
# EPOCH:  189  LOSS:  tensor(0.7298, grad_fn=<AddBackward0>)
# EPOCH:  190  LOSS:  tensor(0.7250, grad_fn=<AddBackward0>)
# EPOCH:  191  LOSS:  tensor(0.7198, grad_fn=<AddBackward0>)
# EPOCH:  192  LOSS:  tensor(0.7143, grad_fn=<AddBackward0>)
# EPOCH:  193  LOSS:  tensor(0.7091, grad_fn=<AddBackward0>)
# EPOCH:  194  LOSS:  tensor(0.7037, grad_fn=<AddBackward0>)
# EPOCH:  195  LOSS:  tensor(0.6983, grad_fn=<AddBackward0>)
# EPOCH:  196  LOSS:  tensor(0.6929, grad_fn=<AddBackward0>)
# EPOCH:  197  LOSS:  tensor(0.6874, grad_fn=<AddBackward0>)
# EPOCH:  198  LOSS:  tensor(0.6823, grad_fn=<AddBackward0>)
# EPOCH:  199  LOSS:  tensor(0.6774, grad_fn=<AddBackward0>)
# EPOCH:  200  LOSS:  tensor(0.6723, grad_fn=<AddBackward0>)
# EPOCH:  201  LOSS:  tensor(0.6676, grad_fn=<AddBackward0>)
# EPOCH:  202  LOSS:  tensor(0.6630, grad_fn=<AddBackward0>)
# EPOCH:  203  LOSS:  tensor(0.6583, grad_fn=<AddBackward0>)
# EPOCH:  204  LOSS:  tensor(0.6537, grad_fn=<AddBackward0>)
# EPOCH:  205  LOSS:  tensor(0.6491, grad_fn=<AddBackward0>)
# EPOCH:  206  LOSS:  tensor(0.6446, grad_fn=<AddBackward0>)
# EPOCH:  207  LOSS:  tensor(0.6403, grad_fn=<AddBackward0>)
# EPOCH:  208  LOSS:  tensor(0.6361, grad_fn=<AddBackward0>)
# EPOCH:  209  LOSS:  tensor(0.6320, grad_fn=<AddBackward0>)
# EPOCH:  210  LOSS:  tensor(0.6279, grad_fn=<AddBackward0>)
# EPOCH:  211  LOSS:  tensor(0.6238, grad_fn=<AddBackward0>)
# EPOCH:  212  LOSS:  tensor(0.6195, grad_fn=<AddBackward0>)
# EPOCH:  213  LOSS:  tensor(0.6155, grad_fn=<AddBackward0>)
# EPOCH:  214  LOSS:  tensor(0.6117, grad_fn=<AddBackward0>)
# EPOCH:  215  LOSS:  tensor(0.6077, grad_fn=<AddBackward0>)
# EPOCH:  216  LOSS:  tensor(0.6037, grad_fn=<AddBackward0>)
# EPOCH:  217  LOSS:  tensor(0.5999, grad_fn=<AddBackward0>)
# EPOCH:  218  LOSS:  tensor(0.5961, grad_fn=<AddBackward0>)
# EPOCH:  219  LOSS:  tensor(0.5923, grad_fn=<AddBackward0>)
# EPOCH:  220  LOSS:  tensor(0.5885, grad_fn=<AddBackward0>)
# EPOCH:  221  LOSS:  tensor(0.5848, grad_fn=<AddBackward0>)
# EPOCH:  222  LOSS:  tensor(0.5812, grad_fn=<AddBackward0>)
# EPOCH:  223  LOSS:  tensor(0.5776, grad_fn=<AddBackward0>)
# EPOCH:  224  LOSS:  tensor(0.5742, grad_fn=<AddBackward0>)
# EPOCH:  225  LOSS:  tensor(0.5708, grad_fn=<AddBackward0>)
# EPOCH:  226  LOSS:  tensor(0.5673, grad_fn=<AddBackward0>)
# EPOCH:  227  LOSS:  tensor(0.5640, grad_fn=<AddBackward0>)
# EPOCH:  228  LOSS:  tensor(0.5604, grad_fn=<AddBackward0>)
# EPOCH:  229  LOSS:  tensor(0.5571, grad_fn=<AddBackward0>)
# EPOCH:  230  LOSS:  tensor(0.5537, grad_fn=<AddBackward0>)
# EPOCH:  231  LOSS:  tensor(0.5503, grad_fn=<AddBackward0>)
# EPOCH:  232  LOSS:  tensor(0.5471, grad_fn=<AddBackward0>)
# EPOCH:  233  LOSS:  tensor(0.5438, grad_fn=<AddBackward0>)
# EPOCH:  234  LOSS:  tensor(0.5406, grad_fn=<AddBackward0>)
# EPOCH:  235  LOSS:  tensor(0.5374, grad_fn=<AddBackward0>)
# EPOCH:  236  LOSS:  tensor(0.5345, grad_fn=<AddBackward0>)
# EPOCH:  237  LOSS:  tensor(0.5314, grad_fn=<AddBackward0>)
# EPOCH:  238  LOSS:  tensor(0.5284, grad_fn=<AddBackward0>)
# EPOCH:  239  LOSS:  tensor(0.5255, grad_fn=<AddBackward0>)
# EPOCH:  240  LOSS:  tensor(0.5226, grad_fn=<AddBackward0>)
# EPOCH:  241  LOSS:  tensor(0.5197, grad_fn=<AddBackward0>)
# EPOCH:  242  LOSS:  tensor(0.5171, grad_fn=<AddBackward0>)
# EPOCH:  243  LOSS:  tensor(0.5144, grad_fn=<AddBackward0>)
# EPOCH:  244  LOSS:  tensor(0.5115, grad_fn=<AddBackward0>)
# EPOCH:  245  LOSS:  tensor(0.5089, grad_fn=<AddBackward0>)
# EPOCH:  246  LOSS:  tensor(0.5061, grad_fn=<AddBackward0>)
# EPOCH:  247  LOSS:  tensor(0.5036, grad_fn=<AddBackward0>)
# EPOCH:  248  LOSS:  tensor(0.5009, grad_fn=<AddBackward0>)
# EPOCH:  249  LOSS:  tensor(0.4980, grad_fn=<AddBackward0>)
# EPOCH:  250  LOSS:  tensor(0.4952, grad_fn=<AddBackward0>)
# EPOCH:  251  LOSS:  tensor(0.4924, grad_fn=<AddBackward0>)
# EPOCH:  252  LOSS:  tensor(0.4893, grad_fn=<AddBackward0>)
# EPOCH:  253  LOSS:  tensor(0.4858, grad_fn=<AddBackward0>)
# EPOCH:  254  LOSS:  tensor(0.4821, grad_fn=<AddBackward0>)
# EPOCH:  255  LOSS:  tensor(0.4784, grad_fn=<AddBackward0>)
# EPOCH:  256  LOSS:  tensor(0.4747, grad_fn=<AddBackward0>)
# EPOCH:  257  LOSS:  tensor(0.4711, grad_fn=<AddBackward0>)
# EPOCH:  258  LOSS:  tensor(0.4674, grad_fn=<AddBackward0>)
# EPOCH:  259  LOSS:  tensor(0.4639, grad_fn=<AddBackward0>)
# EPOCH:  260  LOSS:  tensor(0.4605, grad_fn=<AddBackward0>)
# EPOCH:  261  LOSS:  tensor(0.4571, grad_fn=<AddBackward0>)
# EPOCH:  262  LOSS:  tensor(0.4538, grad_fn=<AddBackward0>)
# EPOCH:  263  LOSS:  tensor(0.4507, grad_fn=<AddBackward0>)
# EPOCH:  264  LOSS:  tensor(0.4477, grad_fn=<AddBackward0>)
# EPOCH:  265  LOSS:  tensor(0.4447, grad_fn=<AddBackward0>)
# EPOCH:  266  LOSS:  tensor(0.4419, grad_fn=<AddBackward0>)
# EPOCH:  267  LOSS:  tensor(0.4393, grad_fn=<AddBackward0>)
# EPOCH:  268  LOSS:  tensor(0.4369, grad_fn=<AddBackward0>)
# EPOCH:  269  LOSS:  tensor(0.4344, grad_fn=<AddBackward0>)
# EPOCH:  270  LOSS:  tensor(0.4321, grad_fn=<AddBackward0>)
# EPOCH:  271  LOSS:  tensor(0.4298, grad_fn=<AddBackward0>)
# EPOCH:  272  LOSS:  tensor(0.4277, grad_fn=<AddBackward0>)
# EPOCH:  273  LOSS:  tensor(0.4255, grad_fn=<AddBackward0>)
# EPOCH:  274  LOSS:  tensor(0.4233, grad_fn=<AddBackward0>)
# EPOCH:  275  LOSS:  tensor(0.4212, grad_fn=<AddBackward0>)
# EPOCH:  276  LOSS:  tensor(0.4193, grad_fn=<AddBackward0>)
# EPOCH:  277  LOSS:  tensor(0.4173, grad_fn=<AddBackward0>)
# EPOCH:  278  LOSS:  tensor(0.4154, grad_fn=<AddBackward0>)
# EPOCH:  279  LOSS:  tensor(0.4136, grad_fn=<AddBackward0>)
# EPOCH:  280  LOSS:  tensor(0.4118, grad_fn=<AddBackward0>)
# EPOCH:  281  LOSS:  tensor(0.4101, grad_fn=<AddBackward0>)
# EPOCH:  282  LOSS:  tensor(0.4083, grad_fn=<AddBackward0>)
# EPOCH:  283  LOSS:  tensor(0.4067, grad_fn=<AddBackward0>)
# EPOCH:  284  LOSS:  tensor(0.4050, grad_fn=<AddBackward0>)
# EPOCH:  285  LOSS:  tensor(0.4032, grad_fn=<AddBackward0>)
# EPOCH:  286  LOSS:  tensor(0.4013, grad_fn=<AddBackward0>)
# EPOCH:  287  LOSS:  tensor(0.3996, grad_fn=<AddBackward0>)
# EPOCH:  288  LOSS:  tensor(0.3979, grad_fn=<AddBackward0>)
# EPOCH:  289  LOSS:  tensor(0.3961, grad_fn=<AddBackward0>)
# EPOCH:  290  LOSS:  tensor(0.3944, grad_fn=<AddBackward0>)
# EPOCH:  291  LOSS:  tensor(0.3929, grad_fn=<AddBackward0>)
# EPOCH:  292  LOSS:  tensor(0.3913, grad_fn=<AddBackward0>)
# EPOCH:  293  LOSS:  tensor(0.3897, grad_fn=<AddBackward0>)
# EPOCH:  294  LOSS:  tensor(0.3881, grad_fn=<AddBackward0>)
# EPOCH:  295  LOSS:  tensor(0.3864, grad_fn=<AddBackward0>)
# EPOCH:  296  LOSS:  tensor(0.3848, grad_fn=<AddBackward0>)
# EPOCH:  297  LOSS:  tensor(0.3832, grad_fn=<AddBackward0>)
# EPOCH:  298  LOSS:  tensor(0.3816, grad_fn=<AddBackward0>)
# EPOCH:  299  LOSS:  tensor(0.3801, grad_fn=<AddBackward0>)
# EPOCH:  300  LOSS:  tensor(0.3785, grad_fn=<AddBackward0>)
# EPOCH:  301  LOSS:  tensor(0.3771, grad_fn=<AddBackward0>)
# EPOCH:  302  LOSS:  tensor(0.3756, grad_fn=<AddBackward0>)
# EPOCH:  303  LOSS:  tensor(0.3741, grad_fn=<AddBackward0>)
# EPOCH:  304  LOSS:  tensor(0.3727, grad_fn=<AddBackward0>)
# EPOCH:  305  LOSS:  tensor(0.3712, grad_fn=<AddBackward0>)
# EPOCH:  306  LOSS:  tensor(0.3698, grad_fn=<AddBackward0>)
# EPOCH:  307  LOSS:  tensor(0.3684, grad_fn=<AddBackward0>)
# EPOCH:  308  LOSS:  tensor(0.3669, grad_fn=<AddBackward0>)
# EPOCH:  309  LOSS:  tensor(0.3644, grad_fn=<AddBackward0>)
# EPOCH:  310  LOSS:  tensor(0.3616, grad_fn=<AddBackward0>)
# EPOCH:  311  LOSS:  tensor(0.3584, grad_fn=<AddBackward0>)
# EPOCH:  312  LOSS:  tensor(0.3556, grad_fn=<AddBackward0>)
# EPOCH:  313  LOSS:  tensor(0.3536, grad_fn=<AddBackward0>)
# EPOCH:  314  LOSS:  tensor(0.3521, grad_fn=<AddBackward0>)
# EPOCH:  315  LOSS:  tensor(0.3505, grad_fn=<AddBackward0>)
# EPOCH:  316  LOSS:  tensor(0.3488, grad_fn=<AddBackward0>)
# EPOCH:  317  LOSS:  tensor(0.3471, grad_fn=<AddBackward0>)
# EPOCH:  318  LOSS:  tensor(0.3452, grad_fn=<AddBackward0>)
# EPOCH:  319  LOSS:  tensor(0.3433, grad_fn=<AddBackward0>)
# EPOCH:  320  LOSS:  tensor(0.3416, grad_fn=<AddBackward0>)
# EPOCH:  321  LOSS:  tensor(0.3400, grad_fn=<AddBackward0>)
# EPOCH:  322  LOSS:  tensor(0.3386, grad_fn=<AddBackward0>)
# EPOCH:  323  LOSS:  tensor(0.3373, grad_fn=<AddBackward0>)
# EPOCH:  324  LOSS:  tensor(0.3358, grad_fn=<AddBackward0>)
# EPOCH:  325  LOSS:  tensor(0.3344, grad_fn=<AddBackward0>)
# EPOCH:  326  LOSS:  tensor(0.3330, grad_fn=<AddBackward0>)
# EPOCH:  327  LOSS:  tensor(0.3314, grad_fn=<AddBackward0>)
# EPOCH:  328  LOSS:  tensor(0.3299, grad_fn=<AddBackward0>)
# EPOCH:  329  LOSS:  tensor(0.3284, grad_fn=<AddBackward0>)
# EPOCH:  330  LOSS:  tensor(0.3270, grad_fn=<AddBackward0>)
# EPOCH:  331  LOSS:  tensor(0.3256, grad_fn=<AddBackward0>)
# EPOCH:  332  LOSS:  tensor(0.3241, grad_fn=<AddBackward0>)
# EPOCH:  333  LOSS:  tensor(0.3227, grad_fn=<AddBackward0>)
# EPOCH:  334  LOSS:  tensor(0.3212, grad_fn=<AddBackward0>)
# EPOCH:  335  LOSS:  tensor(0.3199, grad_fn=<AddBackward0>)
# EPOCH:  336  LOSS:  tensor(0.3185, grad_fn=<AddBackward0>)
# EPOCH:  337  LOSS:  tensor(0.3171, grad_fn=<AddBackward0>)
# EPOCH:  338  LOSS:  tensor(0.3158, grad_fn=<AddBackward0>)
# EPOCH:  339  LOSS:  tensor(0.3145, grad_fn=<AddBackward0>)
# EPOCH:  340  LOSS:  tensor(0.3133, grad_fn=<AddBackward0>)
# EPOCH:  341  LOSS:  tensor(0.3121, grad_fn=<AddBackward0>)
# EPOCH:  342  LOSS:  tensor(0.3109, grad_fn=<AddBackward0>)
# EPOCH:  343  LOSS:  tensor(0.3097, grad_fn=<AddBackward0>)
# EPOCH:  344  LOSS:  tensor(0.3085, grad_fn=<AddBackward0>)
# EPOCH:  345  LOSS:  tensor(0.3074, grad_fn=<AddBackward0>)
# EPOCH:  346  LOSS:  tensor(0.3063, grad_fn=<AddBackward0>)
# EPOCH:  347  LOSS:  tensor(0.3052, grad_fn=<AddBackward0>)
# EPOCH:  348  LOSS:  tensor(0.3040, grad_fn=<AddBackward0>)
# EPOCH:  349  LOSS:  tensor(0.3029, grad_fn=<AddBackward0>)
# EPOCH:  350  LOSS:  tensor(0.3018, grad_fn=<AddBackward0>)
# EPOCH:  351  LOSS:  tensor(0.3007, grad_fn=<AddBackward0>)
# EPOCH:  352  LOSS:  tensor(0.2997, grad_fn=<AddBackward0>)
# EPOCH:  353  LOSS:  tensor(0.2985, grad_fn=<AddBackward0>)
# EPOCH:  354  LOSS:  tensor(0.2973, grad_fn=<AddBackward0>)
# EPOCH:  355  LOSS:  tensor(0.2961, grad_fn=<AddBackward0>)
# EPOCH:  356  LOSS:  tensor(0.2949, grad_fn=<AddBackward0>)
# EPOCH:  357  LOSS:  tensor(0.2938, grad_fn=<AddBackward0>)
# EPOCH:  358  LOSS:  tensor(0.2928, grad_fn=<AddBackward0>)
# EPOCH:  359  LOSS:  tensor(0.2916, grad_fn=<AddBackward0>)
# EPOCH:  360  LOSS:  tensor(0.2904, grad_fn=<AddBackward0>)
# EPOCH:  361  LOSS:  tensor(0.2892, grad_fn=<AddBackward0>)
# EPOCH:  362  LOSS:  tensor(0.2881, grad_fn=<AddBackward0>)
# EPOCH:  363  LOSS:  tensor(0.2870, grad_fn=<AddBackward0>)
# EPOCH:  364  LOSS:  tensor(0.2859, grad_fn=<AddBackward0>)
# EPOCH:  365  LOSS:  tensor(0.2848, grad_fn=<AddBackward0>)
# EPOCH:  366  LOSS:  tensor(0.2836, grad_fn=<AddBackward0>)
# EPOCH:  367  LOSS:  tensor(0.2824, grad_fn=<AddBackward0>)
# EPOCH:  368  LOSS:  tensor(0.2812, grad_fn=<AddBackward0>)
# EPOCH:  369  LOSS:  tensor(0.2802, grad_fn=<AddBackward0>)
# EPOCH:  370  LOSS:  tensor(0.2791, grad_fn=<AddBackward0>)
# EPOCH:  371  LOSS:  tensor(0.2779, grad_fn=<AddBackward0>)
# EPOCH:  372  LOSS:  tensor(0.2767, grad_fn=<AddBackward0>)
# EPOCH:  373  LOSS:  tensor(0.2756, grad_fn=<AddBackward0>)
# EPOCH:  374  LOSS:  tensor(0.2745, grad_fn=<AddBackward0>)
# EPOCH:  375  LOSS:  tensor(0.2734, grad_fn=<AddBackward0>)
# EPOCH:  376  LOSS:  tensor(0.2722, grad_fn=<AddBackward0>)
# EPOCH:  377  LOSS:  tensor(0.2711, grad_fn=<AddBackward0>)
# EPOCH:  378  LOSS:  tensor(0.2700, grad_fn=<AddBackward0>)
# EPOCH:  379  LOSS:  tensor(0.2690, grad_fn=<AddBackward0>)
# EPOCH:  380  LOSS:  tensor(0.2680, grad_fn=<AddBackward0>)
# EPOCH:  381  LOSS:  tensor(0.2670, grad_fn=<AddBackward0>)
# EPOCH:  382  LOSS:  tensor(0.2660, grad_fn=<AddBackward0>)
# EPOCH:  383  LOSS:  tensor(0.2650, grad_fn=<AddBackward0>)
# EPOCH:  384  LOSS:  tensor(0.2641, grad_fn=<AddBackward0>)
# EPOCH:  385  LOSS:  tensor(0.2631, grad_fn=<AddBackward0>)
# EPOCH:  386  LOSS:  tensor(0.2622, grad_fn=<AddBackward0>)
# EPOCH:  387  LOSS:  tensor(0.2613, grad_fn=<AddBackward0>)
# EPOCH:  388  LOSS:  tensor(0.2604, grad_fn=<AddBackward0>)
# EPOCH:  389  LOSS:  tensor(0.2594, grad_fn=<AddBackward0>)
# EPOCH:  390  LOSS:  tensor(0.2585, grad_fn=<AddBackward0>)
# EPOCH:  391  LOSS:  tensor(0.2576, grad_fn=<AddBackward0>)
# EPOCH:  392  LOSS:  tensor(0.2567, grad_fn=<AddBackward0>)
# EPOCH:  393  LOSS:  tensor(0.2558, grad_fn=<AddBackward0>)
# EPOCH:  394  LOSS:  tensor(0.2549, grad_fn=<AddBackward0>)
# EPOCH:  395  LOSS:  tensor(0.2540, grad_fn=<AddBackward0>)
# EPOCH:  396  LOSS:  tensor(0.2531, grad_fn=<AddBackward0>)
# EPOCH:  397  LOSS:  tensor(0.2522, grad_fn=<AddBackward0>)
# EPOCH:  398  LOSS:  tensor(0.2512, grad_fn=<AddBackward0>)
# EPOCH:  399  LOSS:  tensor(0.2503, grad_fn=<AddBackward0>)
# EPOCH:  400  LOSS:  tensor(0.2493, grad_fn=<AddBackward0>)
# EPOCH:  401  LOSS:  tensor(0.2484, grad_fn=<AddBackward0>)
# EPOCH:  402  LOSS:  tensor(0.2474, grad_fn=<AddBackward0>)
# EPOCH:  403  LOSS:  tensor(0.2464, grad_fn=<AddBackward0>)
# EPOCH:  404  LOSS:  tensor(0.2455, grad_fn=<AddBackward0>)
# EPOCH:  405  LOSS:  tensor(0.2445, grad_fn=<AddBackward0>)
# EPOCH:  406  LOSS:  tensor(0.2437, grad_fn=<AddBackward0>)
# EPOCH:  407  LOSS:  tensor(0.2428, grad_fn=<AddBackward0>)
# EPOCH:  408  LOSS:  tensor(0.2419, grad_fn=<AddBackward0>)
# EPOCH:  409  LOSS:  tensor(0.2411, grad_fn=<AddBackward0>)
# EPOCH:  410  LOSS:  tensor(0.2402, grad_fn=<AddBackward0>)
# EPOCH:  411  LOSS:  tensor(0.2394, grad_fn=<AddBackward0>)
# EPOCH:  412  LOSS:  tensor(0.2385, grad_fn=<AddBackward0>)
# EPOCH:  413  LOSS:  tensor(0.2377, grad_fn=<AddBackward0>)
# EPOCH:  414  LOSS:  tensor(0.2368, grad_fn=<AddBackward0>)
# EPOCH:  415  LOSS:  tensor(0.2360, grad_fn=<AddBackward0>)
# EPOCH:  416  LOSS:  tensor(0.2352, grad_fn=<AddBackward0>)
# EPOCH:  417  LOSS:  tensor(0.2344, grad_fn=<AddBackward0>)
# EPOCH:  418  LOSS:  tensor(0.2336, grad_fn=<AddBackward0>)
# EPOCH:  419  LOSS:  tensor(0.2328, grad_fn=<AddBackward0>)
# EPOCH:  420  LOSS:  tensor(0.2320, grad_fn=<AddBackward0>)
# EPOCH:  421  LOSS:  tensor(0.2313, grad_fn=<AddBackward0>)
# EPOCH:  422  LOSS:  tensor(0.2304, grad_fn=<AddBackward0>)
# EPOCH:  423  LOSS:  tensor(0.2297, grad_fn=<AddBackward0>)
# EPOCH:  424  LOSS:  tensor(0.2288, grad_fn=<AddBackward0>)
# EPOCH:  425  LOSS:  tensor(0.2280, grad_fn=<AddBackward0>)
# EPOCH:  426  LOSS:  tensor(0.2273, grad_fn=<AddBackward0>)
# EPOCH:  427  LOSS:  tensor(0.2265, grad_fn=<AddBackward0>)
# EPOCH:  428  LOSS:  tensor(0.2257, grad_fn=<AddBackward0>)
# EPOCH:  429  LOSS:  tensor(0.2249, grad_fn=<AddBackward0>)
# EPOCH:  430  LOSS:  tensor(0.2242, grad_fn=<AddBackward0>)
# EPOCH:  431  LOSS:  tensor(0.2234, grad_fn=<AddBackward0>)
# EPOCH:  432  LOSS:  tensor(0.2227, grad_fn=<AddBackward0>)
# EPOCH:  433  LOSS:  tensor(0.2219, grad_fn=<AddBackward0>)
# EPOCH:  434  LOSS:  tensor(0.2212, grad_fn=<AddBackward0>)
# EPOCH:  435  LOSS:  tensor(0.2205, grad_fn=<AddBackward0>)
# EPOCH:  436  LOSS:  tensor(0.2198, grad_fn=<AddBackward0>)
# EPOCH:  437  LOSS:  tensor(0.2190, grad_fn=<AddBackward0>)
# EPOCH:  438  LOSS:  tensor(0.2183, grad_fn=<AddBackward0>)
# EPOCH:  439  LOSS:  tensor(0.2175, grad_fn=<AddBackward0>)
# EPOCH:  440  LOSS:  tensor(0.2169, grad_fn=<AddBackward0>)
# EPOCH:  441  LOSS:  tensor(0.2161, grad_fn=<AddBackward0>)
# EPOCH:  442  LOSS:  tensor(0.2154, grad_fn=<AddBackward0>)
# EPOCH:  443  LOSS:  tensor(0.2147, grad_fn=<AddBackward0>)
# EPOCH:  444  LOSS:  tensor(0.2140, grad_fn=<AddBackward0>)
# EPOCH:  445  LOSS:  tensor(0.2134, grad_fn=<AddBackward0>)
# EPOCH:  446  LOSS:  tensor(0.2128, grad_fn=<AddBackward0>)
# EPOCH:  447  LOSS:  tensor(0.2121, grad_fn=<AddBackward0>)
# EPOCH:  448  LOSS:  tensor(0.2115, grad_fn=<AddBackward0>)
# EPOCH:  449  LOSS:  tensor(0.2108, grad_fn=<AddBackward0>)
# EPOCH:  450  LOSS:  tensor(0.2101, grad_fn=<AddBackward0>)
# EPOCH:  451  LOSS:  tensor(0.2095, grad_fn=<AddBackward0>)
# EPOCH:  452  LOSS:  tensor(0.2088, grad_fn=<AddBackward0>)
# EPOCH:  453  LOSS:  tensor(0.2082, grad_fn=<AddBackward0>)
# EPOCH:  454  LOSS:  tensor(0.2075, grad_fn=<AddBackward0>)
# EPOCH:  455  LOSS:  tensor(0.2068, grad_fn=<AddBackward0>)
# EPOCH:  456  LOSS:  tensor(0.2062, grad_fn=<AddBackward0>)
# EPOCH:  457  LOSS:  tensor(0.2055, grad_fn=<AddBackward0>)
# EPOCH:  458  LOSS:  tensor(0.2048, grad_fn=<AddBackward0>)
# EPOCH:  459  LOSS:  tensor(0.2042, grad_fn=<AddBackward0>)
# EPOCH:  460  LOSS:  tensor(0.2035, grad_fn=<AddBackward0>)
# EPOCH:  461  LOSS:  tensor(0.2028, grad_fn=<AddBackward0>)
# EPOCH:  462  LOSS:  tensor(0.2020, grad_fn=<AddBackward0>)
# EPOCH:  463  LOSS:  tensor(0.2012, grad_fn=<AddBackward0>)
# EPOCH:  464  LOSS:  tensor(0.2004, grad_fn=<AddBackward0>)
# EPOCH:  465  LOSS:  tensor(0.1996, grad_fn=<AddBackward0>)
# EPOCH:  466  LOSS:  tensor(0.1989, grad_fn=<AddBackward0>)
# EPOCH:  467  LOSS:  tensor(0.1983, grad_fn=<AddBackward0>)
# EPOCH:  468  LOSS:  tensor(0.1976, grad_fn=<AddBackward0>)
# EPOCH:  469  LOSS:  tensor(0.1970, grad_fn=<AddBackward0>)
# EPOCH:  470  LOSS:  tensor(0.1963, grad_fn=<AddBackward0>)
# EPOCH:  471  LOSS:  tensor(0.1957, grad_fn=<AddBackward0>)
# EPOCH:  472  LOSS:  tensor(0.1951, grad_fn=<AddBackward0>)
# EPOCH:  473  LOSS:  tensor(0.1945, grad_fn=<AddBackward0>)
# EPOCH:  474  LOSS:  tensor(0.1939, grad_fn=<AddBackward0>)
# EPOCH:  475  LOSS:  tensor(0.1933, grad_fn=<AddBackward0>)
# EPOCH:  476  LOSS:  tensor(0.1928, grad_fn=<AddBackward0>)
# EPOCH:  477  LOSS:  tensor(0.1922, grad_fn=<AddBackward0>)
# EPOCH:  478  LOSS:  tensor(0.1917, grad_fn=<AddBackward0>)
# EPOCH:  479  LOSS:  tensor(0.1911, grad_fn=<AddBackward0>)
# EPOCH:  480  LOSS:  tensor(0.1906, grad_fn=<AddBackward0>)
# EPOCH:  481  LOSS:  tensor(0.1901, grad_fn=<AddBackward0>)
# EPOCH:  482  LOSS:  tensor(0.1896, grad_fn=<AddBackward0>)
# EPOCH:  483  LOSS:  tensor(0.1891, grad_fn=<AddBackward0>)
# EPOCH:  484  LOSS:  tensor(0.1886, grad_fn=<AddBackward0>)
# EPOCH:  485  LOSS:  tensor(0.1881, grad_fn=<AddBackward0>)
# EPOCH:  486  LOSS:  tensor(0.1876, grad_fn=<AddBackward0>)
# EPOCH:  487  LOSS:  tensor(0.1871, grad_fn=<AddBackward0>)
# EPOCH:  488  LOSS:  tensor(0.1866, grad_fn=<AddBackward0>)
# EPOCH:  489  LOSS:  tensor(0.1862, grad_fn=<AddBackward0>)
# EPOCH:  490  LOSS:  tensor(0.1857, grad_fn=<AddBackward0>)
# EPOCH:  491  LOSS:  tensor(0.1853, grad_fn=<AddBackward0>)
# EPOCH:  492  LOSS:  tensor(0.1848, grad_fn=<AddBackward0>)
# EPOCH:  493  LOSS:  tensor(0.1844, grad_fn=<AddBackward0>)
# EPOCH:  494  LOSS:  tensor(0.1840, grad_fn=<AddBackward0>)
# EPOCH:  495  LOSS:  tensor(0.1835, grad_fn=<AddBackward0>)
# EPOCH:  496  LOSS:  tensor(0.1831, grad_fn=<AddBackward0>)
# EPOCH:  497  LOSS:  tensor(0.1827, grad_fn=<AddBackward0>)
# EPOCH:  498  LOSS:  tensor(0.1823, grad_fn=<AddBackward0>)
# EPOCH:  499  LOSS:  tensor(0.1819, grad_fn=<AddBackward0>)
# EPOCH:  500  LOSS:  tensor(0.1815, grad_fn=<AddBackward0>)
# EPOCH:  501  LOSS:  tensor(0.1811, grad_fn=<AddBackward0>)
# EPOCH:  502  LOSS:  tensor(0.1807, grad_fn=<AddBackward0>)
# EPOCH:  503  LOSS:  tensor(0.1803, grad_fn=<AddBackward0>)
# EPOCH:  504  LOSS:  tensor(0.1799, grad_fn=<AddBackward0>)
# EPOCH:  505  LOSS:  tensor(0.1795, grad_fn=<AddBackward0>)
# EPOCH:  506  LOSS:  tensor(0.1792, grad_fn=<AddBackward0>)
# EPOCH:  507  LOSS:  tensor(0.1788, grad_fn=<AddBackward0>)
# EPOCH:  508  LOSS:  tensor(0.1784, grad_fn=<AddBackward0>)
# EPOCH:  509  LOSS:  tensor(0.1781, grad_fn=<AddBackward0>)
# EPOCH:  510  LOSS:  tensor(0.1777, grad_fn=<AddBackward0>)
# EPOCH:  511  LOSS:  tensor(0.1774, grad_fn=<AddBackward0>)
# EPOCH:  512  LOSS:  tensor(0.1770, grad_fn=<AddBackward0>)
# EPOCH:  513  LOSS:  tensor(0.1767, grad_fn=<AddBackward0>)
# EPOCH:  514  LOSS:  tensor(0.1763, grad_fn=<AddBackward0>)
# EPOCH:  515  LOSS:  tensor(0.1760, grad_fn=<AddBackward0>)
# EPOCH:  516  LOSS:  tensor(0.1756, grad_fn=<AddBackward0>)
# EPOCH:  517  LOSS:  tensor(0.1753, grad_fn=<AddBackward0>)
# EPOCH:  518  LOSS:  tensor(0.1749, grad_fn=<AddBackward0>)
# EPOCH:  519  LOSS:  tensor(0.1746, grad_fn=<AddBackward0>)
# EPOCH:  520  LOSS:  tensor(0.1742, grad_fn=<AddBackward0>)
# EPOCH:  521  LOSS:  tensor(0.1738, grad_fn=<AddBackward0>)
# EPOCH:  522  LOSS:  tensor(0.1733, grad_fn=<AddBackward0>)
# EPOCH:  523  LOSS:  tensor(0.1729, grad_fn=<AddBackward0>)
# EPOCH:  524  LOSS:  tensor(0.1725, grad_fn=<AddBackward0>)
# EPOCH:  525  LOSS:  tensor(0.1721, grad_fn=<AddBackward0>)
# EPOCH:  526  LOSS:  tensor(0.1717, grad_fn=<AddBackward0>)
# EPOCH:  527  LOSS:  tensor(0.1713, grad_fn=<AddBackward0>)
# EPOCH:  528  LOSS:  tensor(0.1708, grad_fn=<AddBackward0>)
# EPOCH:  529  LOSS:  tensor(0.1704, grad_fn=<AddBackward0>)
# EPOCH:  530  LOSS:  tensor(0.1700, grad_fn=<AddBackward0>)
# EPOCH:  531  LOSS:  tensor(0.1696, grad_fn=<AddBackward0>)
# EPOCH:  532  LOSS:  tensor(0.1692, grad_fn=<AddBackward0>)
# EPOCH:  533  LOSS:  tensor(0.1688, grad_fn=<AddBackward0>)
# EPOCH:  534  LOSS:  tensor(0.1684, grad_fn=<AddBackward0>)
# EPOCH:  535  LOSS:  tensor(0.1680, grad_fn=<AddBackward0>)
# EPOCH:  536  LOSS:  tensor(0.1676, grad_fn=<AddBackward0>)
# EPOCH:  537  LOSS:  tensor(0.1672, grad_fn=<AddBackward0>)
# EPOCH:  538  LOSS:  tensor(0.1668, grad_fn=<AddBackward0>)
# EPOCH:  539  LOSS:  tensor(0.1664, grad_fn=<AddBackward0>)
# EPOCH:  540  LOSS:  tensor(0.1659, grad_fn=<AddBackward0>)
# EPOCH:  541  LOSS:  tensor(0.1655, grad_fn=<AddBackward0>)
# EPOCH:  542  LOSS:  tensor(0.1651, grad_fn=<AddBackward0>)
# EPOCH:  543  LOSS:  tensor(0.1647, grad_fn=<AddBackward0>)
# EPOCH:  544  LOSS:  tensor(0.1643, grad_fn=<AddBackward0>)
# EPOCH:  545  LOSS:  tensor(0.1639, grad_fn=<AddBackward0>)
# EPOCH:  546  LOSS:  tensor(0.1635, grad_fn=<AddBackward0>)
# EPOCH:  547  LOSS:  tensor(0.1631, grad_fn=<AddBackward0>)
# EPOCH:  548  LOSS:  tensor(0.1627, grad_fn=<AddBackward0>)
# EPOCH:  549  LOSS:  tensor(0.1623, grad_fn=<AddBackward0>)
# EPOCH:  550  LOSS:  tensor(0.1619, grad_fn=<AddBackward0>)
# EPOCH:  551  LOSS:  tensor(0.1615, grad_fn=<AddBackward0>)
# EPOCH:  552  LOSS:  tensor(0.1612, grad_fn=<AddBackward0>)
# EPOCH:  553  LOSS:  tensor(0.1607, grad_fn=<AddBackward0>)
# EPOCH:  554  LOSS:  tensor(0.1603, grad_fn=<AddBackward0>)
# EPOCH:  555  LOSS:  tensor(0.1599, grad_fn=<AddBackward0>)
# EPOCH:  556  LOSS:  tensor(0.1595, grad_fn=<AddBackward0>)
# EPOCH:  557  LOSS:  tensor(0.1591, grad_fn=<AddBackward0>)
# EPOCH:  558  LOSS:  tensor(0.1587, grad_fn=<AddBackward0>)
# EPOCH:  559  LOSS:  tensor(0.1583, grad_fn=<AddBackward0>)
# EPOCH:  560  LOSS:  tensor(0.1579, grad_fn=<AddBackward0>)
# EPOCH:  561  LOSS:  tensor(0.1575, grad_fn=<AddBackward0>)
# EPOCH:  562  LOSS:  tensor(0.1570, grad_fn=<AddBackward0>)
# EPOCH:  563  LOSS:  tensor(0.1567, grad_fn=<AddBackward0>)
# EPOCH:  564  LOSS:  tensor(0.1563, grad_fn=<AddBackward0>)
# EPOCH:  565  LOSS:  tensor(0.1559, grad_fn=<AddBackward0>)
# EPOCH:  566  LOSS:  tensor(0.1555, grad_fn=<AddBackward0>)
# EPOCH:  567  LOSS:  tensor(0.1551, grad_fn=<AddBackward0>)
# EPOCH:  568  LOSS:  tensor(0.1547, grad_fn=<AddBackward0>)
# EPOCH:  569  LOSS:  tensor(0.1543, grad_fn=<AddBackward0>)
# EPOCH:  570  LOSS:  tensor(0.1540, grad_fn=<AddBackward0>)
# EPOCH:  571  LOSS:  tensor(0.1536, grad_fn=<AddBackward0>)
# EPOCH:  572  LOSS:  tensor(0.1532, grad_fn=<AddBackward0>)
# EPOCH:  573  LOSS:  tensor(0.1529, grad_fn=<AddBackward0>)
# EPOCH:  574  LOSS:  tensor(0.1526, grad_fn=<AddBackward0>)
# EPOCH:  575  LOSS:  tensor(0.1522, grad_fn=<AddBackward0>)
# EPOCH:  576  LOSS:  tensor(0.1519, grad_fn=<AddBackward0>)
# EPOCH:  577  LOSS:  tensor(0.1515, grad_fn=<AddBackward0>)
# EPOCH:  578  LOSS:  tensor(0.1512, grad_fn=<AddBackward0>)
# EPOCH:  579  LOSS:  tensor(0.1509, grad_fn=<AddBackward0>)
# EPOCH:  580  LOSS:  tensor(0.1506, grad_fn=<AddBackward0>)
# EPOCH:  581  LOSS:  tensor(0.1502, grad_fn=<AddBackward0>)
# EPOCH:  582  LOSS:  tensor(0.1499, grad_fn=<AddBackward0>)
# EPOCH:  583  LOSS:  tensor(0.1496, grad_fn=<AddBackward0>)
# EPOCH:  584  LOSS:  tensor(0.1492, grad_fn=<AddBackward0>)
# EPOCH:  585  LOSS:  tensor(0.1489, grad_fn=<AddBackward0>)
# EPOCH:  586  LOSS:  tensor(0.1486, grad_fn=<AddBackward0>)
# EPOCH:  587  LOSS:  tensor(0.1483, grad_fn=<AddBackward0>)
# EPOCH:  588  LOSS:  tensor(0.1480, grad_fn=<AddBackward0>)
# EPOCH:  589  LOSS:  tensor(0.1476, grad_fn=<AddBackward0>)
# EPOCH:  590  LOSS:  tensor(0.1473, grad_fn=<AddBackward0>)
# EPOCH:  591  LOSS:  tensor(0.1470, grad_fn=<AddBackward0>)
# EPOCH:  592  LOSS:  tensor(0.1467, grad_fn=<AddBackward0>)
# EPOCH:  593  LOSS:  tensor(0.1464, grad_fn=<AddBackward0>)
# EPOCH:  594  LOSS:  tensor(0.1461, grad_fn=<AddBackward0>)
# EPOCH:  595  LOSS:  tensor(0.1458, grad_fn=<AddBackward0>)
# EPOCH:  596  LOSS:  tensor(0.1455, grad_fn=<AddBackward0>)
# EPOCH:  597  LOSS:  tensor(0.1452, grad_fn=<AddBackward0>)
# EPOCH:  598  LOSS:  tensor(0.1449, grad_fn=<AddBackward0>)
# EPOCH:  599  LOSS:  tensor(0.1446, grad_fn=<AddBackward0>)
# EPOCH:  600  LOSS:  tensor(0.1443, grad_fn=<AddBackward0>)
# EPOCH:  601  LOSS:  tensor(0.1440, grad_fn=<AddBackward0>)
# EPOCH:  602  LOSS:  tensor(0.1437, grad_fn=<AddBackward0>)
# EPOCH:  603  LOSS:  tensor(0.1434, grad_fn=<AddBackward0>)
# EPOCH:  604  LOSS:  tensor(0.1431, grad_fn=<AddBackward0>)
# EPOCH:  605  LOSS:  tensor(0.1428, grad_fn=<AddBackward0>)
# EPOCH:  606  LOSS:  tensor(0.1426, grad_fn=<AddBackward0>)
# EPOCH:  607  LOSS:  tensor(0.1423, grad_fn=<AddBackward0>)
# EPOCH:  608  LOSS:  tensor(0.1420, grad_fn=<AddBackward0>)
# EPOCH:  609  LOSS:  tensor(0.1417, grad_fn=<AddBackward0>)
# EPOCH:  610  LOSS:  tensor(0.1414, grad_fn=<AddBackward0>)
# EPOCH:  611  LOSS:  tensor(0.1411, grad_fn=<AddBackward0>)
# EPOCH:  612  LOSS:  tensor(0.1409, grad_fn=<AddBackward0>)
# EPOCH:  613  LOSS:  tensor(0.1406, grad_fn=<AddBackward0>)
# EPOCH:  614  LOSS:  tensor(0.1403, grad_fn=<AddBackward0>)
# EPOCH:  615  LOSS:  tensor(0.1400, grad_fn=<AddBackward0>)
# EPOCH:  616  LOSS:  tensor(0.1397, grad_fn=<AddBackward0>)
# EPOCH:  617  LOSS:  tensor(0.1394, grad_fn=<AddBackward0>)
# EPOCH:  618  LOSS:  tensor(0.1392, grad_fn=<AddBackward0>)
# EPOCH:  619  LOSS:  tensor(0.1389, grad_fn=<AddBackward0>)
# EPOCH:  620  LOSS:  tensor(0.1386, grad_fn=<AddBackward0>)
# EPOCH:  621  LOSS:  tensor(0.1383, grad_fn=<AddBackward0>)
# EPOCH:  622  LOSS:  tensor(0.1381, grad_fn=<AddBackward0>)
# EPOCH:  623  LOSS:  tensor(0.1378, grad_fn=<AddBackward0>)
# EPOCH:  624  LOSS:  tensor(0.1375, grad_fn=<AddBackward0>)
# EPOCH:  625  LOSS:  tensor(0.1373, grad_fn=<AddBackward0>)
# Exception ignored in: <function WeakValueDictionary.__init__.<locals>.remove at 0x102ba5a60>
# Traceback (most recent call last):
#   File "/Users/mac/anaconda3/envs/SSL/lib/python3.6/weakref.py", line 109, in remove
#     def remove(wr, selfref=ref(self), _atomic_removal=_remove_dead_weakref):
# KeyboardInterrupt
# EPOCH:  626  LOSS:  tensor(0.1370, grad_fn=<AddBackward0>)
# EPOCH:  627  LOSS:  tensor(0.1367, grad_fn=<AddBackward0>)
# EPOCH:  628  LOSS:  tensor(0.1365, grad_fn=<AddBackward0>)
# EPOCH:  629  LOSS:  tensor(0.1362, grad_fn=<AddBackward0>)
# EPOCH:  630  LOSS:  tensor(0.1359, grad_fn=<AddBackward0>)
# EPOCH:  631  LOSS:  tensor(0.1357, grad_fn=<AddBackward0>)
# EPOCH:  632  LOSS:  tensor(0.1354, grad_fn=<AddBackward0>)
# EPOCH:  633  LOSS:  tensor(0.1352, grad_fn=<AddBackward0>)
# EPOCH:  634  LOSS:  tensor(0.1349, grad_fn=<AddBackward0>)
# EPOCH:  635  LOSS:  tensor(0.1347, grad_fn=<AddBackward0>)
# EPOCH:  636  LOSS:  tensor(0.1344, grad_fn=<AddBackward0>)
# EPOCH:  637  LOSS:  tensor(0.1342, grad_fn=<AddBackward0>)
# EPOCH:  638  LOSS:  tensor(0.1339, grad_fn=<AddBackward0>)
# EPOCH:  639  LOSS:  tensor(0.1337, grad_fn=<AddBackward0>)
# EPOCH:  640  LOSS:  tensor(0.1334, grad_fn=<AddBackward0>)
# EPOCH:  641  LOSS:  tensor(0.1332, grad_fn=<AddBackward0>)
# EPOCH:  642  LOSS:  tensor(0.1329, grad_fn=<AddBackward0>)
# EPOCH:  643  LOSS:  tensor(0.1327, grad_fn=<AddBackward0>)
# EPOCH:  644  LOSS:  tensor(0.1324, grad_fn=<AddBackward0>)
# EPOCH:  645  LOSS:  tensor(0.1322, grad_fn=<AddBackward0>)
# EPOCH:  646  LOSS:  tensor(0.1320, grad_fn=<AddBackward0>)
# EPOCH:  647  LOSS:  tensor(0.1317, grad_fn=<AddBackward0>)
# EPOCH:  648  LOSS:  tensor(0.1315, grad_fn=<AddBackward0>)
# EPOCH:  649  LOSS:  tensor(0.1313, grad_fn=<AddBackward0>)
# EPOCH:  650  LOSS:  tensor(0.1310, grad_fn=<AddBackward0>)
# EPOCH:  651  LOSS:  tensor(0.1307, grad_fn=<AddBackward0>)
# EPOCH:  652  LOSS:  tensor(0.1305, grad_fn=<AddBackward0>)
# EPOCH:  653  LOSS:  tensor(0.1303, grad_fn=<AddBackward0>)
# EPOCH:  654  LOSS:  tensor(0.1301, grad_fn=<AddBackward0>)
# EPOCH:  655  LOSS:  tensor(0.1298, grad_fn=<AddBackward0>)
# EPOCH:  656  LOSS:  tensor(0.1296, grad_fn=<AddBackward0>)
# EPOCH:  657  LOSS:  tensor(0.1293, grad_fn=<AddBackward0>)
# EPOCH:  658  LOSS:  tensor(0.1291, grad_fn=<AddBackward0>)
# EPOCH:  659  LOSS:  tensor(0.1288, grad_fn=<AddBackward0>)
# EPOCH:  660  LOSS:  tensor(0.1286, grad_fn=<AddBackward0>)
# EPOCH:  661  LOSS:  tensor(0.1284, grad_fn=<AddBackward0>)
# EPOCH:  662  LOSS:  tensor(0.1281, grad_fn=<AddBackward0>)
# EPOCH:  663  LOSS:  tensor(0.1279, grad_fn=<AddBackward0>)
# EPOCH:  664  LOSS:  tensor(0.1277, grad_fn=<AddBackward0>)
# EPOCH:  665  LOSS:  tensor(0.1274, grad_fn=<AddBackward0>)
# EPOCH:  666  LOSS:  tensor(0.1272, grad_fn=<AddBackward0>)
# EPOCH:  667  LOSS:  tensor(0.1270, grad_fn=<AddBackward0>)
# EPOCH:  668  LOSS:  tensor(0.1267, grad_fn=<AddBackward0>)
# EPOCH:  669  LOSS:  tensor(0.1265, grad_fn=<AddBackward0>)
# EPOCH:  670  LOSS:  tensor(0.1263, grad_fn=<AddBackward0>)
# EPOCH:  671  LOSS:  tensor(0.1261, grad_fn=<AddBackward0>)
# EPOCH:  672  LOSS:  tensor(0.1259, grad_fn=<AddBackward0>)
# EPOCH:  673  LOSS:  tensor(0.1256, grad_fn=<AddBackward0>)
# EPOCH:  674  LOSS:  tensor(0.1254, grad_fn=<AddBackward0>)
# EPOCH:  675  LOSS:  tensor(0.1252, grad_fn=<AddBackward0>)
# EPOCH:  676  LOSS:  tensor(0.1250, grad_fn=<AddBackward0>)
# EPOCH:  677  LOSS:  tensor(0.1248, grad_fn=<AddBackward0>)
# EPOCH:  678  LOSS:  tensor(0.1246, grad_fn=<AddBackward0>)
# EPOCH:  679  LOSS:  tensor(0.1243, grad_fn=<AddBackward0>)
# EPOCH:  680  LOSS:  tensor(0.1241, grad_fn=<AddBackward0>)
# EPOCH:  681  LOSS:  tensor(0.1239, grad_fn=<AddBackward0>)
# EPOCH:  682  LOSS:  tensor(0.1237, grad_fn=<AddBackward0>)
# EPOCH:  683  LOSS:  tensor(0.1235, grad_fn=<AddBackward0>)
# EPOCH:  684  LOSS:  tensor(0.1233, grad_fn=<AddBackward0>)
# EPOCH:  685  LOSS:  tensor(0.1231, grad_fn=<AddBackward0>)
# EPOCH:  686  LOSS:  tensor(0.1229, grad_fn=<AddBackward0>)
# EPOCH:  687  LOSS:  tensor(0.1227, grad_fn=<AddBackward0>)
# EPOCH:  688  LOSS:  tensor(0.1225, grad_fn=<AddBackward0>)
# EPOCH:  689  LOSS:  tensor(0.1223, grad_fn=<AddBackward0>)
# EPOCH:  690  LOSS:  tensor(0.1221, grad_fn=<AddBackward0>)
# EPOCH:  691  LOSS:  tensor(0.1220, grad_fn=<AddBackward0>)
# EPOCH:  692  LOSS:  tensor(0.1218, grad_fn=<AddBackward0>)
# EPOCH:  693  LOSS:  tensor(0.1216, grad_fn=<AddBackward0>)
# EPOCH:  694  LOSS:  tensor(0.1214, grad_fn=<AddBackward0>)
# EPOCH:  695  LOSS:  tensor(0.1212, grad_fn=<AddBackward0>)
# EPOCH:  696  LOSS:  tensor(0.1210, grad_fn=<AddBackward0>)
# EPOCH:  697  LOSS:  tensor(0.1209, grad_fn=<AddBackward0>)
# EPOCH:  698  LOSS:  tensor(0.1207, grad_fn=<AddBackward0>)
# EPOCH:  699  LOSS:  tensor(0.1205, grad_fn=<AddBackward0>)
# EPOCH:  700  LOSS:  tensor(0.1203, grad_fn=<AddBackward0>)
# EPOCH:  701  LOSS:  tensor(0.1201, grad_fn=<AddBackward0>)
# EPOCH:  702  LOSS:  tensor(0.1200, grad_fn=<AddBackward0>)
# EPOCH:  703  LOSS:  tensor(0.1198, grad_fn=<AddBackward0>)
# EPOCH:  704  LOSS:  tensor(0.1196, grad_fn=<AddBackward0>)
# EPOCH:  705  LOSS:  tensor(0.1194, grad_fn=<AddBackward0>)
# EPOCH:  706  LOSS:  tensor(0.1192, grad_fn=<AddBackward0>)
# EPOCH:  707  LOSS:  tensor(0.1190, grad_fn=<AddBackward0>)
# EPOCH:  708  LOSS:  tensor(0.1188, grad_fn=<AddBackward0>)
# EPOCH:  709  LOSS:  tensor(0.1186, grad_fn=<AddBackward0>)
# EPOCH:  710  LOSS:  tensor(0.1184, grad_fn=<AddBackward0>)
# EPOCH:  711  LOSS:  tensor(0.1182, grad_fn=<AddBackward0>)
# EPOCH:  712  LOSS:  tensor(0.1180, grad_fn=<AddBackward0>)
# EPOCH:  713  LOSS:  tensor(0.1178, grad_fn=<AddBackward0>)
# EPOCH:  714  LOSS:  tensor(0.1176, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-62e9914a0f4a> in <module>
#     154
#     155     network = netWBB(X_train_original, y_train_original, ([ int(n_hidden) ] * num_hidden_layers),
# --> 156             normalize = True, n_epochs = int(n_epochs * epochs_multiplier))
#     157
#     158
#
# <ipython-input-22-7fb5884ecfb0> in __init__(self, X_train, y_train, n_hidden, n_epochs, normalize)
#     145                 loss += (weights[-1] * lamda * l2).sum()
#     146
# --> 147                 loss.backward()
#     148                 optimizer.step()
#     149                 print("EPOCH: ", epoch, " LOSS: ", loss)
#
# ~/anaconda3/envs/SSL/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# ~/anaconda3/envs/SSL/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
# Copyright 2016, Yarin Gal, All rights reserved.
# This code is based on the code by Jose Miguel Hernandez-Lobato used for his 
# paper "Probabilistic Backpropagation for Scalable Learning of Bayesian Neural Networks".

import warnings
warnings.filterwarnings("ignore")

import math
from scipy.special import logsumexp
import numpy as np

from keras.regularizers import l2
# from keras import Input
from keras.layers import Input
from keras.layers import Dropout
from keras.layers import Dense
# from keras import Model

import time

import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn.functional as F
import torch.nn as nn
import torch.utils.data as Data
from scipy.stats import norm

import time

# %%
class netWBB:
    n_bootstrap_samples = 100     #number of bootstrap sampling
    NNs = []

    def __init__(self, X_train, y_train, n_hidden, n_epochs = 40,
        normalize = False):

        """
            Constructor for the class implementing a Bayesian neural network
            trained with the probabilistic back propagation method.

            @param X_train      Matrix with the features for the training data.
            @param y_train      Vector with the target variables for the
                                training data.
            @param n_hidden     Vector with the number of neurons for each
                                hidden layer.
            @param n_epochs     Numer of epochs for which to train the
                                network. The recommended value 40 should be
                                enough.
            @param normalize    Whether to normalize the input features. This
                                is recommended unles the input vector is for
                                example formed by binary features (a
                                fingerprint). In that case we do not recommend
                                to normalize the features.
        """


        # We normalize the training data to have zero mean and unit standard
        # deviation in the training set if necessary
        print("running")
        if normalize:
            self.std_X_train = np.std(X_train, 0)
            self.std_X_train[ self.std_X_train == 0 ] = 1
            self.mean_X_train = np.mean(X_train, 0)
        else:
            self.std_X_train = np.ones(X_train.shape[ 1 ])
            self.mean_X_train = np.zeros(X_train.shape[ 1 ])

        X_train = (X_train - np.full(X_train.shape, self.mean_X_train)) / \
            np.full(X_train.shape, self.std_X_train)

        self.mean_y_train = np.mean(y_train)
        self.std_y_train = np.std(y_train)

        y_train_normalized = (y_train - self.mean_y_train) / self.std_y_train
        y_train_normalized = np.array(y_train_normalized, ndmin = 2).T

        
        # TODO: implement WBB network
        input_shape = X_train.shape[1]
        output_shape = y_train_normalized.shape[1]
        max_index = X_train.shape[0]
        print("shape of input, output and max_index", input_shape, output_shape, max_index)

        lamda = 0.001
        Exp = torch.distributions.exponential.Exponential(torch.tensor([1.0]))
        for m in range (self.n_bootstrap_samples):
            print("Trainning model: ", m)
            weights = [Exp.sample() for _ in range(X_train.shape[0] + 1)]
            print("....", len(weights))

            # Network with a hidden layer and ReLU activation
            net = torch.nn.Sequential(
            torch.nn.Linear(input_shape, n_hidden[0]),
            torch.nn.ReLU(),
            torch.nn.Linear(n_hidden[0], output_shape),
            )
            
            
            BATCH_SIZE = 64
            optimizer = torch.optim.Adam(net.parameters(), lr=0.01)

            # Minimizing the negative log-likelihood of our data with respect to θ is equivalent to 
            # minimizing the mean squared error between the observed y and our prediction thereof
            loss_func = torch.nn.MSELoss(reduction = 'none')
            torch_dataset = Data.TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train_normalized))

            loader=Data.DataLoader(
            dataset=torch_dataset, 
            batch_size=BATCH_SIZE, 
            shuffle=False, num_workers=2,)

            start_time = time.time()
            for epoch in range(n_epochs):
                optimizer.zero_grad()
                loss = 0

                index1 = 0;
                for step, (batch_x, batch_y) in enumerate(loader):  
                    
                    index2 = (step+1)*BATCH_SIZE   # set index of weight array to multiply with loss: weight*loss_func
                    index2 = min(index2,max_index) 
                    b_x = Variable(batch_x)
                    b_y = Variable(batch_y)               
                    prediction = net(b_x.float())    
                    
                    # print("weight ",(torch.FloatTensor(weights[index1:index2]).shape))
                    # print("loss ", loss_func(prediction, b_y.float()).shape)
                    loss += (torch.FloatTensor(weights[index1:index2]).unsqueeze(1) * loss_func(prediction, b_y.float())).sum()
                    # print((torch.FloatTensor(weights[index1:index2]).unsqueeze(1) * loss_func(prediction, b_y.float())).shape)
                    index1 = index2   

                # #add L1 regularization
                # l1 = 0
                # for p in net.parameters():
                #     l1 = l1 + p.abs().sum()       
                # loss += weights[-1] * lamda * l1

                #add L2 regularization
                l2 = 0
                for p in net.parameters():
                    l2 = l2 + 0.5 * (p ** 2).sum()      
                loss += (weights[-1] * lamda * l2).sum()
                
                loss.backward()         
                optimizer.step()        
                print("EPOCH: ", epoch, " LOSS: ", loss)
            print("BATCH_SIZE: ", BATCH_SIZE, "time execution for a neural net: ", time.time() - start_time )
            self.NNs.append(net)


    def predict(self, X_test, y_test):

        """
            Function for making predictions with the Bayesian neural network.

            @param X_test   The matrix of features for the test data
            
    
            @return m       The predictive mean for the test target variables.
            @return v       The predictive variance for the test target
                            variables.
            @return v_noise The estimated variance for the additive noise.

        """

        X_test = np.array(X_test, ndmin = 2)
        y_test = np.array(y_test, ndmin = 2).T

        # We normalize the test set

        X_test = (X_test - np.full(X_test.shape, self.mean_X_train)) / \
            np.full(X_test.shape, self.std_X_train)

        # We compute the predictive mean and variance for the target variables
        # of the test data

        NN_pred = np.array([self.NNs[m](torch.from_numpy(X_test).float()).detach().numpy() for m in range(self.n_bootstrap_samples)])
        NN_pred = NN_pred * self.std_y_train + self.mean_y_train

        standard_pred = NN_pred[0]
        rmse_standard_pred = np.mean((y_test.squeeze() - standard_pred.squeeze())**2.)**0.5

        # MC_error
        MC_pred = np.mean(NN_pred, axis = 0)
        rmse = np.mean((y_test.squeeze() - MC_pred.squeeze())**2.)**0.5

        variance_ll = 0.1
        tau = 1. / variance_ll
        # T = y_test.shape[0]
        T = self.n_bootstrap_samples
        # We compute the test log-likelihood
        ll = (logsumexp(-0.5 * tau * (y_test[None] - NN_pred)**2., 0) - np.log(T) 
            - 0.5*np.log(2*np.pi) + 0.5*np.log(tau))
        test_ll = np.mean(ll)

        # We are done!
        return rmse_standard_pred, rmse, test_ll

# %%
# Copyright 2016, Yarin Gal, All rights reserved.
# This code is based on the code by Jose Miguel Hernandez-Lobato used for his 
# paper "Probabilistic Backpropagation for Scalable Learning of Bayesian Neural Networks".

# This file contains code to train dropout networks on the UCI datasets using the following algorithm:
# 1. Create 20 random splits of the training-test dataset.
# 2. For each split:
# 3.   Create a validation (val) set taking 20% of the training set.
# 4.   Get best hyperparameters: dropout_rate and tau by training on (train-val) set and testing on val set.
# 5.   Train a network on the entire training set with the best pair of hyperparameters.
# 6.   Get the performance (MC RMSE and log-likelihood) on the test set.
# 7. Report the averaged performance (Monte Carlo RMSE and log-likelihood) on all 20 splits.

import math
import numpy as np
import argparse
import sys

# parser=argparse.ArgumentParser()

# parser.add_argument('--dir', '-d', required=True, help='Name of the UCI Dataset directory. Eg: bostonHousing')
# parser.add_argument('--epochx','-e', default=500, type=int, help='Multiplier for the number of epochs for training.')
# parser.add_argument('--hidden', '-nh', default=2, type=int, help='Number of hidden layers for the neural net')

# args=parser.parse_args()

# data_directory = args.dir
# epochs_multiplier = args.epochx
# num_hidden_layers = args.hidden

data_directory = "yacht"
epochs_multiplier = 30
num_hidden_layers = 1

# sys.path.append('net/')

# import netWBB
# from net import netWBB

# We delete previous results

from subprocess import call


_RESULTS_VALIDATION_LL = "./UCI_Datasets/" + data_directory + "/results/validation_ll_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_VALIDATION_RMSE = "./UCI_Datasets/" + data_directory + "/results/validation_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_VALIDATION_MC_RMSE = "./UCI_Datasets/" + data_directory + "/results/validation_MC_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"

_RESULTS_TEST_LL = "./UCI_Datasets/" + data_directory + "/results/test_ll_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_TAU = "./UCI_Datasets/" + data_directory + "/results/test_tau_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_RMSE = "./UCI_Datasets/" + data_directory + "/results/test_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_MC_RMSE = "./UCI_Datasets/" + data_directory + "/results/test_MC_rmse_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"
_RESULTS_TEST_LOG = "./UCI_Datasets/" + data_directory + "/results/log_" + str(epochs_multiplier) + "_xepochs_" + str(num_hidden_layers) + "_hidden_layers.txt"

_DATA_DIRECTORY_PATH = "./UCI_Datasets/" + data_directory + "/data/"
_DROPOUT_RATES_FILE = _DATA_DIRECTORY_PATH + "dropout_rates.txt"
_TAU_VALUES_FILE = _DATA_DIRECTORY_PATH + "tau_values.txt"
_DATA_FILE = _DATA_DIRECTORY_PATH + "data.txt"
_HIDDEN_UNITS_FILE = _DATA_DIRECTORY_PATH + "n_hidden.txt"
_EPOCHS_FILE = _DATA_DIRECTORY_PATH + "n_epochs.txt"
_INDEX_FEATURES_FILE = _DATA_DIRECTORY_PATH + "index_features.txt"
_INDEX_TARGET_FILE = _DATA_DIRECTORY_PATH + "index_target.txt"
_N_SPLITS_FILE = _DATA_DIRECTORY_PATH + "n_splits.txt"

# %%
def _get_index_train_test_path(split_num, train = True):
    """
       Method to generate the path containing the training/test split for the given
       split number (generally from 1 to 20).
       @param split_num      Split number for which the data has to be generated
       @param train          Is true if the data is training data. Else false.
       @return path          Path of the file containing the requried data
    """
    if train:
        return _DATA_DIRECTORY_PATH + "index_train_" + str(split_num) + ".txt"
    else:
        return _DATA_DIRECTORY_PATH + "index_test_" + str(split_num) + ".txt" 


print ("Removing existing result files...")
call(["rm", _RESULTS_VALIDATION_LL])
call(["rm", _RESULTS_VALIDATION_RMSE])
call(["rm", _RESULTS_VALIDATION_MC_RMSE])
call(["rm", _RESULTS_TEST_LL])
call(["rm", _RESULTS_TEST_TAU])
call(["rm", _RESULTS_TEST_RMSE])
call(["rm", _RESULTS_TEST_MC_RMSE])
call(["rm", _RESULTS_TEST_LOG])
print ("Result files removed.")

# We fix the random seed

np.random.seed(1)

print ("Loading data and other hyperparameters...")
# We load the data

data = np.loadtxt(_DATA_FILE)

# We load the number of hidden units

n_hidden = np.loadtxt(_HIDDEN_UNITS_FILE).tolist()

# We load the number of training epocs

n_epochs = np.loadtxt(_EPOCHS_FILE).tolist()

# We load the indexes for the features and for the target

index_features = np.loadtxt(_INDEX_FEATURES_FILE)
index_target = np.loadtxt(_INDEX_TARGET_FILE)

X = data[ : , [int(i) for i in index_features.tolist()] ]
y = data[ : , int(index_target.tolist()) ]

# We iterate over the training test splits

n_splits = np.loadtxt(_N_SPLITS_FILE)
print ("Done.")

errors, MC_errors, lls = [], [], []
# for split in range(int(n_splits)):
for split in range(5):  # first, test in 5 splits dataset
    print ("Trainning on split: ", split)
    # We load the indexes of the training and test sets
    print ('Loading file: ' + _get_index_train_test_path(split, train=True))
    print ('Loading file: ' + _get_index_train_test_path(split, train=False))
    index_train = np.loadtxt(_get_index_train_test_path(split, train=True))
    index_test = np.loadtxt(_get_index_train_test_path(split, train=False))

    X_train = X[ [int(i) for i in index_train.tolist()] ]
    y_train = y[ [int(i) for i in index_train.tolist()] ]
    
    X_test = X[ [int(i) for i in index_test.tolist()] ]
    y_test = y[ [int(i) for i in index_test.tolist()] ]

    X_train_original = X_train
    y_train_original = y_train
    num_training_examples = int(0.8 * X_train.shape[0])
    X_validation = X_train[num_training_examples:, :]
    y_validation = y_train[num_training_examples:]
    X_train = X_train[0:num_training_examples, :]
    y_train = y_train[0:num_training_examples]
    
    # Printing the size of the training, validation and test sets
    print ('Number of training examples: ' + str(X_train.shape[0]))
    print ('Number of validation examples: ' + str(X_validation.shape[0]))
    print ('Number of test examples: ' + str(X_test.shape[0]))
    print ('Number of train_original examples: ' + str(X_train_original.shape[0]))

    # List of hyperparameters which we will try out using grid-search
    # dropout_rates = np.loadtxt(_DROPOUT_RATES_FILE).tolist()
    # tau_values = np.loadtxt(_TAU_VALUES_FILE).tolist()


    network = netWBB(X_train_original, y_train_original, ([ int(n_hidden) ] * num_hidden_layers),
            normalize = True, n_epochs = int(n_epochs * epochs_multiplier))


            
#             # Storing validation results
#             with open(_RESULTS_VALIDATION_RMSE, "a") as myfile:
#                 myfile.write('Dropout_Rate: ' + repr(dropout_rate) + ' Tau: ' + repr(tau) + ' :: ')
#                 myfile.write(repr(error) + '\n')

#             with open(_RESULTS_VALIDATION_MC_RMSE, "a") as myfile:
#                 myfile.write('Dropout_Rate: ' + repr(dropout_rate) + ' Tau: ' + repr(tau) + ' :: ')
#                 myfile.write(repr(MC_error) + '\n')

#             with open(_RESULTS_VALIDATION_LL, "a") as myfile:
#                 myfile.write('Dropout_Rate: ' + repr(dropout_rate) + ' Tau: ' + repr(tau) + ' :: ')
#                 myfile.write(repr(ll) + '\n')

#     # Storing test results
#     best_network = net.net(X_train_original, y_train_original, ([ int(n_hidden) ] * num_hidden_layers),
#                     normalize = True, n_epochs = int(n_epochs * epochs_multiplier), tau = best_tau,
#                     dropout = best_dropout)
    error, MC_error, ll = network.predict(X_test, y_test)
    
    with open(_RESULTS_TEST_RMSE, "a") as myfile:
        myfile.write(repr(error) + '\n')

    with open(_RESULTS_TEST_MC_RMSE, "a") as myfile:
        myfile.write(repr(MC_error) + '\n')

    with open(_RESULTS_TEST_LL, "a") as myfile:
        myfile.write(repr(ll) + '\n')

    # with open(_RESULTS_TEST_TAU, "a") as myfile:
    #     myfile.write(repr(best_network.tau) + '\n')

    print ("Tests on split " + str(split) + " complete.")
    errors += [error]
    MC_errors += [MC_error]
    lls += [ll]

with open(_RESULTS_TEST_LOG, "a") as myfile:
    myfile.write('errors %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(errors), np.std(errors), np.std(errors)/math.sqrt(n_splits),
        np.percentile(errors, 50), np.percentile(errors, 25), np.percentile(errors, 75)))
    myfile.write('MC errors %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(MC_errors), np.std(MC_errors), np.std(MC_errors)/math.sqrt(n_splits),
        np.percentile(MC_errors, 50), np.percentile(MC_errors, 25), np.percentile(MC_errors, 75)))
    myfile.write('lls %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(lls), np.std(lls), np.std(lls)/math.sqrt(n_splits), 
        np.percentile(lls, 50), np.percentile(lls, 25), np.percentile(lls, 75)))
# Out:
# Removing existing result files...
# Result files removed.
# Loading data and other hyperparameters...
# Done.
# Trainning on split:  0
# Loading file: ./UCI_Datasets/yacht/data/index_train_0.txt
# Loading file: ./UCI_Datasets/yacht/data/index_test_0.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# running
# shape of input, output and max_index 6 1 277
# Trainning model:  0
# .... 278
# EPOCH:  0  LOSS:  tensor(373.3935, grad_fn=<AddBackward0>)
# EPOCH:  1  LOSS:  tensor(332.3792, grad_fn=<AddBackward0>)
# EPOCH:  2  LOSS:  tensor(297.7012, grad_fn=<AddBackward0>)
# EPOCH:  3  LOSS:  tensor(267.3447, grad_fn=<AddBackward0>)
# EPOCH:  4  LOSS:  tensor(240.2691, grad_fn=<AddBackward0>)
# EPOCH:  5  LOSS:  tensor(216.2865, grad_fn=<AddBackward0>)
# EPOCH:  6  LOSS:  tensor(195.3037, grad_fn=<AddBackward0>)
# EPOCH:  7  LOSS:  tensor(177.3007, grad_fn=<AddBackward0>)
# EPOCH:  8  LOSS:  tensor(162.1440, grad_fn=<AddBackward0>)
# EPOCH:  9  LOSS:  tensor(149.8452, grad_fn=<AddBackward0>)
# EPOCH:  10  LOSS:  tensor(140.3174, grad_fn=<AddBackward0>)
# EPOCH:  11  LOSS:  tensor(133.3246, grad_fn=<AddBackward0>)
# EPOCH:  12  LOSS:  tensor(128.5622, grad_fn=<AddBackward0>)
# EPOCH:  13  LOSS:  tensor(125.5943, grad_fn=<AddBackward0>)
# EPOCH:  14  LOSS:  tensor(123.6106, grad_fn=<AddBackward0>)
# EPOCH:  15  LOSS:  tensor(122.0517, grad_fn=<AddBackward0>)
# EPOCH:  16  LOSS:  tensor(120.2321, grad_fn=<AddBackward0>)
# EPOCH:  17  LOSS:  tensor(117.7956, grad_fn=<AddBackward0>)
# EPOCH:  18  LOSS:  tensor(114.7822, grad_fn=<AddBackward0>)
# EPOCH:  19  LOSS:  tensor(111.2226, grad_fn=<AddBackward0>)
# EPOCH:  20  LOSS:  tensor(107.3056, grad_fn=<AddBackward0>)
# EPOCH:  21  LOSS:  tensor(103.3385, grad_fn=<AddBackward0>)
# EPOCH:  22  LOSS:  tensor(99.4830, grad_fn=<AddBackward0>)
# EPOCH:  23  LOSS:  tensor(95.9827, grad_fn=<AddBackward0>)
# EPOCH:  24  LOSS:  tensor(93.0923, grad_fn=<AddBackward0>)
# EPOCH:  25  LOSS:  tensor(90.6975, grad_fn=<AddBackward0>)
# EPOCH:  26  LOSS:  tensor(88.7749, grad_fn=<AddBackward0>)
# EPOCH:  27  LOSS:  tensor(87.1550, grad_fn=<AddBackward0>)
# EPOCH:  28  LOSS:  tensor(85.6871, grad_fn=<AddBackward0>)
# EPOCH:  29  LOSS:  tensor(84.2992, grad_fn=<AddBackward0>)
# EPOCH:  30  LOSS:  tensor(82.8585, grad_fn=<AddBackward0>)
# EPOCH:  31  LOSS:  tensor(81.3180, grad_fn=<AddBackward0>)
# EPOCH:  32  LOSS:  tensor(79.6562, grad_fn=<AddBackward0>)
# EPOCH:  33  LOSS:  tensor(77.8972, grad_fn=<AddBackward0>)
# EPOCH:  34  LOSS:  tensor(76.0232, grad_fn=<AddBackward0>)
# EPOCH:  35  LOSS:  tensor(74.0614, grad_fn=<AddBackward0>)
# EPOCH:  36  LOSS:  tensor(72.0807, grad_fn=<AddBackward0>)
# EPOCH:  37  LOSS:  tensor(70.1121, grad_fn=<AddBackward0>)
# EPOCH:  38  LOSS:  tensor(68.2156, grad_fn=<AddBackward0>)
# EPOCH:  39  LOSS:  tensor(66.3538, grad_fn=<AddBackward0>)
# EPOCH:  40  LOSS:  tensor(64.5291, grad_fn=<AddBackward0>)
# EPOCH:  41  LOSS:  tensor(62.7234, grad_fn=<AddBackward0>)
# EPOCH:  42  LOSS:  tensor(60.9250, grad_fn=<AddBackward0>)
# EPOCH:  43  LOSS:  tensor(59.1183, grad_fn=<AddBackward0>)
# EPOCH:  44  LOSS:  tensor(57.3107, grad_fn=<AddBackward0>)
# EPOCH:  45  LOSS:  tensor(55.4973, grad_fn=<AddBackward0>)
# EPOCH:  46  LOSS:  tensor(53.7591, grad_fn=<AddBackward0>)
# EPOCH:  47  LOSS:  tensor(51.9539, grad_fn=<AddBackward0>)
# EPOCH:  48  LOSS:  tensor(50.1452, grad_fn=<AddBackward0>)
# EPOCH:  49  LOSS:  tensor(48.4221, grad_fn=<AddBackward0>)
# EPOCH:  50  LOSS:  tensor(46.6936, grad_fn=<AddBackward0>)
# EPOCH:  51  LOSS:  tensor(44.9713, grad_fn=<AddBackward0>)
# EPOCH:  52  LOSS:  tensor(43.2485, grad_fn=<AddBackward0>)
# EPOCH:  53  LOSS:  tensor(41.5145, grad_fn=<AddBackward0>)
# EPOCH:  54  LOSS:  tensor(39.7561, grad_fn=<AddBackward0>)
# EPOCH:  55  LOSS:  tensor(38.0111, grad_fn=<AddBackward0>)
# EPOCH:  56  LOSS:  tensor(36.2673, grad_fn=<AddBackward0>)
# EPOCH:  57  LOSS:  tensor(34.5133, grad_fn=<AddBackward0>)
# EPOCH:  58  LOSS:  tensor(32.7849, grad_fn=<AddBackward0>)
# EPOCH:  59  LOSS:  tensor(31.0747, grad_fn=<AddBackward0>)
# EPOCH:  60  LOSS:  tensor(29.4348, grad_fn=<AddBackward0>)
# EPOCH:  61  LOSS:  tensor(27.8611, grad_fn=<AddBackward0>)
# EPOCH:  62  LOSS:  tensor(26.3579, grad_fn=<AddBackward0>)
# EPOCH:  63  LOSS:  tensor(24.9282, grad_fn=<AddBackward0>)
# EPOCH:  64  LOSS:  tensor(23.5659, grad_fn=<AddBackward0>)
# EPOCH:  65  LOSS:  tensor(22.3024, grad_fn=<AddBackward0>)
# EPOCH:  66  LOSS:  tensor(21.1293, grad_fn=<AddBackward0>)
# EPOCH:  67  LOSS:  tensor(20.0422, grad_fn=<AddBackward0>)
# EPOCH:  68  LOSS:  tensor(19.0605, grad_fn=<AddBackward0>)
# EPOCH:  69  LOSS:  tensor(18.1839, grad_fn=<AddBackward0>)
# EPOCH:  70  LOSS:  tensor(17.4101, grad_fn=<AddBackward0>)
# EPOCH:  71  LOSS:  tensor(16.6989, grad_fn=<AddBackward0>)
# EPOCH:  72  LOSS:  tensor(16.0248, grad_fn=<AddBackward0>)
# EPOCH:  73  LOSS:  tensor(15.3673, grad_fn=<AddBackward0>)
# EPOCH:  74  LOSS:  tensor(14.6951, grad_fn=<AddBackward0>)
# EPOCH:  75  LOSS:  tensor(14.0402, grad_fn=<AddBackward0>)
# EPOCH:  76  LOSS:  tensor(13.4016, grad_fn=<AddBackward0>)
# EPOCH:  77  LOSS:  tensor(12.7401, grad_fn=<AddBackward0>)
# EPOCH:  78  LOSS:  tensor(12.0969, grad_fn=<AddBackward0>)
# EPOCH:  79  LOSS:  tensor(11.4700, grad_fn=<AddBackward0>)
# EPOCH:  80  LOSS:  tensor(10.8823, grad_fn=<AddBackward0>)
# EPOCH:  81  LOSS:  tensor(10.3032, grad_fn=<AddBackward0>)
# EPOCH:  82  LOSS:  tensor(9.7649, grad_fn=<AddBackward0>)
# EPOCH:  83  LOSS:  tensor(9.2536, grad_fn=<AddBackward0>)
# EPOCH:  84  LOSS:  tensor(8.8041, grad_fn=<AddBackward0>)
# EPOCH:  85  LOSS:  tensor(8.4406, grad_fn=<AddBackward0>)
# EPOCH:  86  LOSS:  tensor(8.1160, grad_fn=<AddBackward0>)
# EPOCH:  87  LOSS:  tensor(7.8006, grad_fn=<AddBackward0>)
# EPOCH:  88  LOSS:  tensor(7.4842, grad_fn=<AddBackward0>)
# EPOCH:  89  LOSS:  tensor(7.1665, grad_fn=<AddBackward0>)
# EPOCH:  90  LOSS:  tensor(6.8562, grad_fn=<AddBackward0>)
# EPOCH:  91  LOSS:  tensor(6.5475, grad_fn=<AddBackward0>)
# EPOCH:  92  LOSS:  tensor(6.2653, grad_fn=<AddBackward0>)
# EPOCH:  93  LOSS:  tensor(5.9943, grad_fn=<AddBackward0>)
# EPOCH:  94  LOSS:  tensor(5.7223, grad_fn=<AddBackward0>)
# EPOCH:  95  LOSS:  tensor(5.4576, grad_fn=<AddBackward0>)
# EPOCH:  96  LOSS:  tensor(5.2068, grad_fn=<AddBackward0>)
# EPOCH:  97  LOSS:  tensor(4.9677, grad_fn=<AddBackward0>)
# EPOCH:  98  LOSS:  tensor(4.7365, grad_fn=<AddBackward0>)
# EPOCH:  99  LOSS:  tensor(4.5218, grad_fn=<AddBackward0>)
# EPOCH:  100  LOSS:  tensor(4.3171, grad_fn=<AddBackward0>)
# EPOCH:  101  LOSS:  tensor(4.1198, grad_fn=<AddBackward0>)
# EPOCH:  102  LOSS:  tensor(3.9377, grad_fn=<AddBackward0>)
# EPOCH:  103  LOSS:  tensor(3.7655, grad_fn=<AddBackward0>)
# EPOCH:  104  LOSS:  tensor(3.6075, grad_fn=<AddBackward0>)
# EPOCH:  105  LOSS:  tensor(3.4646, grad_fn=<AddBackward0>)
# EPOCH:  106  LOSS:  tensor(3.3374, grad_fn=<AddBackward0>)
# EPOCH:  107  LOSS:  tensor(3.2179, grad_fn=<AddBackward0>)
# EPOCH:  108  LOSS:  tensor(3.1061, grad_fn=<AddBackward0>)
# EPOCH:  109  LOSS:  tensor(3.0018, grad_fn=<AddBackward0>)
# EPOCH:  110  LOSS:  tensor(2.9024, grad_fn=<AddBackward0>)
# EPOCH:  111  LOSS:  tensor(2.8078, grad_fn=<AddBackward0>)
# EPOCH:  112  LOSS:  tensor(2.7185, grad_fn=<AddBackward0>)
# EPOCH:  113  LOSS:  tensor(2.6320, grad_fn=<AddBackward0>)
# EPOCH:  114  LOSS:  tensor(2.5496, grad_fn=<AddBackward0>)
# EPOCH:  115  LOSS:  tensor(2.4722, grad_fn=<AddBackward0>)
# EPOCH:  116  LOSS:  tensor(2.4008, grad_fn=<AddBackward0>)
# EPOCH:  117  LOSS:  tensor(2.3328, grad_fn=<AddBackward0>)
# EPOCH:  118  LOSS:  tensor(2.2675, grad_fn=<AddBackward0>)
# EPOCH:  119  LOSS:  tensor(2.2034, grad_fn=<AddBackward0>)
# EPOCH:  120  LOSS:  tensor(2.1411, grad_fn=<AddBackward0>)
# EPOCH:  121  LOSS:  tensor(2.0804, grad_fn=<AddBackward0>)
# EPOCH:  122  LOSS:  tensor(2.0217, grad_fn=<AddBackward0>)
# EPOCH:  123  LOSS:  tensor(1.9656, grad_fn=<AddBackward0>)
# EPOCH:  124  LOSS:  tensor(1.9121, grad_fn=<AddBackward0>)
# EPOCH:  125  LOSS:  tensor(1.8619, grad_fn=<AddBackward0>)
# EPOCH:  126  LOSS:  tensor(1.8139, grad_fn=<AddBackward0>)
# EPOCH:  127  LOSS:  tensor(1.7677, grad_fn=<AddBackward0>)
# EPOCH:  128  LOSS:  tensor(1.7232, grad_fn=<AddBackward0>)
# EPOCH:  129  LOSS:  tensor(1.6802, grad_fn=<AddBackward0>)
# EPOCH:  130  LOSS:  tensor(1.6387, grad_fn=<AddBackward0>)
# EPOCH:  131  LOSS:  tensor(1.5986, grad_fn=<AddBackward0>)
# EPOCH:  132  LOSS:  tensor(1.5608, grad_fn=<AddBackward0>)
# EPOCH:  133  LOSS:  tensor(1.5247, grad_fn=<AddBackward0>)
# EPOCH:  134  LOSS:  tensor(1.4897, grad_fn=<AddBackward0>)
# EPOCH:  135  LOSS:  tensor(1.4564, grad_fn=<AddBackward0>)
# EPOCH:  136  LOSS:  tensor(1.4240, grad_fn=<AddBackward0>)
# EPOCH:  137  LOSS:  tensor(1.3924, grad_fn=<AddBackward0>)
# EPOCH:  138  LOSS:  tensor(1.3620, grad_fn=<AddBackward0>)
# EPOCH:  139  LOSS:  tensor(1.3327, grad_fn=<AddBackward0>)
# EPOCH:  140  LOSS:  tensor(1.3049, grad_fn=<AddBackward0>)
# EPOCH:  141  LOSS:  tensor(1.2781, grad_fn=<AddBackward0>)
# EPOCH:  142  LOSS:  tensor(1.2521, grad_fn=<AddBackward0>)
# EPOCH:  143  LOSS:  tensor(1.2262, grad_fn=<AddBackward0>)
# EPOCH:  144  LOSS:  tensor(1.2014, grad_fn=<AddBackward0>)
# EPOCH:  145  LOSS:  tensor(1.1781, grad_fn=<AddBackward0>)
# EPOCH:  146  LOSS:  tensor(1.1553, grad_fn=<AddBackward0>)
# EPOCH:  147  LOSS:  tensor(1.1329, grad_fn=<AddBackward0>)
# EPOCH:  148  LOSS:  tensor(1.1109, grad_fn=<AddBackward0>)
# EPOCH:  149  LOSS:  tensor(1.0900, grad_fn=<AddBackward0>)
# EPOCH:  150  LOSS:  tensor(1.0697, grad_fn=<AddBackward0>)
# EPOCH:  151  LOSS:  tensor(1.0499, grad_fn=<AddBackward0>)
# EPOCH:  152  LOSS:  tensor(1.0315, grad_fn=<AddBackward0>)
# EPOCH:  153  LOSS:  tensor(1.0150, grad_fn=<AddBackward0>)
# EPOCH:  154  LOSS:  tensor(0.9971, grad_fn=<AddBackward0>)
# EPOCH:  155  LOSS:  tensor(0.9801, grad_fn=<AddBackward0>)
# EPOCH:  156  LOSS:  tensor(0.9639, grad_fn=<AddBackward0>)
# EPOCH:  157  LOSS:  tensor(0.9483, grad_fn=<AddBackward0>)
# EPOCH:  158  LOSS:  tensor(0.9332, grad_fn=<AddBackward0>)
# EPOCH:  159  LOSS:  tensor(0.9185, grad_fn=<AddBackward0>)
# EPOCH:  160  LOSS:  tensor(0.9044, grad_fn=<AddBackward0>)
# EPOCH:  161  LOSS:  tensor(0.8905, grad_fn=<AddBackward0>)
# EPOCH:  162  LOSS:  tensor(0.8769, grad_fn=<AddBackward0>)
# EPOCH:  163  LOSS:  tensor(0.8638, grad_fn=<AddBackward0>)
# EPOCH:  164  LOSS:  tensor(0.8508, grad_fn=<AddBackward0>)
# EPOCH:  165  LOSS:  tensor(0.8382, grad_fn=<AddBackward0>)
# EPOCH:  166  LOSS:  tensor(0.8260, grad_fn=<AddBackward0>)
# EPOCH:  167  LOSS:  tensor(0.8146, grad_fn=<AddBackward0>)
# EPOCH:  168  LOSS:  tensor(0.8030, grad_fn=<AddBackward0>)
# EPOCH:  169  LOSS:  tensor(0.7918, grad_fn=<AddBackward0>)
# EPOCH:  170  LOSS:  tensor(0.7809, grad_fn=<AddBackward0>)
# EPOCH:  171  LOSS:  tensor(0.7700, grad_fn=<AddBackward0>)
# EPOCH:  172  LOSS:  tensor(0.7597, grad_fn=<AddBackward0>)
# EPOCH:  173  LOSS:  tensor(0.7497, grad_fn=<AddBackward0>)
# EPOCH:  174  LOSS:  tensor(0.7401, grad_fn=<AddBackward0>)
# EPOCH:  175  LOSS:  tensor(0.7299, grad_fn=<AddBackward0>)
# EPOCH:  176  LOSS:  tensor(0.7206, grad_fn=<AddBackward0>)
# EPOCH:  177  LOSS:  tensor(0.7113, grad_fn=<AddBackward0>)
# EPOCH:  178  LOSS:  tensor(0.7024, grad_fn=<AddBackward0>)
# EPOCH:  179  LOSS:  tensor(0.6934, grad_fn=<AddBackward0>)
# EPOCH:  180  LOSS:  tensor(0.6849, grad_fn=<AddBackward0>)
# EPOCH:  181  LOSS:  tensor(0.6766, grad_fn=<AddBackward0>)
# EPOCH:  182  LOSS:  tensor(0.6687, grad_fn=<AddBackward0>)
# EPOCH:  183  LOSS:  tensor(0.6608, grad_fn=<AddBackward0>)
# EPOCH:  184  LOSS:  tensor(0.6534, grad_fn=<AddBackward0>)
# EPOCH:  185  LOSS:  tensor(0.6455, grad_fn=<AddBackward0>)
# EPOCH:  186  LOSS:  tensor(0.6381, grad_fn=<AddBackward0>)
# EPOCH:  187  LOSS:  tensor(0.6311, grad_fn=<AddBackward0>)
# EPOCH:  188  LOSS:  tensor(0.6241, grad_fn=<AddBackward0>)
# EPOCH:  189  LOSS:  tensor(0.6173, grad_fn=<AddBackward0>)
# EPOCH:  190  LOSS:  tensor(0.6107, grad_fn=<AddBackward0>)
# EPOCH:  191  LOSS:  tensor(0.6040, grad_fn=<AddBackward0>)
# EPOCH:  192  LOSS:  tensor(0.5976, grad_fn=<AddBackward0>)
# EPOCH:  193  LOSS:  tensor(0.5916, grad_fn=<AddBackward0>)
# EPOCH:  194  LOSS:  tensor(0.5852, grad_fn=<AddBackward0>)
# EPOCH:  195  LOSS:  tensor(0.5792, grad_fn=<AddBackward0>)
# EPOCH:  196  LOSS:  tensor(0.5733, grad_fn=<AddBackward0>)
# EPOCH:  197  LOSS:  tensor(0.5676, grad_fn=<AddBackward0>)
# EPOCH:  198  LOSS:  tensor(0.5621, grad_fn=<AddBackward0>)
# EPOCH:  199  LOSS:  tensor(0.5565, grad_fn=<AddBackward0>)
# EPOCH:  200  LOSS:  tensor(0.5510, grad_fn=<AddBackward0>)
# EPOCH:  201  LOSS:  tensor(0.5451, grad_fn=<AddBackward0>)
# EPOCH:  202  LOSS:  tensor(0.5391, grad_fn=<AddBackward0>)
# EPOCH:  203  LOSS:  tensor(0.5334, grad_fn=<AddBackward0>)
# EPOCH:  204  LOSS:  tensor(0.5273, grad_fn=<AddBackward0>)
# EPOCH:  205  LOSS:  tensor(0.5217, grad_fn=<AddBackward0>)
# EPOCH:  206  LOSS:  tensor(0.5158, grad_fn=<AddBackward0>)
# EPOCH:  207  LOSS:  tensor(0.5104, grad_fn=<AddBackward0>)
# EPOCH:  208  LOSS:  tensor(0.5051, grad_fn=<AddBackward0>)
# EPOCH:  209  LOSS:  tensor(0.4998, grad_fn=<AddBackward0>)
# EPOCH:  210  LOSS:  tensor(0.4946, grad_fn=<AddBackward0>)
# EPOCH:  211  LOSS:  tensor(0.4894, grad_fn=<AddBackward0>)
# EPOCH:  212  LOSS:  tensor(0.4845, grad_fn=<AddBackward0>)
# EPOCH:  213  LOSS:  tensor(0.4795, grad_fn=<AddBackward0>)
# EPOCH:  214  LOSS:  tensor(0.4746, grad_fn=<AddBackward0>)
# EPOCH:  215  LOSS:  tensor(0.4698, grad_fn=<AddBackward0>)
# EPOCH:  216  LOSS:  tensor(0.4653, grad_fn=<AddBackward0>)
# EPOCH:  217  LOSS:  tensor(0.4609, grad_fn=<AddBackward0>)
# EPOCH:  218  LOSS:  tensor(0.4562, grad_fn=<AddBackward0>)
# EPOCH:  219  LOSS:  tensor(0.4520, grad_fn=<AddBackward0>)
# EPOCH:  220  LOSS:  tensor(0.4478, grad_fn=<AddBackward0>)
# EPOCH:  221  LOSS:  tensor(0.4437, grad_fn=<AddBackward0>)
# EPOCH:  222  LOSS:  tensor(0.4395, grad_fn=<AddBackward0>)
# EPOCH:  223  LOSS:  tensor(0.4355, grad_fn=<AddBackward0>)
# EPOCH:  224  LOSS:  tensor(0.4315, grad_fn=<AddBackward0>)
# EPOCH:  225  LOSS:  tensor(0.4277, grad_fn=<AddBackward0>)
# EPOCH:  226  LOSS:  tensor(0.4239, grad_fn=<AddBackward0>)
# EPOCH:  227  LOSS:  tensor(0.4201, grad_fn=<AddBackward0>)
# EPOCH:  228  LOSS:  tensor(0.4165, grad_fn=<AddBackward0>)
# EPOCH:  229  LOSS:  tensor(0.4128, grad_fn=<AddBackward0>)
# EPOCH:  230  LOSS:  tensor(0.4092, grad_fn=<AddBackward0>)
# EPOCH:  231  LOSS:  tensor(0.4057, grad_fn=<AddBackward0>)
# EPOCH:  232  LOSS:  tensor(0.4022, grad_fn=<AddBackward0>)
# EPOCH:  233  LOSS:  tensor(0.3987, grad_fn=<AddBackward0>)
# EPOCH:  234  LOSS:  tensor(0.3953, grad_fn=<AddBackward0>)
# EPOCH:  235  LOSS:  tensor(0.3919, grad_fn=<AddBackward0>)
# EPOCH:  236  LOSS:  tensor(0.3887, grad_fn=<AddBackward0>)
# EPOCH:  237  LOSS:  tensor(0.3854, grad_fn=<AddBackward0>)
# EPOCH:  238  LOSS:  tensor(0.3825, grad_fn=<AddBackward0>)
# EPOCH:  239  LOSS:  tensor(0.3793, grad_fn=<AddBackward0>)
# EPOCH:  240  LOSS:  tensor(0.3762, grad_fn=<AddBackward0>)
# EPOCH:  241  LOSS:  tensor(0.3733, grad_fn=<AddBackward0>)
# EPOCH:  242  LOSS:  tensor(0.3703, grad_fn=<AddBackward0>)
# EPOCH:  243  LOSS:  tensor(0.3673, grad_fn=<AddBackward0>)
# EPOCH:  244  LOSS:  tensor(0.3645, grad_fn=<AddBackward0>)
# EPOCH:  245  LOSS:  tensor(0.3616, grad_fn=<AddBackward0>)
# EPOCH:  246  LOSS:  tensor(0.3587, grad_fn=<AddBackward0>)
# EPOCH:  247  LOSS:  tensor(0.3558, grad_fn=<AddBackward0>)
# EPOCH:  248  LOSS:  tensor(0.3531, grad_fn=<AddBackward0>)
# EPOCH:  249  LOSS:  tensor(0.3505, grad_fn=<AddBackward0>)
# EPOCH:  250  LOSS:  tensor(0.3475, grad_fn=<AddBackward0>)
# EPOCH:  251  LOSS:  tensor(0.3448, grad_fn=<AddBackward0>)
# EPOCH:  252  LOSS:  tensor(0.3423, grad_fn=<AddBackward0>)
# EPOCH:  253  LOSS:  tensor(0.3396, grad_fn=<AddBackward0>)
# EPOCH:  254  LOSS:  tensor(0.3371, grad_fn=<AddBackward0>)
# EPOCH:  255  LOSS:  tensor(0.3345, grad_fn=<AddBackward0>)
# EPOCH:  256  LOSS:  tensor(0.3320, grad_fn=<AddBackward0>)
# EPOCH:  257  LOSS:  tensor(0.3294, grad_fn=<AddBackward0>)
# EPOCH:  258  LOSS:  tensor(0.3270, grad_fn=<AddBackward0>)
# EPOCH:  259  LOSS:  tensor(0.3244, grad_fn=<AddBackward0>)
# EPOCH:  260  LOSS:  tensor(0.3220, grad_fn=<AddBackward0>)
# EPOCH:  261  LOSS:  tensor(0.3196, grad_fn=<AddBackward0>)
# EPOCH:  262  LOSS:  tensor(0.3172, grad_fn=<AddBackward0>)
# EPOCH:  263  LOSS:  tensor(0.3146, grad_fn=<AddBackward0>)
# EPOCH:  264  LOSS:  tensor(0.3124, grad_fn=<AddBackward0>)
# EPOCH:  265  LOSS:  tensor(0.3099, grad_fn=<AddBackward0>)
# EPOCH:  266  LOSS:  tensor(0.3077, grad_fn=<AddBackward0>)
# EPOCH:  267  LOSS:  tensor(0.3053, grad_fn=<AddBackward0>)
# EPOCH:  268  LOSS:  tensor(0.3030, grad_fn=<AddBackward0>)
# EPOCH:  269  LOSS:  tensor(0.3009, grad_fn=<AddBackward0>)
# EPOCH:  270  LOSS:  tensor(0.2988, grad_fn=<AddBackward0>)
# EPOCH:  271  LOSS:  tensor(0.2967, grad_fn=<AddBackward0>)
# EPOCH:  272  LOSS:  tensor(0.2945, grad_fn=<AddBackward0>)
# EPOCH:  273  LOSS:  tensor(0.2926, grad_fn=<AddBackward0>)
# EPOCH:  274  LOSS:  tensor(0.2906, grad_fn=<AddBackward0>)
# EPOCH:  275  LOSS:  tensor(0.2886, grad_fn=<AddBackward0>)
# EPOCH:  276  LOSS:  tensor(0.2866, grad_fn=<AddBackward0>)
# EPOCH:  277  LOSS:  tensor(0.2847, grad_fn=<AddBackward0>)
# EPOCH:  278  LOSS:  tensor(0.2826, grad_fn=<AddBackward0>)
# EPOCH:  279  LOSS:  tensor(0.2808, grad_fn=<AddBackward0>)
# EPOCH:  280  LOSS:  tensor(0.2789, grad_fn=<AddBackward0>)
# EPOCH:  281  LOSS:  tensor(0.2771, grad_fn=<AddBackward0>)
# EPOCH:  282  LOSS:  tensor(0.2753, grad_fn=<AddBackward0>)
# EPOCH:  283  LOSS:  tensor(0.2736, grad_fn=<AddBackward0>)
# EPOCH:  284  LOSS:  tensor(0.2718, grad_fn=<AddBackward0>)
# EPOCH:  285  LOSS:  tensor(0.2702, grad_fn=<AddBackward0>)
# EPOCH:  286  LOSS:  tensor(0.2685, grad_fn=<AddBackward0>)
# EPOCH:  287  LOSS:  tensor(0.2668, grad_fn=<AddBackward0>)
# EPOCH:  288  LOSS:  tensor(0.2652, grad_fn=<AddBackward0>)
# EPOCH:  289  LOSS:  tensor(0.2635, grad_fn=<AddBackward0>)
# EPOCH:  290  LOSS:  tensor(0.2619, grad_fn=<AddBackward0>)
# EPOCH:  291  LOSS:  tensor(0.2603, grad_fn=<AddBackward0>)
# EPOCH:  292  LOSS:  tensor(0.2587, grad_fn=<AddBackward0>)
# EPOCH:  293  LOSS:  tensor(0.2572, grad_fn=<AddBackward0>)
# EPOCH:  294  LOSS:  tensor(0.2556, grad_fn=<AddBackward0>)
# EPOCH:  295  LOSS:  tensor(0.2541, grad_fn=<AddBackward0>)
# EPOCH:  296  LOSS:  tensor(0.2525, grad_fn=<AddBackward0>)
# EPOCH:  297  LOSS:  tensor(0.2510, grad_fn=<AddBackward0>)
# EPOCH:  298  LOSS:  tensor(0.2495, grad_fn=<AddBackward0>)
# EPOCH:  299  LOSS:  tensor(0.2480, grad_fn=<AddBackward0>)
# EPOCH:  300  LOSS:  tensor(0.2467, grad_fn=<AddBackward0>)
# EPOCH:  301  LOSS:  tensor(0.2452, grad_fn=<AddBackward0>)
# EPOCH:  302  LOSS:  tensor(0.2438, grad_fn=<AddBackward0>)
# EPOCH:  303  LOSS:  tensor(0.2425, grad_fn=<AddBackward0>)
# EPOCH:  304  LOSS:  tensor(0.2411, grad_fn=<AddBackward0>)
# EPOCH:  305  LOSS:  tensor(0.2397, grad_fn=<AddBackward0>)
# EPOCH:  306  LOSS:  tensor(0.2385, grad_fn=<AddBackward0>)
# EPOCH:  307  LOSS:  tensor(0.2371, grad_fn=<AddBackward0>)
# EPOCH:  308  LOSS:  tensor(0.2358, grad_fn=<AddBackward0>)
# EPOCH:  309  LOSS:  tensor(0.2346, grad_fn=<AddBackward0>)
# EPOCH:  310  LOSS:  tensor(0.2334, grad_fn=<AddBackward0>)
# EPOCH:  311  LOSS:  tensor(0.2321, grad_fn=<AddBackward0>)
# EPOCH:  312  LOSS:  tensor(0.2310, grad_fn=<AddBackward0>)
# EPOCH:  313  LOSS:  tensor(0.2298, grad_fn=<AddBackward0>)
# EPOCH:  314  LOSS:  tensor(0.2287, grad_fn=<AddBackward0>)
# EPOCH:  315  LOSS:  tensor(0.2276, grad_fn=<AddBackward0>)
# EPOCH:  316  LOSS:  tensor(0.2264, grad_fn=<AddBackward0>)
# EPOCH:  317  LOSS:  tensor(0.2252, grad_fn=<AddBackward0>)
# EPOCH:  318  LOSS:  tensor(0.2242, grad_fn=<AddBackward0>)
# EPOCH:  319  LOSS:  tensor(0.2232, grad_fn=<AddBackward0>)
# EPOCH:  320  LOSS:  tensor(0.2220, grad_fn=<AddBackward0>)
# EPOCH:  321  LOSS:  tensor(0.2210, grad_fn=<AddBackward0>)
# EPOCH:  322  LOSS:  tensor(0.2200, grad_fn=<AddBackward0>)
# EPOCH:  323  LOSS:  tensor(0.2189, grad_fn=<AddBackward0>)
# EPOCH:  324  LOSS:  tensor(0.2178, grad_fn=<AddBackward0>)
# EPOCH:  325  LOSS:  tensor(0.2168, grad_fn=<AddBackward0>)
# EPOCH:  326  LOSS:  tensor(0.2158, grad_fn=<AddBackward0>)
# EPOCH:  327  LOSS:  tensor(0.2148, grad_fn=<AddBackward0>)
# EPOCH:  328  LOSS:  tensor(0.2139, grad_fn=<AddBackward0>)
# EPOCH:  329  LOSS:  tensor(0.2128, grad_fn=<AddBackward0>)
# EPOCH:  330  LOSS:  tensor(0.2118, grad_fn=<AddBackward0>)
# EPOCH:  331  LOSS:  tensor(0.2108, grad_fn=<AddBackward0>)
# EPOCH:  332  LOSS:  tensor(0.2098, grad_fn=<AddBackward0>)
# EPOCH:  333  LOSS:  tensor(0.2087, grad_fn=<AddBackward0>)
# EPOCH:  334  LOSS:  tensor(0.2076, grad_fn=<AddBackward0>)
# EPOCH:  335  LOSS:  tensor(0.2066, grad_fn=<AddBackward0>)
# EPOCH:  336  LOSS:  tensor(0.2056, grad_fn=<AddBackward0>)
# EPOCH:  337  LOSS:  tensor(0.2046, grad_fn=<AddBackward0>)
# EPOCH:  338  LOSS:  tensor(0.2036, grad_fn=<AddBackward0>)
# EPOCH:  339  LOSS:  tensor(0.2026, grad_fn=<AddBackward0>)
# EPOCH:  340  LOSS:  tensor(0.2018, grad_fn=<AddBackward0>)
# EPOCH:  341  LOSS:  tensor(0.2010, grad_fn=<AddBackward0>)
# EPOCH:  342  LOSS:  tensor(0.2001, grad_fn=<AddBackward0>)
# EPOCH:  343  LOSS:  tensor(0.1994, grad_fn=<AddBackward0>)
# EPOCH:  344  LOSS:  tensor(0.1987, grad_fn=<AddBackward0>)
# EPOCH:  345  LOSS:  tensor(0.1979, grad_fn=<AddBackward0>)
# EPOCH:  346  LOSS:  tensor(0.1971, grad_fn=<AddBackward0>)
# EPOCH:  347  LOSS:  tensor(0.1964, grad_fn=<AddBackward0>)
# EPOCH:  348  LOSS:  tensor(0.1956, grad_fn=<AddBackward0>)
# EPOCH:  349  LOSS:  tensor(0.1949, grad_fn=<AddBackward0>)
# EPOCH:  350  LOSS:  tensor(0.1943, grad_fn=<AddBackward0>)
# EPOCH:  351  LOSS:  tensor(0.1936, grad_fn=<AddBackward0>)
# EPOCH:  352  LOSS:  tensor(0.1929, grad_fn=<AddBackward0>)
# EPOCH:  353  LOSS:  tensor(0.1921, grad_fn=<AddBackward0>)
# EPOCH:  354  LOSS:  tensor(0.1915, grad_fn=<AddBackward0>)
# EPOCH:  355  LOSS:  tensor(0.1908, grad_fn=<AddBackward0>)
# EPOCH:  356  LOSS:  tensor(0.1901, grad_fn=<AddBackward0>)
# EPOCH:  357  LOSS:  tensor(0.1895, grad_fn=<AddBackward0>)
# EPOCH:  358  LOSS:  tensor(0.1890, grad_fn=<AddBackward0>)
# EPOCH:  359  LOSS:  tensor(0.1882, grad_fn=<AddBackward0>)
# EPOCH:  360  LOSS:  tensor(0.1876, grad_fn=<AddBackward0>)
# EPOCH:  361  LOSS:  tensor(0.1869, grad_fn=<AddBackward0>)
# EPOCH:  362  LOSS:  tensor(0.1863, grad_fn=<AddBackward0>)
# EPOCH:  363  LOSS:  tensor(0.1856, grad_fn=<AddBackward0>)
# EPOCH:  364  LOSS:  tensor(0.1850, grad_fn=<AddBackward0>)
# EPOCH:  365  LOSS:  tensor(0.1844, grad_fn=<AddBackward0>)
# EPOCH:  366  LOSS:  tensor(0.1837, grad_fn=<AddBackward0>)
# EPOCH:  367  LOSS:  tensor(0.1832, grad_fn=<AddBackward0>)
# EPOCH:  368  LOSS:  tensor(0.1826, grad_fn=<AddBackward0>)
# EPOCH:  369  LOSS:  tensor(0.1820, grad_fn=<AddBackward0>)
# EPOCH:  370  LOSS:  tensor(0.1814, grad_fn=<AddBackward0>)
# EPOCH:  371  LOSS:  tensor(0.1809, grad_fn=<AddBackward0>)
# EPOCH:  372  LOSS:  tensor(0.1803, grad_fn=<AddBackward0>)
# EPOCH:  373  LOSS:  tensor(0.1798, grad_fn=<AddBackward0>)
# EPOCH:  374  LOSS:  tensor(0.1792, grad_fn=<AddBackward0>)
# EPOCH:  375  LOSS:  tensor(0.1786, grad_fn=<AddBackward0>)
# EPOCH:  376  LOSS:  tensor(0.1781, grad_fn=<AddBackward0>)
# EPOCH:  377  LOSS:  tensor(0.1776, grad_fn=<AddBackward0>)
# EPOCH:  378  LOSS:  tensor(0.1771, grad_fn=<AddBackward0>)
# EPOCH:  379  LOSS:  tensor(0.1765, grad_fn=<AddBackward0>)
# EPOCH:  380  LOSS:  tensor(0.1760, grad_fn=<AddBackward0>)
# EPOCH:  381  LOSS:  tensor(0.1755, grad_fn=<AddBackward0>)
# EPOCH:  382  LOSS:  tensor(0.1750, grad_fn=<AddBackward0>)
# EPOCH:  383  LOSS:  tensor(0.1745, grad_fn=<AddBackward0>)
# EPOCH:  384  LOSS:  tensor(0.1741, grad_fn=<AddBackward0>)
# EPOCH:  385  LOSS:  tensor(0.1736, grad_fn=<AddBackward0>)
# EPOCH:  386  LOSS:  tensor(0.1731, grad_fn=<AddBackward0>)
# EPOCH:  387  LOSS:  tensor(0.1726, grad_fn=<AddBackward0>)
# EPOCH:  388  LOSS:  tensor(0.1721, grad_fn=<AddBackward0>)
# EPOCH:  389  LOSS:  tensor(0.1717, grad_fn=<AddBackward0>)
# EPOCH:  390  LOSS:  tensor(0.1712, grad_fn=<AddBackward0>)
# EPOCH:  391  LOSS:  tensor(0.1707, grad_fn=<AddBackward0>)
# EPOCH:  392  LOSS:  tensor(0.1703, grad_fn=<AddBackward0>)
# EPOCH:  393  LOSS:  tensor(0.1698, grad_fn=<AddBackward0>)
# EPOCH:  394  LOSS:  tensor(0.1694, grad_fn=<AddBackward0>)
# EPOCH:  395  LOSS:  tensor(0.1689, grad_fn=<AddBackward0>)
# EPOCH:  396  LOSS:  tensor(0.1685, grad_fn=<AddBackward0>)
# EPOCH:  397  LOSS:  tensor(0.1681, grad_fn=<AddBackward0>)
# EPOCH:  398  LOSS:  tensor(0.1676, grad_fn=<AddBackward0>)
# EPOCH:  399  LOSS:  tensor(0.1672, grad_fn=<AddBackward0>)
# EPOCH:  400  LOSS:  tensor(0.1668, grad_fn=<AddBackward0>)
# EPOCH:  401  LOSS:  tensor(0.1664, grad_fn=<AddBackward0>)
# EPOCH:  402  LOSS:  tensor(0.1660, grad_fn=<AddBackward0>)
# EPOCH:  403  LOSS:  tensor(0.1656, grad_fn=<AddBackward0>)
# EPOCH:  404  LOSS:  tensor(0.1651, grad_fn=<AddBackward0>)
# EPOCH:  405  LOSS:  tensor(0.1648, grad_fn=<AddBackward0>)
# EPOCH:  406  LOSS:  tensor(0.1645, grad_fn=<AddBackward0>)
# EPOCH:  407  LOSS:  tensor(0.1640, grad_fn=<AddBackward0>)
# EPOCH:  408  LOSS:  tensor(0.1636, grad_fn=<AddBackward0>)
# EPOCH:  409  LOSS:  tensor(0.1633, grad_fn=<AddBackward0>)
# EPOCH:  410  LOSS:  tensor(0.1629, grad_fn=<AddBackward0>)
# EPOCH:  411  LOSS:  tensor(0.1625, grad_fn=<AddBackward0>)
# EPOCH:  412  LOSS:  tensor(0.1621, grad_fn=<AddBackward0>)
# EPOCH:  413  LOSS:  tensor(0.1617, grad_fn=<AddBackward0>)
# EPOCH:  414  LOSS:  tensor(0.1613, grad_fn=<AddBackward0>)
# EPOCH:  415  LOSS:  tensor(0.1610, grad_fn=<AddBackward0>)
# EPOCH:  416  LOSS:  tensor(0.1606, grad_fn=<AddBackward0>)
# EPOCH:  417  LOSS:  tensor(0.1602, grad_fn=<AddBackward0>)
# EPOCH:  418  LOSS:  tensor(0.1599, grad_fn=<AddBackward0>)
# EPOCH:  419  LOSS:  tensor(0.1595, grad_fn=<AddBackward0>)
# EPOCH:  420  LOSS:  tensor(0.1591, grad_fn=<AddBackward0>)
# EPOCH:  421  LOSS:  tensor(0.1587, grad_fn=<AddBackward0>)
# EPOCH:  422  LOSS:  tensor(0.1584, grad_fn=<AddBackward0>)
# EPOCH:  423  LOSS:  tensor(0.1581, grad_fn=<AddBackward0>)
# EPOCH:  424  LOSS:  tensor(0.1577, grad_fn=<AddBackward0>)
# EPOCH:  425  LOSS:  tensor(0.1573, grad_fn=<AddBackward0>)
# EPOCH:  426  LOSS:  tensor(0.1571, grad_fn=<AddBackward0>)
# EPOCH:  427  LOSS:  tensor(0.1566, grad_fn=<AddBackward0>)
# EPOCH:  428  LOSS:  tensor(0.1563, grad_fn=<AddBackward0>)
# EPOCH:  429  LOSS:  tensor(0.1560, grad_fn=<AddBackward0>)
# EPOCH:  430  LOSS:  tensor(0.1556, grad_fn=<AddBackward0>)
# EPOCH:  431  LOSS:  tensor(0.1553, grad_fn=<AddBackward0>)
# EPOCH:  432  LOSS:  tensor(0.1550, grad_fn=<AddBackward0>)
# EPOCH:  433  LOSS:  tensor(0.1547, grad_fn=<AddBackward0>)
# EPOCH:  434  LOSS:  tensor(0.1544, grad_fn=<AddBackward0>)
# EPOCH:  435  LOSS:  tensor(0.1541, grad_fn=<AddBackward0>)
# EPOCH:  436  LOSS:  tensor(0.1538, grad_fn=<AddBackward0>)
# EPOCH:  437  LOSS:  tensor(0.1536, grad_fn=<AddBackward0>)
# EPOCH:  438  LOSS:  tensor(0.1532, grad_fn=<AddBackward0>)
# EPOCH:  439  LOSS:  tensor(0.1529, grad_fn=<AddBackward0>)
# EPOCH:  440  LOSS:  tensor(0.1526, grad_fn=<AddBackward0>)
# EPOCH:  441  LOSS:  tensor(0.1522, grad_fn=<AddBackward0>)
# EPOCH:  442  LOSS:  tensor(0.1519, grad_fn=<AddBackward0>)
# EPOCH:  443  LOSS:  tensor(0.1516, grad_fn=<AddBackward0>)
# EPOCH:  444  LOSS:  tensor(0.1513, grad_fn=<AddBackward0>)
# EPOCH:  445  LOSS:  tensor(0.1510, grad_fn=<AddBackward0>)
# EPOCH:  446  LOSS:  tensor(0.1507, grad_fn=<AddBackward0>)
# EPOCH:  447  LOSS:  tensor(0.1504, grad_fn=<AddBackward0>)
# EPOCH:  448  LOSS:  tensor(0.1500, grad_fn=<AddBackward0>)
# EPOCH:  449  LOSS:  tensor(0.1498, grad_fn=<AddBackward0>)
# EPOCH:  450  LOSS:  tensor(0.1495, grad_fn=<AddBackward0>)
# EPOCH:  451  LOSS:  tensor(0.1492, grad_fn=<AddBackward0>)
# EPOCH:  452  LOSS:  tensor(0.1489, grad_fn=<AddBackward0>)
# EPOCH:  453  LOSS:  tensor(0.1486, grad_fn=<AddBackward0>)
# EPOCH:  454  LOSS:  tensor(0.1483, grad_fn=<AddBackward0>)
# EPOCH:  455  LOSS:  tensor(0.1480, grad_fn=<AddBackward0>)
# EPOCH:  456  LOSS:  tensor(0.1477, grad_fn=<AddBackward0>)
# EPOCH:  457  LOSS:  tensor(0.1474, grad_fn=<AddBackward0>)
# EPOCH:  458  LOSS:  tensor(0.1471, grad_fn=<AddBackward0>)
# EPOCH:  459  LOSS:  tensor(0.1468, grad_fn=<AddBackward0>)
# EPOCH:  460  LOSS:  tensor(0.1466, grad_fn=<AddBackward0>)
# EPOCH:  461  LOSS:  tensor(0.1463, grad_fn=<AddBackward0>)
# EPOCH:  462  LOSS:  tensor(0.1461, grad_fn=<AddBackward0>)
# EPOCH:  463  LOSS:  tensor(0.1458, grad_fn=<AddBackward0>)
# EPOCH:  464  LOSS:  tensor(0.1455, grad_fn=<AddBackward0>)
# EPOCH:  465  LOSS:  tensor(0.1452, grad_fn=<AddBackward0>)
# EPOCH:  466  LOSS:  tensor(0.1450, grad_fn=<AddBackward0>)
# EPOCH:  467  LOSS:  tensor(0.1448, grad_fn=<AddBackward0>)
# EPOCH:  468  LOSS:  tensor(0.1445, grad_fn=<AddBackward0>)
# EPOCH:  469  LOSS:  tensor(0.1442, grad_fn=<AddBackward0>)
# EPOCH:  470  LOSS:  tensor(0.1439, grad_fn=<AddBackward0>)
# EPOCH:  471  LOSS:  tensor(0.1437, grad_fn=<AddBackward0>)
# EPOCH:  472  LOSS:  tensor(0.1435, grad_fn=<AddBackward0>)
# EPOCH:  473  LOSS:  tensor(0.1432, grad_fn=<AddBackward0>)
# EPOCH:  474  LOSS:  tensor(0.1430, grad_fn=<AddBackward0>)
# EPOCH:  475  LOSS:  tensor(0.1428, grad_fn=<AddBackward0>)
# EPOCH:  476  LOSS:  tensor(0.1425, grad_fn=<AddBackward0>)
# EPOCH:  477  LOSS:  tensor(0.1423, grad_fn=<AddBackward0>)
# EPOCH:  478  LOSS:  tensor(0.1420, grad_fn=<AddBackward0>)
# EPOCH:  479  LOSS:  tensor(0.1418, grad_fn=<AddBackward0>)
# EPOCH:  480  LOSS:  tensor(0.1416, grad_fn=<AddBackward0>)
# EPOCH:  481  LOSS:  tensor(0.1413, grad_fn=<AddBackward0>)
# EPOCH:  482  LOSS:  tensor(0.1411, grad_fn=<AddBackward0>)
# EPOCH:  483  LOSS:  tensor(0.1408, grad_fn=<AddBackward0>)
# EPOCH:  484  LOSS:  tensor(0.1406, grad_fn=<AddBackward0>)
# EPOCH:  485  LOSS:  tensor(0.1403, grad_fn=<AddBackward0>)
# EPOCH:  486  LOSS:  tensor(0.1401, grad_fn=<AddBackward0>)
# EPOCH:  487  LOSS:  tensor(0.1399, grad_fn=<AddBackward0>)
# EPOCH:  488  LOSS:  tensor(0.1396, grad_fn=<AddBackward0>)
# EPOCH:  489  LOSS:  tensor(0.1394, grad_fn=<AddBackward0>)
# EPOCH:  490  LOSS:  tensor(0.1392, grad_fn=<AddBackward0>)
# EPOCH:  491  LOSS:  tensor(0.1390, grad_fn=<AddBackward0>)
# EPOCH:  492  LOSS:  tensor(0.1388, grad_fn=<AddBackward0>)
# EPOCH:  493  LOSS:  tensor(0.1385, grad_fn=<AddBackward0>)
# EPOCH:  494  LOSS:  tensor(0.1383, grad_fn=<AddBackward0>)
# EPOCH:  495  LOSS:  tensor(0.1381, grad_fn=<AddBackward0>)
# EPOCH:  496  LOSS:  tensor(0.1378, grad_fn=<AddBackward0>)
# EPOCH:  497  LOSS:  tensor(0.1376, grad_fn=<AddBackward0>)
# EPOCH:  498  LOSS:  tensor(0.1373, grad_fn=<AddBackward0>)
# EPOCH:  499  LOSS:  tensor(0.1371, grad_fn=<AddBackward0>)
# EPOCH:  500  LOSS:  tensor(0.1369, grad_fn=<AddBackward0>)
# EPOCH:  501  LOSS:  tensor(0.1367, grad_fn=<AddBackward0>)
# EPOCH:  502  LOSS:  tensor(0.1365, grad_fn=<AddBackward0>)
# EPOCH:  503  LOSS:  tensor(0.1363, grad_fn=<AddBackward0>)
# EPOCH:  504  LOSS:  tensor(0.1362, grad_fn=<AddBackward0>)
# EPOCH:  505  LOSS:  tensor(0.1360, grad_fn=<AddBackward0>)
# EPOCH:  506  LOSS:  tensor(0.1358, grad_fn=<AddBackward0>)
# EPOCH:  507  LOSS:  tensor(0.1356, grad_fn=<AddBackward0>)
# EPOCH:  508  LOSS:  tensor(0.1354, grad_fn=<AddBackward0>)
# EPOCH:  509  LOSS:  tensor(0.1352, grad_fn=<AddBackward0>)
# EPOCH:  510  LOSS:  tensor(0.1350, grad_fn=<AddBackward0>)
# EPOCH:  511  LOSS:  tensor(0.1348, grad_fn=<AddBackward0>)
# EPOCH:  512  LOSS:  tensor(0.1347, grad_fn=<AddBackward0>)
# EPOCH:  513  LOSS:  tensor(0.1345, grad_fn=<AddBackward0>)
# EPOCH:  514  LOSS:  tensor(0.1343, grad_fn=<AddBackward0>)
# EPOCH:  515  LOSS:  tensor(0.1341, grad_fn=<AddBackward0>)
# EPOCH:  516  LOSS:  tensor(0.1339, grad_fn=<AddBackward0>)
# EPOCH:  517  LOSS:  tensor(0.1338, grad_fn=<AddBackward0>)
# EPOCH:  518  LOSS:  tensor(0.1336, grad_fn=<AddBackward0>)
# EPOCH:  519  LOSS:  tensor(0.1334, grad_fn=<AddBackward0>)
# EPOCH:  520  LOSS:  tensor(0.1333, grad_fn=<AddBackward0>)
# EPOCH:  521  LOSS:  tensor(0.1331, grad_fn=<AddBackward0>)
# EPOCH:  522  LOSS:  tensor(0.1329, grad_fn=<AddBackward0>)
# EPOCH:  523  LOSS:  tensor(0.1327, grad_fn=<AddBackward0>)
# EPOCH:  524  LOSS:  tensor(0.1326, grad_fn=<AddBackward0>)
# EPOCH:  525  LOSS:  tensor(0.1324, grad_fn=<AddBackward0>)
# EPOCH:  526  LOSS:  tensor(0.1322, grad_fn=<AddBackward0>)
# EPOCH:  527  LOSS:  tensor(0.1320, grad_fn=<AddBackward0>)
# EPOCH:  528  LOSS:  tensor(0.1319, grad_fn=<AddBackward0>)
# EPOCH:  529  LOSS:  tensor(0.1317, grad_fn=<AddBackward0>)
# EPOCH:  530  LOSS:  tensor(0.1315, grad_fn=<AddBackward0>)
# EPOCH:  531  LOSS:  tensor(0.1314, grad_fn=<AddBackward0>)
# EPOCH:  532  LOSS:  tensor(0.1312, grad_fn=<AddBackward0>)
# EPOCH:  533  LOSS:  tensor(0.1310, grad_fn=<AddBackward0>)
# EPOCH:  534  LOSS:  tensor(0.1308, grad_fn=<AddBackward0>)
# EPOCH:  535  LOSS:  tensor(0.1307, grad_fn=<AddBackward0>)
# EPOCH:  536  LOSS:  tensor(0.1305, grad_fn=<AddBackward0>)
# EPOCH:  537  LOSS:  tensor(0.1303, grad_fn=<AddBackward0>)
# EPOCH:  538  LOSS:  tensor(0.1302, grad_fn=<AddBackward0>)
# EPOCH:  539  LOSS:  tensor(0.1300, grad_fn=<AddBackward0>)
# EPOCH:  540  LOSS:  tensor(0.1299, grad_fn=<AddBackward0>)
# EPOCH:  541  LOSS:  tensor(0.1297, grad_fn=<AddBackward0>)
# EPOCH:  542  LOSS:  tensor(0.1295, grad_fn=<AddBackward0>)
# EPOCH:  543  LOSS:  tensor(0.1294, grad_fn=<AddBackward0>)
# EPOCH:  544  LOSS:  tensor(0.1292, grad_fn=<AddBackward0>)
# EPOCH:  545  LOSS:  tensor(0.1290, grad_fn=<AddBackward0>)
# EPOCH:  546  LOSS:  tensor(0.1289, grad_fn=<AddBackward0>)
# EPOCH:  547  LOSS:  tensor(0.1287, grad_fn=<AddBackward0>)
# EPOCH:  548  LOSS:  tensor(0.1285, grad_fn=<AddBackward0>)
# EPOCH:  549  LOSS:  tensor(0.1284, grad_fn=<AddBackward0>)
# EPOCH:  550  LOSS:  tensor(0.1282, grad_fn=<AddBackward0>)
# EPOCH:  551  LOSS:  tensor(0.1280, grad_fn=<AddBackward0>)
# EPOCH:  552  LOSS:  tensor(0.1279, grad_fn=<AddBackward0>)
# EPOCH:  553  LOSS:  tensor(0.1277, grad_fn=<AddBackward0>)
# EPOCH:  554  LOSS:  tensor(0.1276, grad_fn=<AddBackward0>)
# EPOCH:  555  LOSS:  tensor(0.1274, grad_fn=<AddBackward0>)
# EPOCH:  556  LOSS:  tensor(0.1273, grad_fn=<AddBackward0>)
# EPOCH:  557  LOSS:  tensor(0.1271, grad_fn=<AddBackward0>)
# EPOCH:  558  LOSS:  tensor(0.1270, grad_fn=<AddBackward0>)
# EPOCH:  559  LOSS:  tensor(0.1268, grad_fn=<AddBackward0>)
# EPOCH:  560  LOSS:  tensor(0.1267, grad_fn=<AddBackward0>)
# EPOCH:  561  LOSS:  tensor(0.1265, grad_fn=<AddBackward0>)
# EPOCH:  562  LOSS:  tensor(0.1264, grad_fn=<AddBackward0>)
# EPOCH:  563  LOSS:  tensor(0.1262, grad_fn=<AddBackward0>)
# EPOCH:  564  LOSS:  tensor(0.1260, grad_fn=<AddBackward0>)
# EPOCH:  565  LOSS:  tensor(0.1259, grad_fn=<AddBackward0>)
# EPOCH:  566  LOSS:  tensor(0.1257, grad_fn=<AddBackward0>)
# EPOCH:  567  LOSS:  tensor(0.1256, grad_fn=<AddBackward0>)
# EPOCH:  568  LOSS:  tensor(0.1255, grad_fn=<AddBackward0>)
# EPOCH:  569  LOSS:  tensor(0.1253, grad_fn=<AddBackward0>)
# EPOCH:  570  LOSS:  tensor(0.1252, grad_fn=<AddBackward0>)
# EPOCH:  571  LOSS:  tensor(0.1250, grad_fn=<AddBackward0>)
# EPOCH:  572  LOSS:  tensor(0.1249, grad_fn=<AddBackward0>)
# EPOCH:  573  LOSS:  tensor(0.1248, grad_fn=<AddBackward0>)
# EPOCH:  574  LOSS:  tensor(0.1246, grad_fn=<AddBackward0>)
# EPOCH:  575  LOSS:  tensor(0.1245, grad_fn=<AddBackward0>)
# EPOCH:  576  LOSS:  tensor(0.1244, grad_fn=<AddBackward0>)
# EPOCH:  577  LOSS:  tensor(0.1242, grad_fn=<AddBackward0>)
# EPOCH:  578  LOSS:  tensor(0.1241, grad_fn=<AddBackward0>)
# EPOCH:  579  LOSS:  tensor(0.1239, grad_fn=<AddBackward0>)
# EPOCH:  580  LOSS:  tensor(0.1238, grad_fn=<AddBackward0>)
# EPOCH:  581  LOSS:  tensor(0.1236, grad_fn=<AddBackward0>)
# EPOCH:  582  LOSS:  tensor(0.1235, grad_fn=<AddBackward0>)
# EPOCH:  583  LOSS:  tensor(0.1234, grad_fn=<AddBackward0>)
# EPOCH:  584  LOSS:  tensor(0.1232, grad_fn=<AddBackward0>)
# EPOCH:  585  LOSS:  tensor(0.1231, grad_fn=<AddBackward0>)
# EPOCH:  586  LOSS:  tensor(0.1229, grad_fn=<AddBackward0>)
# EPOCH:  587  LOSS:  tensor(0.1228, grad_fn=<AddBackward0>)
# EPOCH:  588  LOSS:  tensor(0.1226, grad_fn=<AddBackward0>)
# EPOCH:  589  LOSS:  tensor(0.1225, grad_fn=<AddBackward0>)
# EPOCH:  590  LOSS:  tensor(0.1223, grad_fn=<AddBackward0>)
# EPOCH:  591  LOSS:  tensor(0.1222, grad_fn=<AddBackward0>)
# EPOCH:  592  LOSS:  tensor(0.1220, grad_fn=<AddBackward0>)
# EPOCH:  593  LOSS:  tensor(0.1219, grad_fn=<AddBackward0>)
# EPOCH:  594  LOSS:  tensor(0.1217, grad_fn=<AddBackward0>)
# EPOCH:  595  LOSS:  tensor(0.1215, grad_fn=<AddBackward0>)
# EPOCH:  596  LOSS:  tensor(0.1214, grad_fn=<AddBackward0>)
# EPOCH:  597  LOSS:  tensor(0.1212, grad_fn=<AddBackward0>)
# EPOCH:  598  LOSS:  tensor(0.1211, grad_fn=<AddBackward0>)
# EPOCH:  599  LOSS:  tensor(0.1209, grad_fn=<AddBackward0>)
# EPOCH:  600  LOSS:  tensor(0.1207, grad_fn=<AddBackward0>)
# EPOCH:  601  LOSS:  tensor(0.1205, grad_fn=<AddBackward0>)
# EPOCH:  602  LOSS:  tensor(0.1203, grad_fn=<AddBackward0>)
# EPOCH:  603  LOSS:  tensor(0.1201, grad_fn=<AddBackward0>)
# EPOCH:  604  LOSS:  tensor(0.1199, grad_fn=<AddBackward0>)
# EPOCH:  605  LOSS:  tensor(0.1197, grad_fn=<AddBackward0>)
# EPOCH:  606  LOSS:  tensor(0.1194, grad_fn=<AddBackward0>)
# EPOCH:  607  LOSS:  tensor(0.1192, grad_fn=<AddBackward0>)
# EPOCH:  608  LOSS:  tensor(0.1191, grad_fn=<AddBackward0>)
# EPOCH:  609  LOSS:  tensor(0.1188, grad_fn=<AddBackward0>)
# EPOCH:  610  LOSS:  tensor(0.1186, grad_fn=<AddBackward0>)
# EPOCH:  611  LOSS:  tensor(0.1184, grad_fn=<AddBackward0>)
# EPOCH:  612  LOSS:  tensor(0.1182, grad_fn=<AddBackward0>)
# EPOCH:  613  LOSS:  tensor(0.1180, grad_fn=<AddBackward0>)
# EPOCH:  614  LOSS:  tensor(0.1178, grad_fn=<AddBackward0>)
# EPOCH:  615  LOSS:  tensor(0.1176, grad_fn=<AddBackward0>)
# EPOCH:  616  LOSS:  tensor(0.1174, grad_fn=<AddBackward0>)
# EPOCH:  617  LOSS:  tensor(0.1172, grad_fn=<AddBackward0>)
# EPOCH:  618  LOSS:  tensor(0.1171, grad_fn=<AddBackward0>)
# EPOCH:  619  LOSS:  tensor(0.1169, grad_fn=<AddBackward0>)
# EPOCH:  620  LOSS:  tensor(0.1168, grad_fn=<AddBackward0>)
# EPOCH:  621  LOSS:  tensor(0.1168, grad_fn=<AddBackward0>)
# EPOCH:  622  LOSS:  tensor(0.1168, grad_fn=<AddBackward0>)
# EPOCH:  623  LOSS:  tensor(0.1170, grad_fn=<AddBackward0>)
# EPOCH:  624  LOSS:  tensor(0.1173, grad_fn=<AddBackward0>)
# EPOCH:  625  LOSS:  tensor(0.1180, grad_fn=<AddBackward0>)
# EPOCH:  626  LOSS:  tensor(0.1193, grad_fn=<AddBackward0>)
# EPOCH:  627  LOSS:  tensor(0.1215, grad_fn=<AddBackward0>)
# EPOCH:  628  LOSS:  tensor(0.1248, grad_fn=<AddBackward0>)
# EPOCH:  629  LOSS:  tensor(0.1293, grad_fn=<AddBackward0>)
# EPOCH:  630  LOSS:  tensor(0.1346, grad_fn=<AddBackward0>)
# EPOCH:  631  LOSS:  tensor(0.1387, grad_fn=<AddBackward0>)
# EPOCH:  632  LOSS:  tensor(0.1386, grad_fn=<AddBackward0>)
# EPOCH:  633  LOSS:  tensor(0.1331, grad_fn=<AddBackward0>)
# EPOCH:  634  LOSS:  tensor(0.1240, grad_fn=<AddBackward0>)
# EPOCH:  635  LOSS:  tensor(0.1159, grad_fn=<AddBackward0>)
# EPOCH:  636  LOSS:  tensor(0.1129, grad_fn=<AddBackward0>)
# EPOCH:  637  LOSS:  tensor(0.1151, grad_fn=<AddBackward0>)
# EPOCH:  638  LOSS:  tensor(0.1197, grad_fn=<AddBackward0>)
# EPOCH:  639  LOSS:  tensor(0.1230, grad_fn=<AddBackward0>)
# EPOCH:  640  LOSS:  tensor(0.1228, grad_fn=<AddBackward0>)
# EPOCH:  641  LOSS:  tensor(0.1192, grad_fn=<AddBackward0>)
# EPOCH:  642  LOSS:  tensor(0.1145, grad_fn=<AddBackward0>)
# EPOCH:  643  LOSS:  tensor(0.1116, grad_fn=<AddBackward0>)
# EPOCH:  644  LOSS:  tensor(0.1114, grad_fn=<AddBackward0>)
# EPOCH:  645  LOSS:  tensor(0.1129, grad_fn=<AddBackward0>)
# EPOCH:  646  LOSS:  tensor(0.1149, grad_fn=<AddBackward0>)
# EPOCH:  647  LOSS:  tensor(0.1157, grad_fn=<AddBackward0>)
# EPOCH:  648  LOSS:  tensor(0.1147, grad_fn=<AddBackward0>)
# EPOCH:  649  LOSS:  tensor(0.1125, grad_fn=<AddBackward0>)
# EPOCH:  650  LOSS:  tensor(0.1105, grad_fn=<AddBackward0>)
# EPOCH:  651  LOSS:  tensor(0.1098, grad_fn=<AddBackward0>)
# EPOCH:  652  LOSS:  tensor(0.1101, grad_fn=<AddBackward0>)
# EPOCH:  653  LOSS:  tensor(0.1111, grad_fn=<AddBackward0>)
# EPOCH:  654  LOSS:  tensor(0.1119, grad_fn=<AddBackward0>)
# EPOCH:  655  LOSS:  tensor(0.1119, grad_fn=<AddBackward0>)
# EPOCH:  656  LOSS:  tensor(0.1112, grad_fn=<AddBackward0>)
# EPOCH:  657  LOSS:  tensor(0.1101, grad_fn=<AddBackward0>)
# EPOCH:  658  LOSS:  tensor(0.1091, grad_fn=<AddBackward0>)
# EPOCH:  659  LOSS:  tensor(0.1085, grad_fn=<AddBackward0>)
# EPOCH:  660  LOSS:  tensor(0.1085, grad_fn=<AddBackward0>)
# EPOCH:  661  LOSS:  tensor(0.1088, grad_fn=<AddBackward0>)
# EPOCH:  662  LOSS:  tensor(0.1091, grad_fn=<AddBackward0>)
# EPOCH:  663  LOSS:  tensor(0.1092, grad_fn=<AddBackward0>)
# EPOCH:  664  LOSS:  tensor(0.1092, grad_fn=<AddBackward0>)
# EPOCH:  665  LOSS:  tensor(0.1087, grad_fn=<AddBackward0>)
# EPOCH:  666  LOSS:  tensor(0.1083, grad_fn=<AddBackward0>)
# EPOCH:  667  LOSS:  tensor(0.1079, grad_fn=<AddBackward0>)
# EPOCH:  668  LOSS:  tensor(0.1076, grad_fn=<AddBackward0>)
# EPOCH:  669  LOSS:  tensor(0.1075, grad_fn=<AddBackward0>)
# EPOCH:  670  LOSS:  tensor(0.1074, grad_fn=<AddBackward0>)
# EPOCH:  671  LOSS:  tensor(0.1075, grad_fn=<AddBackward0>)
# EPOCH:  672  LOSS:  tensor(0.1075, grad_fn=<AddBackward0>)
# EPOCH:  673  LOSS:  tensor(0.1074, grad_fn=<AddBackward0>)
# EPOCH:  674  LOSS:  tensor(0.1073, grad_fn=<AddBackward0>)
# EPOCH:  675  LOSS:  tensor(0.1071, grad_fn=<AddBackward0>)
# EPOCH:  676  LOSS:  tensor(0.1069, grad_fn=<AddBackward0>)
# EPOCH:  677  LOSS:  tensor(0.1067, grad_fn=<AddBackward0>)
# EPOCH:  678  LOSS:  tensor(0.1064, grad_fn=<AddBackward0>)
# EPOCH:  679  LOSS:  tensor(0.1063, grad_fn=<AddBackward0>)
# EPOCH:  680  LOSS:  tensor(0.1061, grad_fn=<AddBackward0>)
# EPOCH:  681  LOSS:  tensor(0.1060, grad_fn=<AddBackward0>)
# EPOCH:  682  LOSS:  tensor(0.1058, grad_fn=<AddBackward0>)
# EPOCH:  683  LOSS:  tensor(0.1056, grad_fn=<AddBackward0>)
# EPOCH:  684  LOSS:  tensor(0.1055, grad_fn=<AddBackward0>)
# EPOCH:  685  LOSS:  tensor(0.1054, grad_fn=<AddBackward0>)
# EPOCH:  686  LOSS:  tensor(0.1053, grad_fn=<AddBackward0>)
# EPOCH:  687  LOSS:  tensor(0.1052, grad_fn=<AddBackward0>)
# EPOCH:  688  LOSS:  tensor(0.1052, grad_fn=<AddBackward0>)
# EPOCH:  689  LOSS:  tensor(0.1050, grad_fn=<AddBackward0>)
# EPOCH:  690  LOSS:  tensor(0.1050, grad_fn=<AddBackward0>)
# EPOCH:  691  LOSS:  tensor(0.1049, grad_fn=<AddBackward0>)
# EPOCH:  692  LOSS:  tensor(0.1048, grad_fn=<AddBackward0>)
# EPOCH:  693  LOSS:  tensor(0.1047, grad_fn=<AddBackward0>)
# EPOCH:  694  LOSS:  tensor(0.1046, grad_fn=<AddBackward0>)
# EPOCH:  695  LOSS:  tensor(0.1045, grad_fn=<AddBackward0>)
# EPOCH:  696  LOSS:  tensor(0.1044, grad_fn=<AddBackward0>)
# EPOCH:  697  LOSS:  tensor(0.1044, grad_fn=<AddBackward0>)
# EPOCH:  698  LOSS:  tensor(0.1043, grad_fn=<AddBackward0>)
# EPOCH:  699  LOSS:  tensor(0.1042, grad_fn=<AddBackward0>)
# EPOCH:  700  LOSS:  tensor(0.1043, grad_fn=<AddBackward0>)
# EPOCH:  701  LOSS:  tensor(0.1042, grad_fn=<AddBackward0>)
# EPOCH:  702  LOSS:  tensor(0.1042, grad_fn=<AddBackward0>)
# EPOCH:  703  LOSS:  tensor(0.1042, grad_fn=<AddBackward0>)
# EPOCH:  704  LOSS:  tensor(0.1043, grad_fn=<AddBackward0>)
# EPOCH:  705  LOSS:  tensor(0.1045, grad_fn=<AddBackward0>)
# EPOCH:  706  LOSS:  tensor(0.1052, grad_fn=<AddBackward0>)
# EPOCH:  707  LOSS:  tensor(0.1059, grad_fn=<AddBackward0>)
# EPOCH:  708  LOSS:  tensor(0.1072, grad_fn=<AddBackward0>)
# EPOCH:  709  LOSS:  tensor(0.1091, grad_fn=<AddBackward0>)
# EPOCH:  710  LOSS:  tensor(0.1118, grad_fn=<AddBackward0>)
# EPOCH:  711  LOSS:  tensor(0.1154, grad_fn=<AddBackward0>)
# EPOCH:  712  LOSS:  tensor(0.1198, grad_fn=<AddBackward0>)
# EPOCH:  713  LOSS:  tensor(0.1250, grad_fn=<AddBackward0>)
# EPOCH:  714  LOSS:  tensor(0.1303, grad_fn=<AddBackward0>)
# EPOCH:  715  LOSS:  tensor(0.1334, grad_fn=<AddBackward0>)
# EPOCH:  716  LOSS:  tensor(0.1324, grad_fn=<AddBackward0>)
# EPOCH:  717  LOSS:  tensor(0.1269, grad_fn=<AddBackward0>)
# EPOCH:  718  LOSS:  tensor(0.1180, grad_fn=<AddBackward0>)
# EPOCH:  719  LOSS:  tensor(0.1090, grad_fn=<AddBackward0>)
# EPOCH:  720  LOSS:  tensor(0.1032, grad_fn=<AddBackward0>)
# EPOCH:  721  LOSS:  tensor(0.1023, grad_fn=<AddBackward0>)
# EPOCH:  722  LOSS:  tensor(0.1053, grad_fn=<AddBackward0>)
# EPOCH:  723  LOSS:  tensor(0.1097, grad_fn=<AddBackward0>)
# EPOCH:  724  LOSS:  tensor(0.1132, grad_fn=<AddBackward0>)
# EPOCH:  725  LOSS:  tensor(0.1141, grad_fn=<AddBackward0>)
# EPOCH:  726  LOSS:  tensor(0.1122, grad_fn=<AddBackward0>)
# EPOCH:  727  LOSS:  tensor(0.1083, grad_fn=<AddBackward0>)
# EPOCH:  728  LOSS:  tensor(0.1041, grad_fn=<AddBackward0>)
# EPOCH:  729  LOSS:  tensor(0.1017, grad_fn=<AddBackward0>)
# EPOCH:  730  LOSS:  tensor(0.1016, grad_fn=<AddBackward0>)
# EPOCH:  731  LOSS:  tensor(0.1030, grad_fn=<AddBackward0>)
# EPOCH:  732  LOSS:  tensor(0.1051, grad_fn=<AddBackward0>)
# EPOCH:  733  LOSS:  tensor(0.1065, grad_fn=<AddBackward0>)
# EPOCH:  734  LOSS:  tensor(0.1067, grad_fn=<AddBackward0>)
# EPOCH:  735  LOSS:  tensor(0.1056, grad_fn=<AddBackward0>)
# EPOCH:  736  LOSS:  tensor(0.1035, grad_fn=<AddBackward0>)
# EPOCH:  737  LOSS:  tensor(0.1017, grad_fn=<AddBackward0>)
# EPOCH:  738  LOSS:  tensor(0.1008, grad_fn=<AddBackward0>)
# EPOCH:  739  LOSS:  tensor(0.1008, grad_fn=<AddBackward0>)
# EPOCH:  740  LOSS:  tensor(0.1015, grad_fn=<AddBackward0>)
# EPOCH:  741  LOSS:  tensor(0.1025, grad_fn=<AddBackward0>)
# EPOCH:  742  LOSS:  tensor(0.1031, grad_fn=<AddBackward0>)
# EPOCH:  743  LOSS:  tensor(0.1033, grad_fn=<AddBackward0>)
# EPOCH:  744  LOSS:  tensor(0.1030, grad_fn=<AddBackward0>)
# EPOCH:  745  LOSS:  tensor(0.1022, grad_fn=<AddBackward0>)
# EPOCH:  746  LOSS:  tensor(0.1012, grad_fn=<AddBackward0>)
# EPOCH:  747  LOSS:  tensor(0.1005, grad_fn=<AddBackward0>)
# EPOCH:  748  LOSS:  tensor(0.1000, grad_fn=<AddBackward0>)
# EPOCH:  749  LOSS:  tensor(0.0999, grad_fn=<AddBackward0>)
# EPOCH:  750  LOSS:  tensor(0.1000, grad_fn=<AddBackward0>)
# EPOCH:  751  LOSS:  tensor(0.1003, grad_fn=<AddBackward0>)
# EPOCH:  752  LOSS:  tensor(0.1005, grad_fn=<AddBackward0>)
# EPOCH:  753  LOSS:  tensor(0.1008, grad_fn=<AddBackward0>)
# EPOCH:  754  LOSS:  tensor(0.1008, grad_fn=<AddBackward0>)
# EPOCH:  755  LOSS:  tensor(0.1006, grad_fn=<AddBackward0>)
# EPOCH:  756  LOSS:  tensor(0.1003, grad_fn=<AddBackward0>)
# EPOCH:  757  LOSS:  tensor(0.0999, grad_fn=<AddBackward0>)
# EPOCH:  758  LOSS:  tensor(0.0996, grad_fn=<AddBackward0>)
# EPOCH:  759  LOSS:  tensor(0.0994, grad_fn=<AddBackward0>)
# EPOCH:  760  LOSS:  tensor(0.0992, grad_fn=<AddBackward0>)
# EPOCH:  761  LOSS:  tensor(0.0991, grad_fn=<AddBackward0>)
# EPOCH:  762  LOSS:  tensor(0.0990, grad_fn=<AddBackward0>)
# EPOCH:  763  LOSS:  tensor(0.0990, grad_fn=<AddBackward0>)
# EPOCH:  764  LOSS:  tensor(0.0991, grad_fn=<AddBackward0>)
# EPOCH:  765  LOSS:  tensor(0.0990, grad_fn=<AddBackward0>)
# EPOCH:  766  LOSS:  tensor(0.0991, grad_fn=<AddBackward0>)
# EPOCH:  767  LOSS:  tensor(0.0991, grad_fn=<AddBackward0>)
# EPOCH:  768  LOSS:  tensor(0.0991, grad_fn=<AddBackward0>)
# EPOCH:  769  LOSS:  tensor(0.0992, grad_fn=<AddBackward0>)
# EPOCH:  770  LOSS:  tensor(0.0992, grad_fn=<AddBackward0>)
# EPOCH:  771  LOSS:  tensor(0.0993, grad_fn=<AddBackward0>)
# EPOCH:  772  LOSS:  tensor(0.0993, grad_fn=<AddBackward0>)
# EPOCH:  773  LOSS:  tensor(0.0993, grad_fn=<AddBackward0>)
# EPOCH:  774  LOSS:  tensor(0.0993, grad_fn=<AddBackward0>)
# EPOCH:  775  LOSS:  tensor(0.0993, grad_fn=<AddBackward0>)
# EPOCH:  776  LOSS:  tensor(0.0994, grad_fn=<AddBackward0>)
# EPOCH:  777  LOSS:  tensor(0.0996, grad_fn=<AddBackward0>)
# EPOCH:  778  LOSS:  tensor(0.0998, grad_fn=<AddBackward0>)
# EPOCH:  779  LOSS:  tensor(0.1000, grad_fn=<AddBackward0>)
# EPOCH:  780  LOSS:  tensor(0.1003, grad_fn=<AddBackward0>)
# EPOCH:  781  LOSS:  tensor(0.1008, grad_fn=<AddBackward0>)
# EPOCH:  782  LOSS:  tensor(0.1014, grad_fn=<AddBackward0>)
# EPOCH:  783  LOSS:  tensor(0.1023, grad_fn=<AddBackward0>)
# EPOCH:  784  LOSS:  tensor(0.1036, grad_fn=<AddBackward0>)
# EPOCH:  785  LOSS:  tensor(0.1052, grad_fn=<AddBackward0>)
# EPOCH:  786  LOSS:  tensor(0.1075, grad_fn=<AddBackward0>)
# EPOCH:  787  LOSS:  tensor(0.1099, grad_fn=<AddBackward0>)
# EPOCH:  788  LOSS:  tensor(0.1128, grad_fn=<AddBackward0>)
# EPOCH:  789  LOSS:  tensor(0.1157, grad_fn=<AddBackward0>)
# EPOCH:  790  LOSS:  tensor(0.1186, grad_fn=<AddBackward0>)
# EPOCH:  791  LOSS:  tensor(0.1202, grad_fn=<AddBackward0>)
# EPOCH:  792  LOSS:  tensor(0.1201, grad_fn=<AddBackward0>)
# EPOCH:  793  LOSS:  tensor(0.1179, grad_fn=<AddBackward0>)
# EPOCH:  794  LOSS:  tensor(0.1142, grad_fn=<AddBackward0>)
# EPOCH:  795  LOSS:  tensor(0.1091, grad_fn=<AddBackward0>)
# EPOCH:  796  LOSS:  tensor(0.1039, grad_fn=<AddBackward0>)
# EPOCH:  797  LOSS:  tensor(0.0998, grad_fn=<AddBackward0>)
# EPOCH:  798  LOSS:  tensor(0.0975, grad_fn=<AddBackward0>)
# EPOCH:  799  LOSS:  tensor(0.0971, grad_fn=<AddBackward0>)
# EPOCH:  800  LOSS:  tensor(0.0982, grad_fn=<AddBackward0>)
# EPOCH:  801  LOSS:  tensor(0.1002, grad_fn=<AddBackward0>)
# EPOCH:  802  LOSS:  tensor(0.1024, grad_fn=<AddBackward0>)
# EPOCH:  803  LOSS:  tensor(0.1042, grad_fn=<AddBackward0>)
# EPOCH:  804  LOSS:  tensor(0.1055, grad_fn=<AddBackward0>)
# ...
# EPOCH:  663  LOSS:  tensor(0.1105, grad_fn=<AddBackward0>)
# EPOCH:  664  LOSS:  tensor(0.1104, grad_fn=<AddBackward0>)
# EPOCH:  665  LOSS:  tensor(0.1103, grad_fn=<AddBackward0>)
# EPOCH:  666  LOSS:  tensor(0.1101, grad_fn=<AddBackward0>)
# EPOCH:  667  LOSS:  tensor(0.1100, grad_fn=<AddBackward0>)
# EPOCH:  668  LOSS:  tensor(0.1099, grad_fn=<AddBackward0>)
# EPOCH:  669  LOSS:  tensor(0.1098, grad_fn=<AddBackward0>)
# EPOCH:  670  LOSS:  tensor(0.1097, grad_fn=<AddBackward0>)
# EPOCH:  671  LOSS:  tensor(0.1095, grad_fn=<AddBackward0>)
# EPOCH:  672  LOSS:  tensor(0.1094, grad_fn=<AddBackward0>)
# EPOCH:  673  LOSS:  tensor(0.1092, grad_fn=<AddBackward0>)
# EPOCH:  674  LOSS:  tensor(0.1092, grad_fn=<AddBackward0>)
# EPOCH:  675  LOSS:  tensor(0.1091, grad_fn=<AddBackward0>)
# EPOCH:  676  LOSS:  tensor(0.1089, grad_fn=<AddBackward0>)
# EPOCH:  677  LOSS:  tensor(0.1088, grad_fn=<AddBackward0>)
# EPOCH:  678  LOSS:  tensor(0.1087, grad_fn=<AddBackward0>)
# EPOCH:  679  LOSS:  tensor(0.1085, grad_fn=<AddBackward0>)
# EPOCH:  680  LOSS:  tensor(0.1084, grad_fn=<AddBackward0>)
# EPOCH:  681  LOSS:  tensor(0.1083, grad_fn=<AddBackward0>)
# EPOCH:  682  LOSS:  tensor(0.1081, grad_fn=<AddBackward0>)
# EPOCH:  683  LOSS:  tensor(0.1080, grad_fn=<AddBackward0>)
# EPOCH:  684  LOSS:  tensor(0.1079, grad_fn=<AddBackward0>)
# EPOCH:  685  LOSS:  tensor(0.1079, grad_fn=<AddBackward0>)
# EPOCH:  686  LOSS:  tensor(0.1077, grad_fn=<AddBackward0>)
# EPOCH:  687  LOSS:  tensor(0.1074, grad_fn=<AddBackward0>)
# EPOCH:  688  LOSS:  tensor(0.1070, grad_fn=<AddBackward0>)
# EPOCH:  689  LOSS:  tensor(0.1065, grad_fn=<AddBackward0>)
# EPOCH:  690  LOSS:  tensor(0.1061, grad_fn=<AddBackward0>)
# EPOCH:  691  LOSS:  tensor(0.1058, grad_fn=<AddBackward0>)
# EPOCH:  692  LOSS:  tensor(0.1055, grad_fn=<AddBackward0>)
# EPOCH:  693  LOSS:  tensor(0.1054, grad_fn=<AddBackward0>)
# EPOCH:  694  LOSS:  tensor(0.1054, grad_fn=<AddBackward0>)
# EPOCH:  695  LOSS:  tensor(0.1052, grad_fn=<AddBackward0>)
# EPOCH:  696  LOSS:  tensor(0.1051, grad_fn=<AddBackward0>)
# EPOCH:  697  LOSS:  tensor(0.1049, grad_fn=<AddBackward0>)
# EPOCH:  698  LOSS:  tensor(0.1047, grad_fn=<AddBackward0>)
# EPOCH:  699  LOSS:  tensor(0.1045, grad_fn=<AddBackward0>)
# EPOCH:  700  LOSS:  tensor(0.1043, grad_fn=<AddBackward0>)
# EPOCH:  701  LOSS:  tensor(0.1041, grad_fn=<AddBackward0>)
# EPOCH:  702  LOSS:  tensor(0.1040, grad_fn=<AddBackward0>)
# EPOCH:  703  LOSS:  tensor(0.1038, grad_fn=<AddBackward0>)
# EPOCH:  704  LOSS:  tensor(0.1036, grad_fn=<AddBackward0>)
# EPOCH:  705  LOSS:  tensor(0.1035, grad_fn=<AddBackward0>)
# EPOCH:  706  LOSS:  tensor(0.1033, grad_fn=<AddBackward0>)
# EPOCH:  707  LOSS:  tensor(0.1032, grad_fn=<AddBackward0>)
# EPOCH:  708  LOSS:  tensor(0.1030, grad_fn=<AddBackward0>)
# EPOCH:  709  LOSS:  tensor(0.1029, grad_fn=<AddBackward0>)
# EPOCH:  710  LOSS:  tensor(0.1027, grad_fn=<AddBackward0>)
# EPOCH:  711  LOSS:  tensor(0.1026, grad_fn=<AddBackward0>)
# EPOCH:  712  LOSS:  tensor(0.1024, grad_fn=<AddBackward0>)
# EPOCH:  713  LOSS:  tensor(0.1023, grad_fn=<AddBackward0>)
# EPOCH:  714  LOSS:  tensor(0.1022, grad_fn=<AddBackward0>)
# EPOCH:  715  LOSS:  tensor(0.1020, grad_fn=<AddBackward0>)
# EPOCH:  716  LOSS:  tensor(0.1019, grad_fn=<AddBackward0>)
# EPOCH:  717  LOSS:  tensor(0.1018, grad_fn=<AddBackward0>)
# EPOCH:  718  LOSS:  tensor(0.1016, grad_fn=<AddBackward0>)
# EPOCH:  719  LOSS:  tensor(0.1015, grad_fn=<AddBackward0>)
# EPOCH:  720  LOSS:  tensor(0.1014, grad_fn=<AddBackward0>)
# EPOCH:  721  LOSS:  tensor(0.1013, grad_fn=<AddBackward0>)
# EPOCH:  722  LOSS:  tensor(0.1011, grad_fn=<AddBackward0>)
# EPOCH:  723  LOSS:  tensor(0.1010, grad_fn=<AddBackward0>)
# EPOCH:  724  LOSS:  tensor(0.1009, grad_fn=<AddBackward0>)
# EPOCH:  725  LOSS:  tensor(0.1008, grad_fn=<AddBackward0>)
# EPOCH:  726  LOSS:  tensor(0.1007, grad_fn=<AddBackward0>)
# EPOCH:  727  LOSS:  tensor(0.1005, grad_fn=<AddBackward0>)
# EPOCH:  728  LOSS:  tensor(0.1004, grad_fn=<AddBackward0>)
# EPOCH:  729  LOSS:  tensor(0.1003, grad_fn=<AddBackward0>)
# EPOCH:  730  LOSS:  tensor(0.1002, grad_fn=<AddBackward0>)
# EPOCH:  731  LOSS:  tensor(0.1001, grad_fn=<AddBackward0>)
# EPOCH:  732  LOSS:  tensor(0.1000, grad_fn=<AddBackward0>)
# EPOCH:  733  LOSS:  tensor(0.0998, grad_fn=<AddBackward0>)
# EPOCH:  734  LOSS:  tensor(0.0998, grad_fn=<AddBackward0>)
# EPOCH:  735  LOSS:  tensor(0.0996, grad_fn=<AddBackward0>)
# EPOCH:  736  LOSS:  tensor(0.0995, grad_fn=<AddBackward0>)
# EPOCH:  737  LOSS:  tensor(0.0994, grad_fn=<AddBackward0>)
# EPOCH:  738  LOSS:  tensor(0.0993, grad_fn=<AddBackward0>)
# EPOCH:  739  LOSS:  tensor(0.0992, grad_fn=<AddBackward0>)
# EPOCH:  740  LOSS:  tensor(0.0991, grad_fn=<AddBackward0>)
# EPOCH:  741  LOSS:  tensor(0.0990, grad_fn=<AddBackward0>)
# EPOCH:  742  LOSS:  tensor(0.0989, grad_fn=<AddBackward0>)
# EPOCH:  743  LOSS:  tensor(0.0988, grad_fn=<AddBackward0>)
# EPOCH:  744  LOSS:  tensor(0.0987, grad_fn=<AddBackward0>)
# EPOCH:  745  LOSS:  tensor(0.0986, grad_fn=<AddBackward0>)
# EPOCH:  746  LOSS:  tensor(0.0985, grad_fn=<AddBackward0>)
# EPOCH:  747  LOSS:  tensor(0.0984, grad_fn=<AddBackward0>)
# EPOCH:  748  LOSS:  tensor(0.0982, grad_fn=<AddBackward0>)
# EPOCH:  749  LOSS:  tensor(0.0982, grad_fn=<AddBackward0>)
# EPOCH:  750  LOSS:  tensor(0.0980, grad_fn=<AddBackward0>)
# EPOCH:  751  LOSS:  tensor(0.0980, grad_fn=<AddBackward0>)
# EPOCH:  752  LOSS:  tensor(0.0978, grad_fn=<AddBackward0>)
# EPOCH:  753  LOSS:  tensor(0.0977, grad_fn=<AddBackward0>)
# EPOCH:  754  LOSS:  tensor(0.0977, grad_fn=<AddBackward0>)
# EPOCH:  755  LOSS:  tensor(0.0975, grad_fn=<AddBackward0>)
# EPOCH:  756  LOSS:  tensor(0.0973, grad_fn=<AddBackward0>)
# EPOCH:  757  LOSS:  tensor(0.0973, grad_fn=<AddBackward0>)
# EPOCH:  758  LOSS:  tensor(0.0972, grad_fn=<AddBackward0>)
# EPOCH:  759  LOSS:  tensor(0.0971, grad_fn=<AddBackward0>)
# EPOCH:  760  LOSS:  tensor(0.0970, grad_fn=<AddBackward0>)
# EPOCH:  761  LOSS:  tensor(0.0969, grad_fn=<AddBackward0>)
# EPOCH:  762  LOSS:  tensor(0.0968, grad_fn=<AddBackward0>)
# EPOCH:  763  LOSS:  tensor(0.0966, grad_fn=<AddBackward0>)
# EPOCH:  764  LOSS:  tensor(0.0965, grad_fn=<AddBackward0>)
# EPOCH:  765  LOSS:  tensor(0.0964, grad_fn=<AddBackward0>)
# EPOCH:  766  LOSS:  tensor(0.0962, grad_fn=<AddBackward0>)
# EPOCH:  767  LOSS:  tensor(0.0959, grad_fn=<AddBackward0>)
# EPOCH:  768  LOSS:  tensor(0.0957, grad_fn=<AddBackward0>)
# EPOCH:  769  LOSS:  tensor(0.0955, grad_fn=<AddBackward0>)
# EPOCH:  770  LOSS:  tensor(0.0952, grad_fn=<AddBackward0>)
# EPOCH:  771  LOSS:  tensor(0.0950, grad_fn=<AddBackward0>)
# EPOCH:  772  LOSS:  tensor(0.0948, grad_fn=<AddBackward0>)
# EPOCH:  773  LOSS:  tensor(0.0946, grad_fn=<AddBackward0>)
# EPOCH:  774  LOSS:  tensor(0.0944, grad_fn=<AddBackward0>)
# EPOCH:  775  LOSS:  tensor(0.0943, grad_fn=<AddBackward0>)
# EPOCH:  776  LOSS:  tensor(0.0941, grad_fn=<AddBackward0>)
# EPOCH:  777  LOSS:  tensor(0.0938, grad_fn=<AddBackward0>)
# EPOCH:  778  LOSS:  tensor(0.0936, grad_fn=<AddBackward0>)
# EPOCH:  779  LOSS:  tensor(0.0933, grad_fn=<AddBackward0>)
# EPOCH:  780  LOSS:  tensor(0.0931, grad_fn=<AddBackward0>)
# EPOCH:  781  LOSS:  tensor(0.0928, grad_fn=<AddBackward0>)
# EPOCH:  782  LOSS:  tensor(0.0925, grad_fn=<AddBackward0>)
# EPOCH:  783  LOSS:  tensor(0.0923, grad_fn=<AddBackward0>)
# EPOCH:  784  LOSS:  tensor(0.0920, grad_fn=<AddBackward0>)
# EPOCH:  785  LOSS:  tensor(0.0917, grad_fn=<AddBackward0>)
# EPOCH:  786  LOSS:  tensor(0.0914, grad_fn=<AddBackward0>)
# EPOCH:  787  LOSS:  tensor(0.0911, grad_fn=<AddBackward0>)
# EPOCH:  788  LOSS:  tensor(0.0908, grad_fn=<AddBackward0>)
# EPOCH:  789  LOSS:  tensor(0.0906, grad_fn=<AddBackward0>)
# EPOCH:  790  LOSS:  tensor(0.0903, grad_fn=<AddBackward0>)
# EPOCH:  791  LOSS:  tensor(0.0901, grad_fn=<AddBackward0>)
# EPOCH:  792  LOSS:  tensor(0.0898, grad_fn=<AddBackward0>)
# EPOCH:  793  LOSS:  tensor(0.0895, grad_fn=<AddBackward0>)
# EPOCH:  794  LOSS:  tensor(0.0891, grad_fn=<AddBackward0>)
# EPOCH:  795  LOSS:  tensor(0.0886, grad_fn=<AddBackward0>)
# EPOCH:  796  LOSS:  tensor(0.0882, grad_fn=<AddBackward0>)
# EPOCH:  797  LOSS:  tensor(0.0879, grad_fn=<AddBackward0>)
# EPOCH:  798  LOSS:  tensor(0.0875, grad_fn=<AddBackward0>)
# EPOCH:  799  LOSS:  tensor(0.0873, grad_fn=<AddBackward0>)
# EPOCH:  800  LOSS:  tensor(0.0870, grad_fn=<AddBackward0>)
# EPOCH:  801  LOSS:  tensor(0.0868, grad_fn=<AddBackward0>)
# EPOCH:  802  LOSS:  tensor(0.0867, grad_fn=<AddBackward0>)
# EPOCH:  803  LOSS:  tensor(0.0864, grad_fn=<AddBackward0>)
# EPOCH:  804  LOSS:  tensor(0.0862, grad_fn=<AddBackward0>)
# EPOCH:  805  LOSS:  tensor(0.0859, grad_fn=<AddBackward0>)
# EPOCH:  806  LOSS:  tensor(0.0855, grad_fn=<AddBackward0>)
# EPOCH:  807  LOSS:  tensor(0.0854, grad_fn=<AddBackward0>)
# EPOCH:  808  LOSS:  tensor(0.0852, grad_fn=<AddBackward0>)
# EPOCH:  809  LOSS:  tensor(0.0850, grad_fn=<AddBackward0>)
# EPOCH:  810  LOSS:  tensor(0.0847, grad_fn=<AddBackward0>)
# EPOCH:  811  LOSS:  tensor(0.0845, grad_fn=<AddBackward0>)
# EPOCH:  812  LOSS:  tensor(0.0843, grad_fn=<AddBackward0>)
# EPOCH:  813  LOSS:  tensor(0.0841, grad_fn=<AddBackward0>)
# EPOCH:  814  LOSS:  tensor(0.0839, grad_fn=<AddBackward0>)
# EPOCH:  815  LOSS:  tensor(0.0836, grad_fn=<AddBackward0>)
# EPOCH:  816  LOSS:  tensor(0.0834, grad_fn=<AddBackward0>)
# EPOCH:  817  LOSS:  tensor(0.0832, grad_fn=<AddBackward0>)
# EPOCH:  818  LOSS:  tensor(0.0829, grad_fn=<AddBackward0>)
# EPOCH:  819  LOSS:  tensor(0.0828, grad_fn=<AddBackward0>)
# EPOCH:  820  LOSS:  tensor(0.0826, grad_fn=<AddBackward0>)
# EPOCH:  821  LOSS:  tensor(0.0824, grad_fn=<AddBackward0>)
# EPOCH:  822  LOSS:  tensor(0.0822, grad_fn=<AddBackward0>)
# EPOCH:  823  LOSS:  tensor(0.0820, grad_fn=<AddBackward0>)
# EPOCH:  824  LOSS:  tensor(0.0818, grad_fn=<AddBackward0>)
# EPOCH:  825  LOSS:  tensor(0.0816, grad_fn=<AddBackward0>)
# EPOCH:  826  LOSS:  tensor(0.0814, grad_fn=<AddBackward0>)
# EPOCH:  827  LOSS:  tensor(0.0812, grad_fn=<AddBackward0>)
# EPOCH:  828  LOSS:  tensor(0.0810, grad_fn=<AddBackward0>)
# EPOCH:  829  LOSS:  tensor(0.0808, grad_fn=<AddBackward0>)
# EPOCH:  830  LOSS:  tensor(0.0807, grad_fn=<AddBackward0>)
# EPOCH:  831  LOSS:  tensor(0.0805, grad_fn=<AddBackward0>)
# EPOCH:  832  LOSS:  tensor(0.0803, grad_fn=<AddBackward0>)
# EPOCH:  833  LOSS:  tensor(0.0802, grad_fn=<AddBackward0>)
# EPOCH:  834  LOSS:  tensor(0.0800, grad_fn=<AddBackward0>)
# EPOCH:  835  LOSS:  tensor(0.0799, grad_fn=<AddBackward0>)
# EPOCH:  836  LOSS:  tensor(0.0797, grad_fn=<AddBackward0>)
# EPOCH:  837  LOSS:  tensor(0.0795, grad_fn=<AddBackward0>)
# EPOCH:  838  LOSS:  tensor(0.0793, grad_fn=<AddBackward0>)
# EPOCH:  839  LOSS:  tensor(0.0792, grad_fn=<AddBackward0>)
# EPOCH:  840  LOSS:  tensor(0.0790, grad_fn=<AddBackward0>)
# EPOCH:  841  LOSS:  tensor(0.0789, grad_fn=<AddBackward0>)
# EPOCH:  842  LOSS:  tensor(0.0787, grad_fn=<AddBackward0>)
# EPOCH:  843  LOSS:  tensor(0.0785, grad_fn=<AddBackward0>)
# EPOCH:  844  LOSS:  tensor(0.0784, grad_fn=<AddBackward0>)
# EPOCH:  845  LOSS:  tensor(0.0783, grad_fn=<AddBackward0>)
# EPOCH:  846  LOSS:  tensor(0.0781, grad_fn=<AddBackward0>)
# EPOCH:  847  LOSS:  tensor(0.0780, grad_fn=<AddBackward0>)
# EPOCH:  848  LOSS:  tensor(0.0779, grad_fn=<AddBackward0>)
# EPOCH:  849  LOSS:  tensor(0.0777, grad_fn=<AddBackward0>)
# EPOCH:  850  LOSS:  tensor(0.0776, grad_fn=<AddBackward0>)
# EPOCH:  851  LOSS:  tensor(0.0774, grad_fn=<AddBackward0>)
# EPOCH:  852  LOSS:  tensor(0.0773, grad_fn=<AddBackward0>)
# EPOCH:  853  LOSS:  tensor(0.0771, grad_fn=<AddBackward0>)
# EPOCH:  854  LOSS:  tensor(0.0770, grad_fn=<AddBackward0>)
# EPOCH:  855  LOSS:  tensor(0.0769, grad_fn=<AddBackward0>)
# EPOCH:  856  LOSS:  tensor(0.0768, grad_fn=<AddBackward0>)
# EPOCH:  857  LOSS:  tensor(0.0766, grad_fn=<AddBackward0>)
# EPOCH:  858  LOSS:  tensor(0.0765, grad_fn=<AddBackward0>)
# EPOCH:  859  LOSS:  tensor(0.0764, grad_fn=<AddBackward0>)
# EPOCH:  860  LOSS:  tensor(0.0763, grad_fn=<AddBackward0>)
# EPOCH:  861  LOSS:  tensor(0.0762, grad_fn=<AddBackward0>)
# EPOCH:  862  LOSS:  tensor(0.0761, grad_fn=<AddBackward0>)
# EPOCH:  863  LOSS:  tensor(0.0760, grad_fn=<AddBackward0>)
# EPOCH:  864  LOSS:  tensor(0.0759, grad_fn=<AddBackward0>)
# EPOCH:  865  LOSS:  tensor(0.0758, grad_fn=<AddBackward0>)
# EPOCH:  866  LOSS:  tensor(0.0756, grad_fn=<AddBackward0>)
# EPOCH:  867  LOSS:  tensor(0.0755, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5de81f0090e7> in <module>
#      90
#      91     network = netWBB(X_train_original, y_train_original, ([ int(n_hidden) ] * num_hidden_layers),
# ---> 92             normalize = True, n_epochs = int(n_epochs * epochs_multiplier))
#      93
#      94
#
# <ipython-input-17-f4b946c393d6> in __init__(self, X_train, y_train, n_hidden, n_epochs, normalize)
#      87
#      88                 index1 = 0;
# ---> 89                 for step, (batch_x, batch_y) in enumerate(loader):
#      90
#      91                     index2 = (step+1)*BATCH_SIZE   # set index of weight array to multiply with loss: weight*loss_func
#
# ~/anaconda3/envs/SSL/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __iter__(self)
#     276             return _SingleProcessDataLoaderIter(self)
#     277         else:
# --> 278             return _MultiProcessingDataLoaderIter(self)
#     279
#     280     @property
#
# ~/anaconda3/envs/SSL/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     680             #     before it starts, and __del__ tries to join but will get:
#     681             #     AssertionError: can only join a started process.
# --> 682             w.start()
#     683             self._index_queues.append(index_queue)
#     684             self._workers.append(w)
#
# ~/anaconda3/envs/SSL/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda3/envs/SSL/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~/anaconda3/envs/SSL/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda3/envs/SSL/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      15
#      16     def __init__(self, process_obj):
# ---> 17         util._flush_std_streams()
#      18         self.returncode = None
#      19         self._launch(process_obj)
#
# ~/anaconda3/envs/SSL/lib/python3.6/multiprocessing/util.py in _flush_std_streams()
#     395 def _flush_std_streams():
#     396     try:
# --> 397         sys.stdout.flush()
#     398     except (AttributeError, ValueError):
#     399         pass
#
# ~/anaconda3/envs/SSL/lib/python3.6/site-packages/ipykernel/iostream.py in flush(self)
#     347                 self.pub_thread.schedule(evt.set)
#     348                 # and give a timeout to avoid
# --> 349                 if not evt.wait(self.flush_timeout):
#     350                     # write directly to __stderr__ instead of warning because
#     351                     # if this is happening sys.stderr may be the problem.
#
# ~/anaconda3/envs/SSL/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/SSL/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
